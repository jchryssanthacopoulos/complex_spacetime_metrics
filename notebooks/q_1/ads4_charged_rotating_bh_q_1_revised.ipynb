# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial import Delaunay
import sympy

sympy.init_printing()

# %% [markdown]
# ### Variable Definitions

# %%
t, r, theta, phi, phi_tilde = sympy.symbols("t r theta phi \\tilde{\phi}")

# %%
dt, dr, dtheta, dphi, dphi_tilde = sympy.symbols(r"dt dr d\theta d\phi d\tilde{\phi}")

# %%
r_tilde, delta_r, delta_theta, W, xi = sympy.symbols("\\tilde{r} Delta_r Delta_theta W Xi")

# %%
tau, dtau = sympy.symbols("tau d\\tau")

# %%
a, r_tilde_plus, delta = sympy.symbols("a \\tilde{r}_+ \delta")

# %% [markdown]
# ### Metric

# %%
metric_orig = -delta_r / W * (dt - a * sympy.sin(theta) ** 2 * dphi / xi) ** 2
metric_orig += delta_theta * sympy.sin(theta) ** 2 / W * (a * dt - (r_tilde ** 2 + a ** 2) * dphi / xi) ** 2
metric_orig
# Out:
#                            2                                          2
#      ⎛                2   ⎞           ⎛             ⎛         2    2⎞⎞
#      ⎜     a⋅d\phi⋅sin (θ)⎟           ⎜       d\phi⋅⎝\tilde{r}  + a ⎠⎟     2
#   Δᵣ⋅⎜dt - ───────────────⎟    Δₜₕₑₜₐ⋅⎜a⋅dt - ───────────────────────⎟ ⋅sin (θ
#      ⎝            Ξ       ⎠           ⎝                  Ξ           ⎠
# - ────────────────────────── + ───────────────────────────────────────────────
#               W                                       W
#
#
#
#
# )
#
# ─

# %% [markdown]
# #### Just Wick Rotation

# %%
dt_val = sympy.I * dtau

# %%
euclidean_metric = metric_orig.subs({dt: dt_val}).expand().collect([dtau ** 2, dtau * dphi, dphi ** 2])
euclidean_metric
# Out:
#        ⎛      2    4                      4    2                        2  2
#      2 ⎜  Δᵣ⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅\tilde{r} ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a ⋅s
# d\phi ⋅⎜- ───────────── + ───────────────────────── + ────────────────────────
#        ⎜          2                     2                             2
#        ⎝       W⋅Ξ                   W⋅Ξ                           W⋅Ξ
#
#   2              4    2   ⎞               ⎛            2
# in (θ)   Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟               ⎜2⋅ⅈ⋅Δᵣ⋅a⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅\tild
# ────── + ─────────────────⎟ + d\phi⋅d\tau⋅⎜──────────────── - ────────────────
#                    2      ⎟               ⎝      W⋅Ξ                        W⋅
#                 W⋅Ξ       ⎠
#
#     2      2                  3    2   ⎞          ⎛             2    2   ⎞
# e{r} ⋅a⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟        2 ⎜Δᵣ   Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟
# ─────────────── - ─────────────────────⎟ + d\tau ⋅⎜── - ─────────────────⎟
# Ξ                          W⋅Ξ         ⎠          ⎝W            W        ⎠

# %%
metric_list_matrix = [[0 for i in range(2)] for i in range(2)]
metric_list_matrix[0][0] = euclidean_metric.coeff(dtau ** 2)
metric_list_matrix[0][1] = euclidean_metric.coeff(dtau * dphi) / 2
metric_list_matrix[1][0] = metric_list_matrix[0][1]
metric_list_matrix[1][1] = euclidean_metric.coeff(dphi ** 2)

# %%
g_mat = sympy.Matrix(metric_list_matrix)
g_mat.simplify()
g_mat
# Out:
# ⎡                          2    2                                       ⎛
# ⎢             Δᵣ - Δₜₕₑₜₐ⋅a ⋅sin (θ)                                ⅈ⋅a⋅⎝Δᵣ -
# ⎢             ──────────────────────                                ──────────
# ⎢                       W
# ⎢
# ⎢    ⎛                     2           2⎞    2     ⎛      2    2
# ⎢ⅈ⋅a⋅⎝Δᵣ - Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⋅sin (θ)  ⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\
# ⎢────────────────────────────────────────────────  ───────────────────────────
# ⎢                      W⋅Ξ
# ⎣
#
#                 2           2⎞    2                    ⎤
# Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⋅sin (θ)                 ⎥
# ──────────────────────────────────────                 ⎥
#             W⋅Ξ                                        ⎥
#                                                        ⎥
#         4                     2  2           4⎞    2   ⎥
# tilde{r}  + 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠⋅sin (θ)⎥
# ───────────────────────────────────────────────────────⎥
#                2                                       ⎥
#             W⋅Ξ                                        ⎦

# %%
g_mat.det().simplify()
# Out:
#                                    2
#           ⎛         2    2    2   ⎞     2
# Δᵣ⋅Δₜₕₑₜₐ⋅⎝\tilde{r}  + a ⋅cos (θ)⎠ ⋅sin (θ)
# ────────────────────────────────────────────
#                     2  2
#                    W ⋅Ξ

# %%
g_00 = delta_r - delta_theta * a ** 2 * sympy.sin(theta) ** 2
g_00
# Out:
#              2    2
# Δᵣ - Δₜₕₑₜₐ⋅a ⋅sin (θ)

# %%
g_11 = (r_tilde ** 2 + a ** 2) ** 2 * delta_theta - delta_r * a ** 2 * sympy.sin(theta) ** 2
g_11
# Out:
#                                           2
#       2    2             ⎛         2    2⎞
# - Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅⎝\tilde{r}  + a ⎠

# %%
(g_11 * sympy.sin(theta) ** 2 / (W * xi ** 2) - g_mat[1, 1]).simplify()
# Out:
# 0

# %%
delta_r_val = (r_tilde ** 2 - r_tilde_plus ** 2) ** 2 + (r_tilde_plus ** 2 + 1) ** 2 * ((r_tilde_plus - r_tilde) ** 2)
delta_r_val
# Out:
#                                             2                             2
#                          2 ⎛          2    ⎞    ⎛         2             2⎞
# (-\tilde{r} + \tilde{r}₊) ⋅⎝\tilde{r}₊  + 1⎠  + ⎝\tilde{r}  - \tilde{r}₊ ⎠

# %%
xi_val = 1 - a ** 2
a_val = r_tilde_plus ** 2
delta_theta_val = 1 - a ** 2 * sympy.cos(theta) ** 2

# %% [markdown]
# ##### $g_{00}$

# %%
g_00_simp = g_00.subs({delta_r: delta_r_val, xi: xi_val, delta_theta: delta_theta_val}).subs({a: a_val})
g_00_simp = g_00_simp.expand().collect([r_tilde, r_tilde ** 2, r_tilde ** 3, r_tilde ** 4])
g_00_simp
# Out:
#          4            2 ⎛          4    ⎞             ⎛              5
# \tilde{r}  + \tilde{r} ⋅⎝\tilde{r}₊  + 1⎠ + \tilde{r}⋅⎝- 2⋅\tilde{r}₊  - 4⋅\ti
#
#        3               ⎞             8    2       2                6
# lde{r}₊  - 2⋅\tilde{r}₊⎠ + \tilde{r}₊ ⋅sin (θ)⋅cos (θ) + \tilde{r}₊  - \tilde{
#
#    4    2                  4             2
# r}₊ ⋅sin (θ) + 3⋅\tilde{r}₊  + \tilde{r}₊

# %%
A_coeff_00 = g_00_simp.coeff(r_tilde).simplify()
A_coeff_00.factor()
# Out:
#                                2
#               ⎛          2    ⎞
# -2⋅\tilde{r}₊⋅⎝\tilde{r}₊  + 1⎠

# %%
B_coeff_00 = g_00_simp.coeff(r_tilde ** 2).simplify().factor()
B_coeff_00
# Out:
#           4
# \tilde{r}₊  + 1

# %%
C_coeff_00 = g_00_simp.coeff(r_tilde ** 4).simplify().factor()
C_coeff_00
# Out:
# 1

# %%
D_coeff_00 = g_00_simp - A_coeff_00 * r_tilde - B_coeff_00 * r_tilde ** 2 - C_coeff_00 * r_tilde ** 4
D_coeff_00.factor()
# Out:
#           2 ⎛          6    2       2                4             2    2
# \tilde{r}₊ ⋅⎝\tilde{r}₊ ⋅sin (θ)⋅cos (θ) + \tilde{r}₊  - \tilde{r}₊ ⋅sin (θ) +
#
#              2    ⎞
#  3⋅\tilde{r}₊  + 1⎠

# %% [markdown]
# ##### $g_{11}$

# %%
g_11_simp = g_11.subs({delta_r: delta_r_val, delta_theta: delta_theta_val}).subs({a: a_val})
g_11_simp /= (r_tilde_plus ** 2 + 1)
g_11_simp = g_11_simp.expand().collect([r_tilde, r_tilde ** 2, r_tilde ** 3, r_tilde ** 4])
g_11_simp.simplify()
# Out:
#          4 ⎛              4⎞            2           4 ⎛            4    2
# \tilde{r} ⋅⎝1 - \tilde{r}₊ ⎠ + \tilde{r} ⋅\tilde{r}₊ ⋅⎝- \tilde{r}₊ ⋅cos (θ) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            4      2       ⎞                         5 ⎛          4
#  \tilde{r}₊  + cos (θ) + 1⎠ + 2⋅\tilde{r}⋅\tilde{r}₊ ⋅⎝\tilde{r}₊  + 2⋅\tilde{
# ──────────────────────────────────────────────────────────────────────────────
#                                                                 2
#                                                       \tilde{r}₊  + 1
#
#    2    ⎞    2                12    2                10    2
# r}₊  + 1⎠⋅sin (θ) - \tilde{r}₊  ⋅cos (θ) - \tilde{r}₊  ⋅sin (θ) - 3⋅\tilde{r}₊
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 8    2                8             6    2
#  ⋅sin (θ) + \tilde{r}₊  - \tilde{r}₊ ⋅sin (θ)
# ─────────────────────────────────────────────

# %%
A_coeff_11 = g_11_simp.coeff(r_tilde).simplify()
A_coeff_11.factor()
# Out:
#             5 ⎛          2    ⎞    2
# 2⋅\tilde{r}₊ ⋅⎝\tilde{r}₊  + 1⎠⋅sin (θ)

# %%
B_coeff_11 = g_11_simp.coeff(r_tilde ** 2).simplify().factor()
B_coeff_11
# Out:
#            4                                   ⎛   2       ⎞
# -\tilde{r}₊ ⋅(\tilde{r}₊ - 1)⋅(\tilde{r}₊ + 1)⋅⎝cos (θ) + 1⎠

# %%
C_coeff_11 = g_11_simp.coeff(r_tilde ** 4).simplify().factor()
C_coeff_11
# Out:
# -(\tilde{r}₊ - 1)⋅(\tilde{r}₊ + 1)

# %%
D_coeff_11 = g_11_simp - A_coeff_11 * r_tilde - B_coeff_11 * r_tilde ** 2 - C_coeff_11 * r_tilde ** 4
D_coeff_11 = D_coeff_11.simplify().factor()
D_coeff_11
# Out:
#           6 ⎛          4    2                4               2    2
# \tilde{r}₊ ⋅⎝\tilde{r}₊ ⋅sin (θ) - \tilde{r}₊  - 2⋅\tilde{r}₊ ⋅sin (θ) + \tild
#
#      2      2   ⎞
# e{r}₊  - sin (θ)⎠

# %% [markdown]
# This is the same as:

# %%
D_coeff_11_new = -r_tilde_plus ** 6 * (r_tilde_plus ** 4 * sympy.cos(theta) ** 2 - r_tilde_plus ** 2 * sympy.cos(2 * theta) + sympy.sin(theta) ** 2)
D_coeff_11_new
# Out:
#            6 ⎛          4    2                2               2   ⎞
# -\tilde{r}₊ ⋅⎝\tilde{r}₊ ⋅cos (θ) - \tilde{r}₊ ⋅cos(2⋅θ) + sin (θ)⎠

# %%
D_coeff_11_new = r_tilde_plus ** 6 * (r_tilde_plus ** 4 * sympy.sin(theta) ** 2 + r_tilde_plus ** 2 + 2 * r_tilde_plus ** 2 * sympy.cos(theta) ** 2 + sympy.cos(theta) ** 2)
D_coeff_11_new -= r_tilde_plus ** 6 * (r_tilde_plus ** 2 + 1) ** 2
D_coeff_11_new
# Out:
#                                2
#             6 ⎛          2    ⎞              6 ⎛          4    2
# - \tilde{r}₊ ⋅⎝\tilde{r}₊  + 1⎠  + \tilde{r}₊ ⋅⎝\tilde{r}₊ ⋅sin (θ) + 2⋅\tilde
#
#
#     2    2                2      2   ⎞
# {r}₊ ⋅cos (θ) + \tilde{r}₊  + cos (θ)⎠

# %%
D_coeff_11_new = r_tilde_plus ** 6 * (sympy.sin(theta) ** 2 * (r_tilde_plus ** 2 - 1) ** 2 + r_tilde_plus ** 2 * (1 - r_tilde_plus ** 2) - 2 * sympy.sin(theta) ** 2)
D_coeff_11_new
# Out:
#             ⎛                                                 2
#           6 ⎜          2 ⎛              2⎞   ⎛          2    ⎞     2
# \tilde{r}₊ ⋅⎝\tilde{r}₊ ⋅⎝1 - \tilde{r}₊ ⎠ + ⎝\tilde{r}₊  - 1⎠ ⋅sin (θ) - 2⋅si
#
#      ⎞
#  2   ⎟
# n (θ)⎠

# %%
(D_coeff_11 - D_coeff_11_new).simplify()
# Out:
# 0

# %%
sigma_quartic = C_coeff_11 * r_tilde ** 4 + B_coeff_11 * r_tilde ** 2 + A_coeff_11 * r_tilde + D_coeff_11
sigma_quartic
# Out:
#            4                                              2           4
# - \tilde{r} ⋅(\tilde{r}₊ - 1)⋅(\tilde{r}₊ + 1) - \tilde{r} ⋅\tilde{r}₊ ⋅(\tild
#
#                             ⎛   2       ⎞                         5 ⎛
# e{r}₊ - 1)⋅(\tilde{r}₊ + 1)⋅⎝cos (θ) + 1⎠ + 2⋅\tilde{r}⋅\tilde{r}₊ ⋅⎝\tilde{r}
#
#  2    ⎞    2                6 ⎛          4    2                4
# ₊  + 1⎠⋅sin (θ) + \tilde{r}₊ ⋅⎝\tilde{r}₊ ⋅sin (θ) - \tilde{r}₊  - 2⋅\tilde{r}
#
#  2    2                2      2   ⎞
# ₊ ⋅sin (θ) + \tilde{r}₊  - sin (θ)⎠

# %%
(sigma_quartic - g_11_simp).simplify()
# Out:
# 0

# %%
D_coeff_11.factor()
# Out:
#           6 ⎛          4    2                4               2    2
# \tilde{r}₊ ⋅⎝\tilde{r}₊ ⋅sin (θ) - \tilde{r}₊  - 2⋅\tilde{r}₊ ⋅sin (θ) + \tild
#
#      2      2   ⎞
# e{r}₊  - sin (θ)⎠

# %% [markdown]
# Get the roots.

# %%
sol = sympy.solve(sigma_quartic, r_tilde)

# %%
roots = {}

r_tilde_plus_vals = range(1, 21)
theta_val = np.pi / 2

for r_tilde_plus_val in r_tilde_plus_vals:
    root_vals = []
    for i in range(4):
        root = sol[i].subs({r_tilde_plus: r_tilde_plus_val, theta: theta_val}).evalf()
        root_vals.append(root)
    roots[r_tilde_plus_val] = root_vals

# %%
roots
# Out:
# {1: [nan, nan, nan, nan], 2: [-2.0655502102563 - 5.01763867140387⋅ⅈ, -2.065550
# 2102563 + 5.01763867140387⋅ⅈ, 1.26323948828632, 2.86786093222627], 3: [-3.0167
# 1329135522 - 9.99725386493028⋅ⅈ, -3.01671329135522 + 9.99725386493028⋅ⅈ, 2.154
# 17826285794, 3.87924831985251], 4: [-4.00553403306599 - 16.9973687937857⋅ⅈ, -4
# .00553403306599 + 16.9973687937857⋅ⅈ, 3.09892489354698, 4.91214317258501], 5:
# [-5.00217667639291 - 25.9983869339842⋅ⅈ, -5.00217667639291 + 25.9983869339842⋅
# ⅈ, 4.06805668117599, 5.93629667160983], 6: [-6.00097514588222 - 36.99903996623
# 61⋅ⅈ, -6.00097514588222 + 36.9990399662361⋅ⅈ, 5.04936964981481, 6.952580641949
# 63], 7: [-7.00048346330319 - 49.9994123896809⋅ⅈ, -7.00048346330319 + 49.999412
# 3896809⋅ⅈ, 6.03731064733864, 7.96365627926773], 8: [-8.00025976251418 - 64.999
# 6263160169⋅ⅈ, -8.00025976251418 + 64.9996263160169⋅ⅈ, 7.02912193170218, 8.9713
# 9759332619], 9: [-9.00014892574029 - 81.9997532989462⋅ⅈ, -9.00014892574029 + 8
# 1.9997532989462⋅ⅈ, 8.02332769489109, 9.97697015658948], 10: [-10.0000900483062
#  - 100.999831527909⋅ⅈ, -10.0000900483062 + 100.999831527909⋅ⅈ, 9.0190871341857
# 8, 10.9810929624267], 11: [-11.0000569141056 - 121.999881467305⋅ⅈ, -11.0000569
# 141056 + 121.999881467305⋅ⅈ, 10.0158954388096, 11.9842183894016], 12: [-12.000
# 0373415834 - 144.999914396346⋅ⅈ, -12.0000373415834 + 144.999914396346⋅ⅈ, 11.01
# 34358269079, 12.986638856259], 13: [-13.0000252940363 - 169.999936746466⋅ⅈ, -1
# 3.0000252940363 + 169.999936746466⋅ⅈ, 12.0115018945088, 13.9885486935639], 14:
#  [-14.0000176113819 - 196.999952311454⋅ⅈ, -14.0000176113819 + 196.999952311454
# ⋅ⅈ, 13.0099547461364, 14.9900804766274], 15: [-15.0000125595593 - 225.99996340
# 1767⋅ⅈ, -15.0000125595593 + 225.999963401767⋅ⅈ, 14.0086982673489, 15.991326851
# 7697], 16: [-16.0000091472902 - 256.999971466364⋅ⅈ, -16.0000091472902 + 256.99
# 9971466364⋅ⅈ, 15.007664305447, 16.9923539891334], 17: [-17.0000067872519 - 289
# .999977438495⋅ⅈ, -17.0000067872519 + 289.999977438495⋅ⅈ, 16.0068034877475, 17.
# 9932100867562], 18: [-18.0000051202953 - 324.999981933966⋅ⅈ, -18.0000051202953
#  + 324.999981933966⋅ⅈ, 17.0060793599914, 18.9939308805992], 19: [-19.000003920
# 5525 - 361.999985368134⋅ⅈ, -19.0000039205525 + 361.999985368134⋅ⅈ, 18.00546454
# 61326, 19.9945432949725], 20: [-20.0000030423706 - 400.999988026783⋅ⅈ, -20.000
# 0030423706 + 400.999988026783⋅ⅈ, 19.0049381750346, 20.9950679097067]}

# %%
root_imag_part = [r[1].coeff(sympy.I) for r in roots.values()]
root_imag_part
# Out:
# [0, 5.01763867140387, 9.99725386493028, 16.9973687937857, 25.9983869339842, 36
# .9990399662361, 49.9994123896809, 64.9996263160169, 81.9997532989462, 100.9998
# 31527909, 121.999881467305, 144.999914396346, 169.999936746466, 196.9999523114
# 54, 225.999963401767, 256.999971466364, 289.999977438495, 324.999981933966, 36
# 1.999985368134, 400.999988026783]

# %%
[r ** 2 for r in r_tilde_plus_vals]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324,
#  361, 400]

# %%
root_real_part = [r[1] - sympy.I * r[1].coeff(sympy.I) for r in roots.values()]
root_real_part
# Out:
# [nan, -2.0655502102563, -3.01671329135522, -4.00553403306599, -5.0021766763929
# 1, -6.00097514588222, -7.00048346330319, -8.00025976251418, -9.00014892574029,
#  -10.0000900483062, -11.0000569141056, -12.0000373415834, -13.0000252940363, -
# 14.0000176113819, -15.0000125595593, -16.0000091472902, -17.0000067872519, -18
# .0000051202953, -19.0000039205525, -20.0000030423706]

# %%
plt.plot(r_tilde_plus_vals, root_imag_part, 'x-');

# %%
plt.plot(r_tilde_plus_vals, root_real_part, 'x-');

# %% [markdown]
# Plot the function.

# %%
# this constraint has to be satisfied: r_tilde_plus ** 2 < 1
r_tilde_plus_val = 0.1

r_tilde_vals = np.linspace(0.1, 10, 50)
theta_val = 2 * np.pi / 3

sigma_quartic_vals = []

for r_tilde_val in r_tilde_vals:
    sigma_quartic_vals.append(sigma_quartic.subs({r_tilde_plus: r_tilde_plus_val, r_tilde: r_tilde_val, theta: theta_val}))

# %%
sigma_quartic_vals
# Out:
# [0.000100997475, 0.00825455120829062, 0.0639586092430264, 0.246196385178428, 0
# .673542678164717, 1.50416387290312, 2.93581793964586, 5.20585443419616, 8.5912
# 1449790826, 13.4084308576874, 20.0136278259898, 28.8025213008226, 40.210418765
# 7442, 54.7122192898638, 72.8224135278415, 95.0950837198888, 122.123903691768,
# 154.542138854791, 193.022646205824, 238.277874327282, 291.05986338713, 352.160
# 245138886, 422.410242921618, 502.680671659946, 593.881937864039, 696.964039629
# 619, 812.916566637958, 942.76870015588, 1087.58921303576, 1248.48646971552, 14
# 26.60842621864, 1623.14263015414, 1839.31622071661, 2076.39592868617, 2335.688
# 07642851, 2618.53857789485, 2926.33293862197, 3260.49625573222, 3622.493217933
# 47, 4013.82810551916, 4436.04479036828, 4890.72673594536, 5379.49699730049, 59
# 04.01822106931, 6465.99264547301, 7067.16210031834, 7709.30800699758, 8394.251
# 37848858, 9123.85281935473, 9900.01252574497]

# %%
plt.plot(r_tilde_vals, sigma_quartic_vals, 'x-');

# %% [markdown]
# #### Wick Rotation + Omega Shift

# %%
omega = sympy.symbols("Omega")
dphi_val = dphi_tilde + omega * dt_val
dphi_val
# Out:
# ⅈ⋅Ω⋅d\tau + d\tilde{\phi}

# %%
euclidean_metric_2 = euclidean_metric.subs({dphi: dphi_val}).expand().collect([dtau ** 2, dtau * dphi_tilde, dphi_tilde ** 2])
euclidean_metric_2
# Out:
#        ⎛    2  2    4                  2                   2          4    2
#      2 ⎜Δᵣ⋅Ω ⋅a ⋅sin (θ)   2⋅Δᵣ⋅Ω⋅a⋅sin (θ)   Δᵣ   Δₜₕₑₜₐ⋅Ω ⋅\tilde{r} ⋅sin (θ
# d\tau ⋅⎜──────────────── - ──────────────── + ── - ───────────────────────────
#        ⎜         2               W⋅Ξ          W                   2
#        ⎝      W⋅Ξ                                              W⋅Ξ
#
#               2          2  2    2              2  4    2
# )   2⋅Δₜₕₑₜₐ⋅Ω ⋅\tilde{r} ⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅Ω ⋅a ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅Ω⋅\til
# ─ - ───────────────────────────────── - ──────────────────── + ───────────────
#                       2                            2                         W
#                    W⋅Ξ                          W⋅Ξ
#
#      2      2                  3    2              2    2   ⎞
# de{r} ⋅a⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅Ω⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟
# ──────────────── + ───────────────────── - ─────────────────⎟ + d\tau⋅d\tilde{
# ⋅Ξ                          W⋅Ξ                    W        ⎟
#                                                             ⎠
#
#       ⎛            2    4                  2                            4    2
#       ⎜  2⋅ⅈ⋅Δᵣ⋅Ω⋅a ⋅sin (θ)   2⋅ⅈ⋅Δᵣ⋅a⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅Ω⋅\tilde{r} ⋅sin
# \phi}⋅⎜- ─────────────────── + ──────────────── + ────────────────────────────
#       ⎜             2                W⋅Ξ                           2
#       ⎝          W⋅Ξ                                            W⋅Ξ
#
#                             2  2    2                    4    2
# (θ)   4⋅ⅈ⋅Δₜₕₑₜₐ⋅Ω⋅\tilde{r} ⋅a ⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅Ω⋅a ⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜ
# ─── + ────────────────────────────────── + ─────────────────────── - ─────────
#                         2                               2
#                      W⋅Ξ                             W⋅Ξ
#
#            2      2                  3    2   ⎞                  ⎛      2    4
# ₐ⋅\tilde{r} ⋅a⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟                2 ⎜  Δᵣ⋅a ⋅sin
# ────────────────────── - ─────────────────────⎟ + d\tilde{\phi} ⋅⎜- ──────────
#      W⋅Ξ                          W⋅Ξ         ⎟                  ⎜          2
#                                               ⎠                  ⎝       W⋅Ξ
#
#                       4    2                        2  2    2              4
# (θ)   Δₜₕₑₜₐ⋅\tilde{r} ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅a ⋅s
# ─── + ───────────────────────── + ────────────────────────────── + ───────────
#                     2                             2                          2
#                  W⋅Ξ                           W⋅Ξ                        W⋅Ξ
#
#   2   ⎞
# in (θ)⎟
# ──────⎟
#       ⎟
#       ⎠

# %%
metric_list_matrix = [[0 for i in range(2)] for i in range(2)]
metric_list_matrix[0][0] = euclidean_metric_2.coeff(dtau ** 2)
metric_list_matrix[0][1] = euclidean_metric_2.coeff(dtau * dphi_tilde) / 2
metric_list_matrix[1][0] = metric_list_matrix[0][1]
metric_list_matrix[1][1] = euclidean_metric_2.coeff(dphi_tilde ** 2)

# %%
g_mat_2 = sympy.Matrix(metric_list_matrix)
g_mat_2.simplify()
g_mat_2
# Out:
# ⎡ 2 ⎛    2    2                      4                     2  2           4⎞
# ⎢Ω ⋅⎝Δᵣ⋅a ⋅sin (θ) - Δₜₕₑₜₐ⋅\tilde{r}  - 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  - Δₜₕₑₜₐ⋅a ⎠⋅s
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢                     ⎛  ⎛      2    2                      4
# ⎢                   ⅈ⋅⎝Ω⋅⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\tilde{r}  + 2⋅Δₜₕₑₜₐ⋅\tild
# ⎢                   ──────────────────────────────────────────────────────────
# ⎢
# ⎣
#
#   2              ⎛                      2           2⎞    2       2 ⎛
# in (θ) + 2⋅Ω⋅Ξ⋅a⋅⎝-Δᵣ + Δₜₕₑₜₐ⋅\tilde{r}  + Δₜₕₑₜₐ⋅a ⎠⋅sin (θ) + Ξ ⋅⎝Δᵣ - Δₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#          2
#       W⋅Ξ
#
#     2  2           4⎞       ⎛                     2           2⎞⎞    2
# e{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠ + Ξ⋅a⋅⎝Δᵣ - Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⎠⋅sin (θ)
# ─────────────────────────────────────────────────────────────────────────
#          2
#       W⋅Ξ
#
#     2    2   ⎞    ⎛  ⎛      2    2                      4
# ₜₐ⋅a ⋅sin (θ)⎠  ⅈ⋅⎝Ω⋅⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\tilde{r}  + 2⋅Δₜₕₑₜₐ⋅\tilde{r}
# ──────────────  ──────────────────────────────────────────────────────────────
#
#
#
#                                         ⎛      2    2                      4
#                                         ⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\tilde{r}  +
#                                         ──────────────────────────────────────
#
#
#
# 2  2           4⎞       ⎛                     2           2⎞⎞    2   ⎤
#  ⋅a  + Δₜₕₑₜₐ⋅a ⎠ + Ξ⋅a⋅⎝Δᵣ - Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⎠⋅sin (θ)⎥
# ─────────────────────────────────────────────────────────────────────⎥
#      2                                                               ⎥
#   W⋅Ξ                                                                ⎥
#                                                                      ⎥
#                    2  2           4⎞    2                            ⎥
#  2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠⋅sin (θ)                         ⎥
# ────────────────────────────────────────────                         ⎥
#     2                                                                ⎥
#  W⋅Ξ                                                                 ⎦

# %%
g_mat_2.det().simplify()
# Out:
#                                    2
#           ⎛         2    2    2   ⎞     2
# Δᵣ⋅Δₜₕₑₜₐ⋅⎝\tilde{r}  + a ⋅cos (θ)⎠ ⋅sin (θ)
# ────────────────────────────────────────────
#                     2  2
#                    W ⋅Ξ

# %% [markdown]
# ##### $g_{00}$

# %%
g_00 = delta_r * (xi - a * omega * sympy.sin(theta) ** 2) ** 2 - delta_theta * (a * xi - omega * (r_tilde ** 2 + a ** 2)) ** 2 * sympy.sin(theta) ** 2
g_00
# Out:
#                       2                                       2
#    ⎛         2       ⎞           ⎛    ⎛         2    2⎞      ⎞     2
# Δᵣ⋅⎝- Ω⋅a⋅sin (θ) + Ξ⎠  - Δₜₕₑₜₐ⋅⎝- Ω⋅⎝\tilde{r}  + a ⎠ + Ξ⋅a⎠ ⋅sin (θ)

# %%
(g_00 / (W * xi ** 2) - g_mat_2[0, 0]).expand().simplify()
# Out:
# 0

# %%
g_00_simp = g_00.subs({delta_r: delta_r_val, xi: xi_val, delta_theta: delta_theta_val}).subs({a: a_val})
g_00_simp = g_00_simp.expand().collect([r_tilde, r_tilde ** 2, r_tilde ** 3, r_tilde ** 4])
g_00_simp
# Out:
#  2           12    2       2       2           10    4         2           8
# Ω ⋅\tilde{r}₊  ⋅sin (θ)⋅cos (θ) + Ω ⋅\tilde{r}₊  ⋅sin (θ) + 3⋅Ω ⋅\tilde{r}₊ ⋅s
#
#   4       2           8    2       2           6    4                    14
# in (θ) - Ω ⋅\tilde{r}₊ ⋅sin (θ) + Ω ⋅\tilde{r}₊ ⋅sin (θ) + 2⋅Ω⋅\tilde{r}₊  ⋅si
#
#  2       2                    12    2                    10    2       2
# n (θ)⋅cos (θ) + 2⋅Ω⋅\tilde{r}₊  ⋅sin (θ) - 2⋅Ω⋅\tilde{r}₊  ⋅sin (θ)⋅cos (θ) +
#
#               10    2                    6    2                    4    2
# 4⋅Ω⋅\tilde{r}₊  ⋅sin (θ) - 4⋅Ω⋅\tilde{r}₊ ⋅sin (θ) - 2⋅Ω⋅\tilde{r}₊ ⋅sin (θ) +
#
#           4 ⎛ 2           4    4       2           4    2       2       2    2
#  \tilde{r} ⋅⎝Ω ⋅\tilde{r}₊ ⋅sin (θ) + Ω ⋅\tilde{r}₊ ⋅sin (θ)⋅cos (θ) - Ω ⋅sin
#
#                     6    2                    2    2                8
# (θ) + 2⋅Ω⋅\tilde{r}₊ ⋅sin (θ) - 2⋅Ω⋅\tilde{r}₊ ⋅sin (θ) + \tilde{r}₊  - 2⋅\til
#
#       4    ⎞            2 ⎛ 2           8    4         2           8    2
# de{r}₊  + 1⎠ + \tilde{r} ⋅⎝Ω ⋅\tilde{r}₊ ⋅sin (θ) + 2⋅Ω ⋅\tilde{r}₊ ⋅sin (θ)⋅c
#
#   2       2           4    4         2           4    2                    10
# os (θ) + Ω ⋅\tilde{r}₊ ⋅sin (θ) - 2⋅Ω ⋅\tilde{r}₊ ⋅sin (θ) + 2⋅Ω⋅\tilde{r}₊  ⋅
#
#    2       2                    10    2                    6    2       2
# sin (θ)⋅cos (θ) + 2⋅Ω⋅\tilde{r}₊  ⋅sin (θ) - 2⋅Ω⋅\tilde{r}₊ ⋅sin (θ)⋅cos (θ) -
#
#                6    2                12             8             4    ⎞
#  2⋅Ω⋅\tilde{r}₊ ⋅sin (θ) + \tilde{r}₊   - \tilde{r}₊  - \tilde{r}₊  + 1⎠ + \ti
#
#        ⎛     2           9    4         2           7    4         2
# lde{r}⋅⎝- 2⋅Ω ⋅\tilde{r}₊ ⋅sin (θ) - 4⋅Ω ⋅\tilde{r}₊ ⋅sin (θ) - 2⋅Ω ⋅\tilde{r}
#
#  5    4                    11    2                    9    2
# ₊ ⋅sin (θ) - 4⋅Ω⋅\tilde{r}₊  ⋅sin (θ) - 8⋅Ω⋅\tilde{r}₊ ⋅sin (θ) + 8⋅Ω⋅\tilde{r
#
#   5    2                    3    2                  13               11
# }₊ ⋅sin (θ) + 4⋅Ω⋅\tilde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊   - 4⋅\tilde{r}₊   + 2⋅\t
#
#         9               7               5               3               ⎞
# ilde{r}₊  + 8⋅\tilde{r}₊  + 2⋅\tilde{r}₊  - 4⋅\tilde{r}₊  - 2⋅\tilde{r}₊⎠ + \t
#
#         16    2       2                14               12    2       2
# ilde{r}₊  ⋅sin (θ)⋅cos (θ) + \tilde{r}₊   - 2⋅\tilde{r}₊  ⋅sin (θ)⋅cos (θ) - \
#
#          12    2                  12             10             8    2       2
# tilde{r}₊  ⋅sin (θ) + 3⋅\tilde{r}₊   - \tilde{r}₊   + \tilde{r}₊ ⋅sin (θ)⋅cos
#
#                   8    2                  8             6             4    2
# (θ) + 2⋅\tilde{r}₊ ⋅sin (θ) - 6⋅\tilde{r}₊  - \tilde{r}₊  - \tilde{r}₊ ⋅sin (θ
#
#                 4             2
# ) + 3⋅\tilde{r}₊  + \tilde{r}₊

# %%
A_coeff_00 = g_00_simp.coeff(r_tilde).simplify()
A_coeff_00.factor()
# Out:
#                                2                                          2
#               ⎛          2    ⎞  ⎛            2    2                4    ⎞
# -2⋅\tilde{r}₊⋅⎝\tilde{r}₊  + 1⎠ ⋅⎝Ω⋅\tilde{r}₊ ⋅sin (θ) + \tilde{r}₊  - 1⎠

# %%
B_coeff_00 = g_00_simp.coeff(r_tilde ** 2).simplify().factor()
B_coeff_00
# Out:
#                                    ⎛          2    ⎞ ⎛ 2           4    4
# -(\tilde{r}₊ - 1)⋅(\tilde{r}₊ + 1)⋅⎝\tilde{r}₊  + 1⎠⋅⎝Ω ⋅\tilde{r}₊ ⋅sin (θ) -
#
#     2           4    2                    6    4                    6    2
#  2⋅Ω ⋅\tilde{r}₊ ⋅sin (θ) + 2⋅Ω⋅\tilde{r}₊ ⋅sin (θ) - 4⋅Ω⋅\tilde{r}₊ ⋅sin (θ)
#
#             8    ⎞
# - \tilde{r}₊  + 1⎠

# %%
C_coeff_00 = g_00_simp.coeff(r_tilde ** 4).simplify().factor()
C_coeff_00
# Out:
#                                   ⎛          2    ⎞ ⎛ 2    2
# (\tilde{r}₊ - 1)⋅(\tilde{r}₊ + 1)⋅⎝\tilde{r}₊  + 1⎠⋅⎝Ω ⋅sin (θ) + 2⋅Ω⋅\tilde{r
#
#   2    2                4    ⎞
# }₊ ⋅sin (θ) + \tilde{r}₊  - 1⎠

# %%
D_coeff_00 = g_00_simp - A_coeff_00 * r_tilde - B_coeff_00 * r_tilde ** 2 - C_coeff_00 * r_tilde ** 4
D_coeff_00.simplify().factor()
# Out:
#            2 ⎛          2    ⎞ ⎛ 2           8    4       2           8    2
# -\tilde{r}₊ ⋅⎝\tilde{r}₊  + 1⎠⋅⎝Ω ⋅\tilde{r}₊ ⋅sin (θ) - Ω ⋅\tilde{r}₊ ⋅sin (θ
#
#        2           6    4       2           6    2       2           4    4
# ) - 2⋅Ω ⋅\tilde{r}₊ ⋅sin (θ) + Ω ⋅\tilde{r}₊ ⋅sin (θ) - Ω ⋅\tilde{r}₊ ⋅sin (θ)
#
#                  10    4                    10    2                    8    4
#  + 2⋅Ω⋅\tilde{r}₊  ⋅sin (θ) - 2⋅Ω⋅\tilde{r}₊  ⋅sin (θ) - 2⋅Ω⋅\tilde{r}₊ ⋅sin (
#
#                    6    2                    4    2                    2    2
# θ) - 2⋅Ω⋅\tilde{r}₊ ⋅sin (θ) + 2⋅Ω⋅\tilde{r}₊ ⋅sin (θ) + 2⋅Ω⋅\tilde{r}₊ ⋅sin (
#
#                12    4                12    2                10    4
# θ) + \tilde{r}₊  ⋅sin (θ) - \tilde{r}₊  ⋅sin (θ) - \tilde{r}₊  ⋅sin (θ) + \til
#
#       10    2                10             8    4                  8    2
# de{r}₊  ⋅sin (θ) - \tilde{r}₊   - \tilde{r}₊ ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅sin (θ)
#
#               8             6    4                  6    2                  6
# - 2⋅\tilde{r}₊  + \tilde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅sin (θ) + 3⋅\tilde{r}₊
#
#             4    2                  4             2    2                  2
# - \tilde{r}₊ ⋅sin (θ) + 3⋅\tilde{r}₊  + \tilde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊  -
#
#  ⎞
# 1⎠

# %% [markdown]
# ##### $g_{11}$

# %% [markdown]
# This component remains unchanged.

# %% [markdown]
# #### Wick Rotation + Omega Shift + Non-rotating Frame

# %%
dphi_prime = sympy.symbols("d\phi'")
dphi_tilde_val = dphi_prime - a * dt_val
dphi_tilde_val
# Out:
# -ⅈ⋅a⋅d\tau + d\phi'

# %%
euclidean_metric_3 = euclidean_metric_2.subs({dphi_tilde: dphi_tilde_val}).expand().collect([dtau ** 2, dtau * dphi_prime, dphi_prime ** 2])
euclidean_metric_3
# Out:
#         ⎛      2    4                      4    2                        2  2
#       2 ⎜  Δᵣ⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅\tilde{r} ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a ⋅
# d\phi' ⋅⎜- ───────────── + ───────────────────────── + ───────────────────────
#         ⎜          2                     2                             2
#         ⎝       W⋅Ξ                   W⋅Ξ                           W⋅Ξ
#
#    2              4    2   ⎞                ⎛            2    4
# sin (θ)   Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟                ⎜  2⋅ⅈ⋅Δᵣ⋅Ω⋅a ⋅sin (θ)   2⋅ⅈ⋅Δᵣ⋅a⋅
# ─────── + ─────────────────⎟ + d\phi'⋅d\tau⋅⎜- ─────────────────── + ─────────
#                     2      ⎟                ⎜             2                W⋅Ξ
#                  W⋅Ξ       ⎠                ⎝          W⋅Ξ
#
#    2              3    4                            4    2
# sin (θ)   2⋅ⅈ⋅Δᵣ⋅a ⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅Ω⋅\tilde{r} ⋅sin (θ)   4⋅ⅈ⋅Δₜₕₑₜₐ⋅Ω⋅\
# ─────── + ───────────────── + ─────────────────────────────── + ──────────────
#                     2                          2
#                  W⋅Ξ                        W⋅Ξ
#
#         2  2    2                    4    2                          2      2
# tilde{r} ⋅a ⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅Ω⋅a ⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a⋅sin (
# ──────────────────── + ─────────────────────── - ─────────────────────────────
#     2                               2                          W⋅Ξ
#  W⋅Ξ                             W⋅Ξ
#
#                  3    2                          4      2
# θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅a ⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a⋅sin (θ)   4⋅ⅈ⋅Δₜₕₑₜₐ⋅\til
# ── - ───────────────────── - ─────────────────────────────── - ───────────────
#               W⋅Ξ                             2
#                                            W⋅Ξ                               W
#
#      2  3    2                  5    2   ⎞          ⎛    2  2    4
# de{r} ⋅a ⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟        2 ⎜Δᵣ⋅Ω ⋅a ⋅sin (θ)   2⋅Δᵣ⋅Ω
# ───────────────── - ─────────────────────⎟ + d\tau ⋅⎜──────────────── - ──────
#   2                             2        ⎟          ⎜         2
# ⋅Ξ                           W⋅Ξ         ⎠          ⎝      W⋅Ξ
#
#       2              3    4                 2    2          4    4
# ⋅a⋅sin (θ)   2⋅Δᵣ⋅Ω⋅a ⋅sin (θ)   Δᵣ   2⋅Δᵣ⋅a ⋅sin (θ)   Δᵣ⋅a ⋅sin (θ)   Δₜₕₑₜₐ
# ────────── - ───────────────── + ── + ─────────────── + ───────────── - ──────
# W⋅Ξ                    2         W          W⋅Ξ                 2
#                     W⋅Ξ                                      W⋅Ξ
#
#   2          4    2                2          2  2    2              2  4    2
# ⋅Ω ⋅\tilde{r} ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅Ω ⋅\tilde{r} ⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅Ω ⋅a ⋅sin
# ────────────────────── - ───────────────────────────────── - ─────────────────
#          2                                 2                            2
#       W⋅Ξ                               W⋅Ξ                          W⋅Ξ
#
#                           2      2                  3    2
# (θ)   2⋅Δₜₕₑₜₐ⋅Ω⋅\tilde{r} ⋅a⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅Ω⋅a ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅Ω⋅\ti
# ─── + ─────────────────────────────── + ───────────────────── + ──────────────
#                     W⋅Ξ                          W⋅Ξ
#
#
#       4      2                          2  3    2                  5    2
# lde{r} ⋅a⋅sin (θ)   4⋅Δₜₕₑₜₐ⋅Ω⋅\tilde{r} ⋅a ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅Ω⋅a ⋅sin (θ)
# ───────────────── + ──────────────────────────────── + ───────────────────── -
#    2                                 2                             2
# W⋅Ξ                               W⋅Ξ                           W⋅Ξ
#
#          2    2                        2  2    2                4    2
#  Δₜₕₑₜₐ⋅a ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅a ⋅sin (θ)   Δₜ
#  ───────────────── - ────────────────────────────── - ─────────────────── - ──
#          W                        W⋅Ξ                         W⋅Ξ
#
#
#               4  2    2                        2  4    2              6    2
# ₕₑₜₐ⋅\tilde{r} ⋅a ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅a ⋅sin (θ
# ────────────────────────── - ────────────────────────────── - ────────────────
#              2                               2                          2
#           W⋅Ξ                             W⋅Ξ                        W⋅Ξ
#
#  ⎞
# )⎟
# ─⎟
#  ⎟
#  ⎠

# %%
metric_list_matrix = [[0 for i in range(2)] for i in range(2)]
metric_list_matrix[0][0] = euclidean_metric_3.coeff(dtau ** 2)
metric_list_matrix[0][1] = euclidean_metric_3.coeff(dtau * dphi_prime) / 2
metric_list_matrix[1][0] = metric_list_matrix[0][1]
metric_list_matrix[1][1] = euclidean_metric_3.coeff(dphi_prime ** 2)

# %%
g_mat_3 = sympy.Matrix(metric_list_matrix)
g_mat_3.simplify()
g_mat_3
# Out:
# ⎡ 2 ⎛             2    2   ⎞         ⎛                                 2
# ⎢Ξ ⋅⎝Δᵣ - Δₜₕₑₜₐ⋅a ⋅sin (θ)⎠ + 2⋅Ξ⋅a⋅⎝-Δᵣ⋅Ω + Δᵣ⋅a + Δₜₕₑₜₐ⋅Ω⋅\tilde{r}  + Δₜₕ
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢       ⎛        2    2          3    2                        4
# ⎢     ⅈ⋅⎝- Δᵣ⋅Ω⋅a ⋅sin (θ) + Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅Ω⋅\tilde{r}  + 2⋅Δₜₕₑₜₐ⋅Ω⋅
# ⎢     ────────────────────────────────────────────────────────────────────────
# ⎢
# ⎣
#
#        2                   2             3⎞    2              2 ⎛    2    2
# ₑₜₐ⋅Ω⋅a  - Δₜₕₑₜₐ⋅\tilde{r} ⋅a - Δₜₕₑₜₐ⋅a ⎠⋅sin (θ) + (-Ω + a) ⋅⎝Δᵣ⋅a ⋅sin (θ)
# ──────────────────────────────────────────────────────────────────────────────
#                                    2
#                                 W⋅Ξ
#
#          2  2             4                   4                       2  3
# \tilde{r} ⋅a  + Δₜₕₑₜₐ⋅Ω⋅a  - Δₜₕₑₜₐ⋅\tilde{r} ⋅a - 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  - Δ
# ──────────────────────────────────────────────────────────────────────────────
#                                   2
#                                W⋅Ξ
#
#                    4                     2  2           4⎞    2       ⎛
#  - Δₜₕₑₜₐ⋅\tilde{r}  - 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  - Δₜₕₑₜₐ⋅a ⎠⋅sin (θ)  ⅈ⋅⎝- Δᵣ⋅Ω⋅
# ──────────────────────────────────────────────────────────────────  ──────────
#
#
#
#        5       ⎛                     2           2⎞⎞    2
# ₜₕₑₜₐ⋅a  + Ξ⋅a⋅⎝Δᵣ - Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⎠⋅sin (θ)
# ────────────────────────────────────────────────────────────
#
#
#
#  2    2          3    2                        4                       2  2
# a ⋅sin (θ) + Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅Ω⋅\tilde{r}  + 2⋅Δₜₕₑₜₐ⋅Ω⋅\tilde{r} ⋅a  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                       ⎛      2    2
#                                                       ⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜ
#                                                       ────────────────────────
#
#
#
#           4                   4                       2  3           5       ⎛
# Δₜₕₑₜₐ⋅Ω⋅a  - Δₜₕₑₜₐ⋅\tilde{r} ⋅a - 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  - Δₜₕₑₜₐ⋅a  + Ξ⋅a⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#                   2
#                W⋅Ξ
#
#            4                     2  2           4⎞    2
# ₐ⋅\tilde{r}  + 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠⋅sin (θ)
# ──────────────────────────────────────────────────────────
#                   2
#                W⋅Ξ
#
#                      2           2⎞⎞    2   ⎤
# Δᵣ - Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⎠⋅sin (θ)⎥
# ────────────────────────────────────────────⎥
#                                             ⎥
#                                             ⎥
#                                             ⎥
#                                             ⎥
#                                             ⎥
#                                             ⎥
#                                             ⎥
#                                             ⎦

# %%
g_mat_3.det().simplify()
# Out:
#                                    2
#           ⎛         2    2    2   ⎞     2
# Δᵣ⋅Δₜₕₑₜₐ⋅⎝\tilde{r}  + a ⋅cos (θ)⎠ ⋅sin (θ)
# ────────────────────────────────────────────
#                     2  2
#                    W ⋅Ξ

# %% [markdown]
# ##### $g_{00}$

# %%
g_00 = delta_r * (xi + a * (a - omega) * sympy.sin(theta) ** 2) ** 2 - delta_theta * sympy.sin(theta) ** 2 * (a * xi + (a - omega) * (r_tilde ** 2 + a ** 2)) ** 2
g_00
# Out:
#                            2                                            2
#    ⎛                  2   ⎞           ⎛               ⎛         2    2⎞⎞     2
# Δᵣ⋅⎝Ξ + a⋅(-Ω + a)⋅sin (θ)⎠  - Δₜₕₑₜₐ⋅⎝Ξ⋅a + (-Ω + a)⋅⎝\tilde{r}  + a ⎠⎠ ⋅sin
#
#
#
# (θ)

# %%
(g_00 / (W * xi ** 2) - g_mat_3[0, 0]).expand().simplify()
# Out:
# 0

# %%
g_00 = g_00.subs({omega: 1})
g_00
# Out:
#                           2                                           2
#    ⎛                 2   ⎞           ⎛      ⎛         2    2⎞        ⎞     2
# Δᵣ⋅⎝Ξ + a⋅(a - 1)⋅sin (θ)⎠  - Δₜₕₑₜₐ⋅⎝Ξ⋅a + ⎝\tilde{r}  + a ⎠⋅(a - 1)⎠ ⋅sin (θ
#
#
#
# )

# %%
g_00_simp = g_00.subs({delta_r: delta_r_val, xi: xi_val, delta_theta: delta_theta_val}).subs({a: a_val})
g_00_simp = g_00_simp.expand().collect([r_tilde, r_tilde ** 2, r_tilde ** 3, r_tilde ** 4])
g_00_simp
# Out:
#          4 ⎛          8    4                8    2       2                  8
# \tilde{r} ⋅⎝\tilde{r}₊ ⋅sin (θ) + \tilde{r}₊ ⋅sin (θ)⋅cos (θ) - 2⋅\tilde{r}₊ ⋅
#
#    2                8               6    4                  6    2       2
# sin (θ) + \tilde{r}₊  - 2⋅\tilde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅sin (θ)⋅cos (θ)
#
#               6    2                4    4                4    2       2
# + 2⋅\tilde{r}₊ ⋅sin (θ) + \tilde{r}₊ ⋅sin (θ) + \tilde{r}₊ ⋅sin (θ)⋅cos (θ) +
#
#           4    2                  4      2       ⎞            2 ⎛          12
# \tilde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊  - sin (θ) + 1⎠ + \tilde{r} ⋅⎝\tilde{r}₊  ⋅
#
#    4                  12    2                12               10    4
# sin (θ) - 2⋅\tilde{r}₊  ⋅sin (θ) + \tilde{r}₊   - 2⋅\tilde{r}₊  ⋅sin (θ) - 2⋅\
#
#          10    2       2                  10    2                  8    4
# tilde{r}₊  ⋅sin (θ)⋅cos (θ) + 2⋅\tilde{r}₊  ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅sin (θ) +
#
#              8    2       2                8               6    4
#  4⋅\tilde{r}₊ ⋅sin (θ)⋅cos (θ) - \tilde{r}₊  - 2⋅\tilde{r}₊ ⋅sin (θ) - 2⋅\tild
#
#      6    2       2                  6    2                4    4
# e{r}₊ ⋅sin (θ)⋅cos (θ) + 2⋅\tilde{r}₊ ⋅sin (θ) + \tilde{r}₊ ⋅sin (θ) - 2⋅\tild
#
#      4    2                4    ⎞             ⎛              13    4
# e{r}₊ ⋅sin (θ) - \tilde{r}₊  + 1⎠ + \tilde{r}⋅⎝- 2⋅\tilde{r}₊  ⋅sin (θ) + 4⋅\t
#
#         13    2                  13               11    2                  11
# ilde{r}₊  ⋅sin (θ) - 2⋅\tilde{r}₊   + 4⋅\tilde{r}₊  ⋅sin (θ) - 4⋅\tilde{r}₊
#
#               9    4                  9    2                  9
# + 4⋅\tilde{r}₊ ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅sin (θ) + 2⋅\tilde{r}₊  - 8⋅\tilde{r}₊
#
# 7    2                  7               5    4                  5    2
#  ⋅sin (θ) + 8⋅\tilde{r}₊  - 2⋅\tilde{r}₊ ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅sin (θ) + 2⋅
#
#           5               3    2                  3               ⎞
# \tilde{r}₊  + 4⋅\tilde{r}₊ ⋅sin (θ) - 4⋅\tilde{r}₊  - 2⋅\tilde{r}₊⎠ + \tilde{r
#
#   14    4                  14    2                14             12    4
# }₊  ⋅sin (θ) - 2⋅\tilde{r}₊  ⋅sin (θ) + \tilde{r}₊   + \tilde{r}₊  ⋅sin (θ) +
#
#           12    2       2                  12    2                  12
# \tilde{r}₊  ⋅sin (θ)⋅cos (θ) - 4⋅\tilde{r}₊  ⋅sin (θ) + 3⋅\tilde{r}₊   - 4⋅\ti
#
#        10    4                  10    2       2                  10    2
# lde{r}₊  ⋅sin (θ) - 2⋅\tilde{r}₊  ⋅sin (θ)⋅cos (θ) + 6⋅\tilde{r}₊  ⋅sin (θ) -
#
#           10             8    4                8    2       2
# \tilde{r}₊   + \tilde{r}₊ ⋅sin (θ) + \tilde{r}₊ ⋅sin (θ)⋅cos (θ) + 5⋅\tilde{r}
#
#  8    2                  8             6    4                  6    2
# ₊ ⋅sin (θ) - 6⋅\tilde{r}₊  + \tilde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅sin (θ) - \ti
#
#        6               4    2                  4             2
# lde{r}₊  - 3⋅\tilde{r}₊ ⋅sin (θ) + 3⋅\tilde{r}₊  + \tilde{r}₊

# %%
A_coeff_00 = g_00_simp.coeff(r_tilde).simplify()
A_coeff_00
# Out:
#                                                                    2
#                               2                 2 ⎛          2    ⎞  ⎛
# -2⋅\tilde{r}₊⋅(\tilde{r}₊ - 1) ⋅(\tilde{r}₊ + 1) ⋅⎝\tilde{r}₊  + 1⎠ ⋅⎝\tilde{r
#
#                 2
#   2    2       ⎞
# }₊ ⋅cos (θ) + 1⎠

# %%
B_coeff_00 = g_00_simp.coeff(r_tilde ** 2).simplify().factor()
B_coeff_00
# Out:
#                                                      2
#                 2                 2 ⎛          2    ⎞  ⎛          4    4
# (\tilde{r}₊ - 1) ⋅(\tilde{r}₊ + 1) ⋅⎝\tilde{r}₊  + 1⎠ ⋅⎝\tilde{r}₊ ⋅sin (θ) -
#
#
#             4    2                4    ⎞
# 2⋅\tilde{r}₊ ⋅sin (θ) + \tilde{r}₊  + 1⎠

# %% [markdown]
# This is the same as:

# %%
B_coeff_00_2 = (r_tilde_plus - 1) ** 2 * (r_tilde_plus + 1) ** 2 * (r_tilde_plus ** 2 + 1) ** 2 * (r_tilde_plus ** 4 * sympy.cos(theta) ** 4 + 1)
B_coeff_00_2
# Out:
#                                                      2
#                 2                 2 ⎛          2    ⎞  ⎛          4    4
# (\tilde{r}₊ - 1) ⋅(\tilde{r}₊ + 1) ⋅⎝\tilde{r}₊  + 1⎠ ⋅⎝\tilde{r}₊ ⋅cos (θ) +
#
#
#  ⎞
# 1⎠

# %%
(B_coeff_00 - B_coeff_00_2).simplify()
# Out:
# 0

# %%
C_coeff_00 = g_00_simp.coeff(r_tilde ** 4).simplify().factor()
C_coeff_00
# Out:
#                                                      2
#                 2                 2 ⎛          2    ⎞     2
# (\tilde{r}₊ - 1) ⋅(\tilde{r}₊ + 1) ⋅⎝\tilde{r}₊  + 1⎠ ⋅cos (θ)

# %%
D_coeff_00 = g_00_simp - A_coeff_00 * r_tilde - B_coeff_00 * r_tilde ** 2 - C_coeff_00 * r_tilde ** 4
D_coeff_00.simplify()
# Out:
#                                                                  2 ⎛
#           2                 2                 2 ⎛          2    ⎞  ⎜
# \tilde{r}₊ ⋅(\tilde{r}₊ - 1) ⋅(\tilde{r}₊ + 1) ⋅⎝\tilde{r}₊  + 1⎠ ⋅⎝\tilde{r}₊
#
#                2
# 4 ⎛       2   ⎞                4    2                4               2    2
#  ⋅⎝1 - cos (θ)⎠  + 2⋅\tilde{r}₊ ⋅cos (θ) - \tilde{r}₊  + 3⋅\tilde{r}₊ ⋅cos (θ)
#
#     ⎞
#     ⎟
#  + 1⎠

# %% [markdown]
# This is the same as:

# %%
D_coeff_00_new = (r_tilde_plus - 1) ** 2 * (r_tilde_plus + 1) ** 2 * (r_tilde_plus ** 2 + 1) ** 2 * r_tilde_plus ** 2 * (r_tilde_plus ** 2 * sympy.cos(theta) ** 2 + (r_tilde_plus ** 2 * sympy.cos(theta) ** 2 + 1) ** 2)
D_coeff_00_new
# Out:
#                                                                  2 ⎛
#           2                 2                 2 ⎛          2    ⎞  ⎜
# \tilde{r}₊ ⋅(\tilde{r}₊ - 1) ⋅(\tilde{r}₊ + 1) ⋅⎝\tilde{r}₊  + 1⎠ ⋅⎝\tilde{r}₊
#
#                                      2⎞
# 2    2      ⎛          2    2       ⎞ ⎟
#  ⋅cos (θ) + ⎝\tilde{r}₊ ⋅cos (θ) + 1⎠ ⎠

# %%
(D_coeff_00 - D_coeff_00_new).simplify()
# Out:
# 0

# %% [markdown]
# ##### $g_{11}$

# %% [markdown]
# This component remains unchanged.

# %% [markdown]
# ### $m$ Complex

# %%
a_m, b_m = sympy.symbols("a_m b_m")

# %%
det_g_r = (a_m ** 2 - b_m ** 2) * sympy.sinh(2 * delta) ** 2 - 2 * r_tilde * a_m * sympy.cosh(2 * delta) + (r_tilde ** 2 + 1) * (r_tilde ** 2 + a ** 2)
det_g_r
# Out:
#                                  ⎛         2    ⎞ ⎛         2    2⎞   ⎛  2
# -2⋅\tilde{r}⋅aₘ⋅cosh(2⋅\delta) + ⎝\tilde{r}  + 1⎠⋅⎝\tilde{r}  + a ⎠ + ⎝aₘ  - b
#
#  2⎞     2
# ₘ ⎠⋅sinh (2⋅\delta)

# %%
det_g_i = 2 * b_m * (a_m * sympy.sinh(2 * delta) ** 2 - r_tilde * sympy.cosh(2 * delta))
det_g_i
# Out:
#      ⎛                                   2          ⎞
# 2⋅bₘ⋅⎝-\tilde{r}⋅cosh(2⋅\delta) + aₘ⋅sinh (2⋅\delta)⎠

# %%
a_m_val = r_tilde_plus * sympy.coth(2 * delta) / sympy.sinh(2 * delta)
a_m_val
# Out:
# \tilde{r}₊⋅coth(2⋅\delta)
# ─────────────────────────
#       sinh(2⋅\delta)

# %%
b_m_val = (r_tilde_plus ** 2 - sympy.coth(2 * delta) + 1) / sympy.sinh(2 * delta)
b_m_val
# Out:
#           2
# \tilde{r}₊  - coth(2⋅\delta) + 1
# ────────────────────────────────
#          sinh(2⋅\delta)

# %%
a_val = 2 / (sympy.exp(4 * delta) - 1)
a_val
# Out:
#       2
# ─────────────
#  4⋅\delta
# ℯ         - 1

# %% [markdown]
# #### $\text{Re} \det g$

# %%
det_g_r_subs = det_g_r.subs({a_m: a_m_val, b_m: b_m_val, a: a_val})
det_g_r_subs
# Out:
#
#
#   2⋅\tilde{r}⋅\tilde{r}₊⋅cosh(2⋅\delta)⋅coth(2⋅\delta)   ⎛         2    ⎞ ⎛
# - ──────────────────────────────────────────────────── + ⎝\tilde{r}  + 1⎠⋅⎜\ti
#                      sinh(2⋅\delta)                                       ⎜
#                                                                           ⎜
#                                                                           ⎝
#
#                               ⎛
#                               ⎜          2     2             ⎛          2
#       2          4        ⎞   ⎜\tilde{r}₊ ⋅coth (2⋅\delta)   ⎝\tilde{r}₊  - co
# lde{r}  + ────────────────⎟ + ⎜─────────────────────────── - ─────────────────
#                          2⎟   ⎜          2                                 2
#           ⎛ 4⋅\delta    ⎞ ⎟   ⎝      sinh (2⋅\delta)                   sinh (2
#           ⎝ℯ         - 1⎠ ⎠
#
#                  2⎞
#                 ⎞ ⎟
# th(2⋅\delta) + 1⎠ ⎟     2
# ──────────────────⎟⋅sinh (2⋅\delta)
#                   ⎟
# ⋅\delta)          ⎠

# %%
det_g_r_simplified = (sympy.exp(4 * delta) - 1) ** 2 * r_tilde ** 4 + ((sympy.exp(4 * delta) - 1) ** 2 + 4) * r_tilde ** 2
det_g_r_simplified += -2 * r_tilde_plus * (sympy.exp(4 * delta) + 1) ** 2 * r_tilde - (sympy.exp(4 * delta) - 1) ** 2 * r_tilde_plus ** 4
det_g_r_simplified += (sympy.exp(8 * delta) + 6 * sympy.exp(4 * delta) - 3) * r_tilde_plus ** 2
det_g_r_simplified
# Out:
#                           2              ⎛               2    ⎞
#          4 ⎛ 4⋅\delta    ⎞             2 ⎜⎛ 4⋅\delta    ⎞     ⎟
# \tilde{r} ⋅⎝ℯ         - 1⎠  + \tilde{r} ⋅⎝⎝ℯ         - 1⎠  + 4⎠ - 2⋅\tilde{r}⋅
#
#                           2                              2
#            ⎛ 4⋅\delta    ⎞              4 ⎛ 4⋅\delta    ⎞              2 ⎛ 8⋅\
# \tilde{r}₊⋅⎝ℯ         + 1⎠  - \tilde{r}₊ ⋅⎝ℯ         - 1⎠  + \tilde{r}₊ ⋅⎝ℯ
#
#
# delta      4⋅\delta    ⎞
#       + 6⋅ℯ         - 3⎠

# %%
det_g_r_simplified_2 = (sympy.exp(4 * delta) - 1) ** 2 * r_tilde ** 4 + 4 * (1 - sympy.exp(4 * delta)) * r_tilde ** 2
det_g_r_simplified_2 += -(sympy.exp(4 * delta) - 1) ** 2 * r_tilde_plus ** 4 + 4 * (sympy.exp(4 * delta) - 1) * r_tilde_plus ** 2
det_g_r_simplified_2 += (sympy.exp(4 * delta) + 1) ** 2 * (r_tilde_plus - r_tilde) ** 2
det_g_r_simplified_2
# Out:
#                           2
#          4 ⎛ 4⋅\delta    ⎞             2 ⎛       4⋅\delta⎞             4 ⎛ 4⋅\
# \tilde{r} ⋅⎝ℯ         - 1⎠  + \tilde{r} ⋅⎝4 - 4⋅ℯ        ⎠ - \tilde{r}₊ ⋅⎝ℯ
#
#           2
# delta    ⎞              2 ⎛   4⋅\delta    ⎞                            2 ⎛ 4⋅\
#       - 1⎠  + \tilde{r}₊ ⋅⎝4⋅ℯ         - 4⎠ + (-\tilde{r} + \tilde{r}₊) ⋅⎝ℯ
#
#           2
# delta    ⎞
#       + 1⎠

# %%
det_g_r_simplified_3 = r_tilde ** 4 - r_tilde_plus ** 4 + (r_tilde_plus - r_tilde) ** 2 * sympy.coth(2 * delta) ** 2
det_g_r_simplified_3 += 4 / (sympy.exp(4 * delta) - 1) * (r_tilde_plus ** 2 - r_tilde ** 2)
det_g_r_simplified_3
# Out:
#                                                                           ⎛
#          4             4                            2     2             4⋅⎝- \
# \tilde{r}  - \tilde{r}₊  + (-\tilde{r} + \tilde{r}₊) ⋅coth (2⋅\delta) + ──────
#
#
#
#         2             2⎞
# tilde{r}  + \tilde{r}₊ ⎠
# ────────────────────────
#    4⋅\delta
#   ℯ         - 1

# %%
det_g_r_simplified_3
# Out:
#                                                                           ⎛
#          4             4                            2     2             4⋅⎝- \
# \tilde{r}  - \tilde{r}₊  + (-\tilde{r} + \tilde{r}₊) ⋅coth (2⋅\delta) + ──────
#
#
#
#         2             2⎞
# tilde{r}  + \tilde{r}₊ ⎠
# ────────────────────────
#    4⋅\delta
#   ℯ         - 1

# %%
det_g_r_final = r_tilde ** 4 - r_tilde_plus ** 4 + (r_tilde_plus - r_tilde) ** 2 * (a + 1) ** 2 + 2 * a * (r_tilde_plus ** 2 - r_tilde ** 2)
det_g_r_final
# Out:
#          4             4       ⎛           2             2⎞
# \tilde{r}  - \tilde{r}₊  + 2⋅a⋅⎝- \tilde{r}  + \tilde{r}₊ ⎠ + (-\tilde{r} + \t
#
#          2        2
# ilde{r}₊) ⋅(a + 1)

# %%
sol = sympy.solve(det_g_r_final, r_tilde)

# %%
roots = {}

a_val = 0.5
r_tilde_plus_vals = range(1, 21)

for r_tilde_plus_val in r_tilde_plus_vals:
    root_vals = []
    for i in range(4):
        root = sol[i].subs({a: a_val, r_tilde_plus: r_tilde_plus_val}).evalf()
        root_vals.append(root)
    roots[r_tilde_plus_val] = root_vals

# %%
a_val = -2
r_tilde_plus_val = 0

det_g_r_vals = []

for r_tilde_val_ex in range(r_tilde_plus_val, r_tilde_plus_val + 1000):
    det_g_r_vals.append(det_g_r_final.subs({a: a_val, r_tilde_plus: r_tilde_plus_val, r_tilde: r_tilde_val_ex}).evalf())

# %%
det_g_r_final_2 = (r_tilde ** 2 + r_tilde_plus ** 2 - 2 * a) * (r_tilde + r_tilde_plus) + (r_tilde - r_tilde_plus) * (a + 1) ** 2
det_g_r_final_2
# Out:
#                                 2                            ⎛         2
# (\tilde{r} - \tilde{r}₊)⋅(a + 1)  + (\tilde{r} + \tilde{r}₊)⋅⎝\tilde{r}  + \ti
#
#        2      ⎞
# lde{r}₊  - 2⋅a⎠

# %%
D, E, C = sympy.symbols("D E C")
D_val = 2 * r_tilde_plus ** 2 + 3 * (a ** 2 + 1)
E_val = 2 * r_tilde_plus * (5 * r_tilde_plus ** 2 - 9 * (a ** 2 + 3 * a + 1))
C_val = E + sympy.sqrt(E ** 2 + D ** 3)

# %%
root_1 = -(r_tilde_plus + sympy.cbrt(C) - D / sympy.cbrt(C)) / 3
root_1
# Out:
#   3 ___
#   ╲╱ C    \tilde{r}₊      D
# - ───── - ────────── + ───────
#     3         3          3 ___
#                        3⋅╲╱ C

# %%
root_2 = -(r_tilde_plus - sympy.cbrt(C) * (1 + sympy.sqrt(3) * sympy.I) / 2 + (1 - sympy.sqrt(3) * sympy.I) * D / (2 * sympy.cbrt(C))) / 3
root_2
# Out:
# 3 ___
# ╲╱ C ⋅(1 + √3⋅ⅈ)   \tilde{r}₊   D⋅(1 - √3⋅ⅈ)
# ──────────────── - ────────── - ────────────
#        6               3            3 ___
#                                   6⋅╲╱ C

# %%
root_3 = -(r_tilde_plus - sympy.cbrt(C) * (1 - sympy.sqrt(3) * sympy.I) / 2 + (1 + sympy.sqrt(3) * sympy.I) * D / (2 * sympy.cbrt(C))) / 3
root_3
# Out:
# 3 ___
# ╲╱ C ⋅(1 - √3⋅ⅈ)   \tilde{r}₊   D⋅(1 + √3⋅ⅈ)
# ──────────────── - ────────── - ────────────
#        6               3            3 ___
#                                   6⋅╲╱ C

# %%
det_g_r_final.subs({r_tilde: root_1}).subs({D: D_val, C: C_val}).subs({E: E_val}).simplify()
# Out:
# 0

# %%
det_g_r_final.subs({r_tilde: root_2}).subs({D: D_val, C: C_val}).subs({E: E_val}).simplify()
# Out:
# 0

# %%
det_g_r_final.subs({r_tilde: root_3}).subs({D: D_val, C: C_val}).subs({E: E_val}).simplify()
# Out:
# 0

# %% [markdown]
# When $b_m = 0$, you get the roots you expect:

# %%
root_1.subs({D: D_val, C: C_val}).subs({E: E_val}).subs({a: r_tilde_plus ** 2}).subs({r_tilde_plus: 9}).evalf()
# Out:
# 9.00000000000000

# %%
root_2.subs({D: D_val, C: C_val}).subs({E: E_val}).subs({a: r_tilde_plus ** 2}).subs({r_tilde_plus: 9}).evalf()
# Out:
# -9.0 + 82.0⋅ⅈ

# %%
root_3.subs({D: D_val, C: C_val}).subs({E: E_val}).subs({a: r_tilde_plus ** 2}).subs({r_tilde_plus: 9}).evalf()
# Out:
# -9.0 - 82.0⋅ⅈ

# %% [markdown]
# The condition that $\tilde{r}_+$ is the larger real root is that this is larger than zero:

# %%
cond = 4 * r_tilde_plus * sympy.cbrt(C) + sympy.cbrt(C ** 2) - D
cond
# Out:
#                             ____
#   3 ___                  3 ╱  2
# 4⋅╲╱ C ⋅\tilde{r}₊ - D + ╲╱  C

# %%
cond2 = cond.subs({D: D_val, C: C_val}).subs({E: E_val})
cond2
# Out:
#
#                                     __________________________________________
#                                    ╱
#                                   ╱
#               2                3 ╱                ⎛            2      2
# - 2⋅\tilde{r}₊  + 4⋅\tilde{r}₊⋅╲╱    2⋅\tilde{r}₊⋅⎝5⋅\tilde{r}₊  - 9⋅a  - 27⋅a
#
#
# ______________________________________________________________________________
#             __________________________________________________________________
#            ╱                                                2
#     ⎞     ╱              2 ⎛            2      2           ⎞    ⎛            2
#  - 9⎠ + ╲╱   4⋅\tilde{r}₊ ⋅⎝5⋅\tilde{r}₊  - 9⋅a  - 27⋅a - 9⎠  + ⎝2⋅\tilde{r}₊
#
#                                _______________________________________________
# _______________               ╱
# ______________               ╱  ⎛
#             3               ╱   ⎜
#       2    ⎞         2   3 ╱    ⎜             ⎛            2      2
#  + 3⋅a  + 3⎠    - 3⋅a  + ╲╱     ⎝2⋅\tilde{r}₊⋅⎝5⋅\tilde{r}₊  - 9⋅a  - 27⋅a - 9
#
# ______________________________________________________________________________
#
#         ______________________________________________________________________
#        ╱                                                2
# ⎞     ╱              2 ⎛            2      2           ⎞    ⎛            2
# ⎠ + ╲╱   4⋅\tilde{r}₊ ⋅⎝5⋅\tilde{r}₊  - 9⋅a  - 27⋅a - 9⎠  + ⎝2⋅\tilde{r}₊  + 3
#
# _____________
#            2
# __________⎞
#         3 ⎟
#   2    ⎞  ⎟
# ⋅a  + 3⎠  ⎠   - 3

# %%
a_vals = np.arange(0, 1.005, 0.005)
r_tilde_plus_vals = np.arange(-1, 1.01, 0.01)

X, Y = np.meshgrid(a_vals, r_tilde_plus_vals)

cond_vals = np.zeros(X.shape)

for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        cond_vals[i, j] = cond2.subs({a: X[i, j], r_tilde_plus: Y[i, j]}).evalf()

# %%
plt.contourf(X, Y, cond_vals > 0, cmap='Set2')
plt.plot([0, 1], [0, 0], 'k-')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.savefig('figures/real_delta_r_sign_parameter_space.pdf', bbox_inches='tight', dpi=300);

# %% [markdown]
# Spotcheck a case where the condition is violated.

# %%
r_tilde_plus_val = 0.2
a_val = 0.8

# %% [markdown]
# The condition is negative and the other real root is greater than $\tilde{r}_+$, as expected.

# %%
cond2.subs({a: a_val, r_tilde_plus: r_tilde_plus_val})
# Out:
# -1.30717913258332

# %%
root_1_val = root_1.subs({C: C_val, D: D_val}).subs({E: E_val}).subs({a: a_val, r_tilde_plus: r_tilde_plus_val})
root_1_val
# Out:
# 0.478800578340083

# %%
det_g_final_vals = []

r_tilde_vals = np.arange(-10, 10, 0.01)

for r_tilde_val in r_tilde_vals:
    det_g_final_vals.append(det_g_r_final.subs({r_tilde_plus: r_tilde_plus_val, a: a_val, r_tilde: r_tilde_val}))

# %%
plt.plot(r_tilde_vals, det_g_final_vals, lw=2)
plt.plot([root_1_val, r_tilde_plus_val], [0, 0], 'rx')
plt.xlim([0, 0.7])
plt.ylim([-0.1, 0.2])
plt.xlabel('$\\tilde{r}$')
plt.ylabel('$z_r$')
plt.grid()
plt.savefig('figures/real_delta_r_versus_tilde_r_not_allowable.pdf', bbox_inches='tight', dpi=300);

# %% [markdown]
# Spotcheck a case where the condition is satisfied.

# %%
r_tilde_plus_val = 1
a_val = 0.8

# %%
cond2.subs({a: a_val, r_tilde_plus: r_tilde_plus_val})
# Out:
# 0.457134250464740

# %%
root_1_val = root_1.subs({C: C_val, D: D_val}).subs({E: E_val}).subs({a: a_val, r_tilde_plus: r_tilde_plus_val})
root_1_val
# Out:
# 0.889018210407677

# %%
det_g_final_vals = []

r_tilde_vals = np.arange(-10, 10, 0.01)

for r_tilde_val in r_tilde_vals:
    det_g_final_vals.append(det_g_r_final.subs({r_tilde_plus: r_tilde_plus_val, a: a_val, r_tilde: r_tilde_val}))

# %%
plt.plot(r_tilde_vals, det_g_final_vals, lw=2)
plt.plot([root_1_val, r_tilde_plus_val], [0, 0], 'rx')
plt.xlim([0.7, 1.2])
plt.ylim([-0.1, 0.2])
plt.xlabel('$\\tilde{r}$')
plt.ylabel('$z_r$')
plt.grid()
plt.savefig('figures/real_delta_r_versus_tilde_r_allowable.pdf', bbox_inches='tight', dpi=300);

# %% [markdown]
# ### $g_{\tau\tau}$

# %%
g_tt = delta_r * (xi - a * omega * sympy.sin(theta) ** 2) ** 2 - delta_theta * (a * xi - omega * (r_tilde ** 2 + a ** 2)) ** 2 * sympy.sin(theta) ** 2
g_tt
# Out:
#                       2                                       2
#    ⎛         2       ⎞           ⎛    ⎛         2    2⎞      ⎞     2
# Δᵣ⋅⎝- Ω⋅a⋅sin (θ) + Ξ⎠  - Δₜₕₑₜₐ⋅⎝- Ω⋅⎝\tilde{r}  + a ⎠ + Ξ⋅a⎠ ⋅sin (θ)

# %%
omega_val = a * xi / (r_tilde_plus ** 2 + a ** 2)
omega_val
# Out:
#       Ξ⋅a
# ────────────────
#           2    2
# \tilde{r}₊  + a

# %%
g_tt.subs({omega: omega_val}).subs({xi: xi_val, delta_theta: delta_theta_val, delta_r: det_g_r_final}).expand().simplify()
# Out:
#        2        2 ⎛ 2 ⎛          2    2⎞ ⎛         4  2            4
# (a - 1) ⋅(a + 1) ⋅⎝a ⋅⎝\tilde{r}₊  + a ⎠⋅⎝\tilde{r} ⋅a  - \tilde{r}  - \tilde{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2  4    2                 2  4            2  2    2                 2  2
# r} ⋅a ⋅sin (θ) + 2⋅\tilde{r} ⋅a  + \tilde{r} ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅a  - 2
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                        4    2                              3    2
# ⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) - 2⋅\tild
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  2    2                4  2    2                2  4    2
# e{r}⋅\tilde{r}₊⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a ⋅sin (θ) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#              2  3    2                2  2    2       6    2       6    4⎞
#  4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a ⋅sin (θ) - a ⋅sin (θ) + a  - a ⎠⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2         2 ⎛          4               2  2    4⎞ ⎛           4            2
#  (θ) + 2⋅a ⋅⎝\tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a  + a ⎠⋅⎝- \tilde{r}  - \tilde{r} ⋅a
# ──────────────────────────────────────────────────────────────────────────────
#                                                         ⎛          2    2⎞ ⎛
#                                                         ⎝\tilde{r}₊  + a ⎠⋅⎝\t
#
# 2    2               2  2                           2
#  ⋅cos (θ) - \tilde{r} ⋅a  + 2⋅\tilde{r}⋅\tilde{r}₊⋅a  + 4⋅\tilde{r}⋅\tilde{r}₊
# ──────────────────────────────────────────────────────────────────────────────
#         4               2  2    4⎞
# ilde{r}₊  + 2⋅\tilde{r}₊ ⋅a  + a ⎠
#
#                                         4             2  2               2
# ⋅a + 2⋅\tilde{r}⋅\tilde{r}₊ + \tilde{r}₊  - \tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2    4    2       2⎞    2      ⎛          2    2⎞ ⎛          4
#  \tilde{r}₊  - a ⋅cos (θ) + a ⎠⋅sin (θ) + ⎝\tilde{r}₊  + a ⎠⋅⎝\tilde{r}₊  + 2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           2  2    4⎞ ⎛         4            2  2            2
# \tilde{r}₊ ⋅a  + a ⎠⋅⎝\tilde{r}  + \tilde{r} ⋅a  + \tilde{r}  - 2⋅\tilde{r}⋅\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           2                                                                 4
# ilde{r}₊⋅a  - 4⋅\tilde{r}⋅\tilde{r}₊⋅a - 2⋅\tilde{r}⋅\tilde{r}₊ - \tilde{r}₊
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             2  2               2               2    4    4       4    2
# + \tilde{r}₊ ⋅a  + 4⋅\tilde{r}₊ ⋅a + \tilde{r}₊  - a ⋅sin (θ) + a ⋅sin (θ) - a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2    2   ⎞⎞
#  ⋅sin (θ)⎠⎠
# ───────────

# %%
g_tt_simp = g_tt.subs({omega: omega_val}).subs({xi: xi_val, delta_theta: delta_theta_val, delta_r: det_g_r_final}).expand().simplify()
g_tt_simp = (sympy.fraction(g_tt_simp)[0] / ((a - 1) ** 2 * (a + 1) ** 2 * (r_tilde_plus ** 2 + a ** 2))).expand().simplify().factor()
g_tt_simp
# Out:
#                          ⎛         3           4              3           2  2
# (\tilde{r} - \tilde{r}₊)⋅⎝\tilde{r} ⋅\tilde{r}₊  + 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a
#
#     2               3  4    2               3  2    2               3  2
# ⋅cos (θ) + \tilde{r} ⋅a ⋅cos (θ) + \tilde{r} ⋅a ⋅cos (θ) - \tilde{r} ⋅a  + \ti
#
#       2           5              2           3  2    2               2
# lde{r} ⋅\tilde{r}₊  + 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅cos (θ) + \tilde{r} ⋅\tilde{
#
#      4    2               2             2    2               2             2
# r}₊⋅a ⋅cos (θ) + \tilde{r} ⋅\tilde{r}₊⋅a ⋅cos (θ) - \tilde{r} ⋅\tilde{r}₊⋅a  +
#
#                      6                         4  2    2
#  \tilde{r}⋅\tilde{r}₊  + 2⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅cos (θ) + \tilde{r}⋅\tilde
#
#     4  2                       4                         2  4    4
# {r}₊ ⋅a  + \tilde{r}⋅\tilde{r}₊  + 2⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅cos (θ) + \tilde
#
#               2  4    2                          2  2    2
# {r}⋅\tilde{r}₊ ⋅a ⋅cos (θ) + \tilde{r}⋅\tilde{r}₊ ⋅a ⋅cos (θ) + \tilde{r}⋅\til
#
#       2  2              6    4                 4    4                7
# de{r}₊ ⋅a  + \tilde{r}⋅a ⋅cos (θ) + \tilde{r}⋅a ⋅cos (θ) + \tilde{r}₊  + 2⋅\ti
#
#        5  2    2                5  2               5               5
# lde{r}₊ ⋅a ⋅cos (θ) - \tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a - \tilde{r}₊  + 2⋅\tild
#
#      3  4    4                  3  4    2                  3  3    2
# e{r}₊ ⋅a ⋅cos (θ) - 3⋅\tilde{r}₊ ⋅a ⋅cos (θ) - 8⋅\tilde{r}₊ ⋅a ⋅cos (θ) - 3⋅\t
#
#         3  2    2                3  2               6    4
# ilde{r}₊ ⋅a ⋅cos (θ) + \tilde{r}₊ ⋅a  - \tilde{r}₊⋅a ⋅cos (θ) - 4⋅\tilde{r}₊⋅a
#
# 5    4                  4    4   ⎞
#  ⋅cos (θ) - \tilde{r}₊⋅a ⋅cos (θ)⎠

# %%
roots_tt = sympy.solve(g_tt_simp, r_tilde)

# %%
coeffs = sympy.Poly(g_tt_simp, r_tilde).all_coeffs()
coeffs
# Out:
# ⎡          4               2  2    2       4    2       2    2       2
# ⎣\tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + a ⋅cos (θ) + a ⋅cos (θ) - a , 0, \ti
#
#        4  2             4               2  4    4                  2  2    6
# lde{r}₊ ⋅a  + \tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + 2⋅\tilde{r}₊ ⋅a  + a ⋅c
#
#   4       4    4                   5  2               5                 5
# os (θ) + a ⋅cos (θ), - 2⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a - 2⋅\tilde{r}₊  - 4⋅
#
#           3  4    2                  3  3    2                  3  2    2
# \tilde{r}₊ ⋅a ⋅cos (θ) - 8⋅\tilde{r}₊ ⋅a ⋅cos (θ) - 4⋅\tilde{r}₊ ⋅a ⋅cos (θ) -
#
#                6    4                    5    4                    4    4
#  2⋅\tilde{r}₊⋅a ⋅cos (θ) - 4⋅\tilde{r}₊⋅a ⋅cos (θ) - 2⋅\tilde{r}₊⋅a ⋅cos (θ),
#
#             8               6  2    2                6  2               6
# - \tilde{r}₊  - 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + \tilde{r}₊ ⋅a  + 4⋅\tilde{r}₊ ⋅a +
#
#           6               4  4    4                  4  4    2
# \tilde{r}₊  - 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + 3⋅\tilde{r}₊ ⋅a ⋅cos (θ) + 8⋅\tilde{r
#
#   4  3    2                  4  2    2                4  2             2  6
# }₊ ⋅a ⋅cos (θ) + 3⋅\tilde{r}₊ ⋅a ⋅cos (θ) - \tilde{r}₊ ⋅a  + \tilde{r}₊ ⋅a ⋅co
#
#  4                  2  5    4                2  4    4   ⎤
# s (θ) + 4⋅\tilde{r}₊ ⋅a ⋅cos (θ) + \tilde{r}₊ ⋅a ⋅cos (θ)⎦

# %%
A_coeff_tt = coeffs[0].simplify().factor()
A_coeff_tt
# Out:
#           4               2  2    2       4    2       2    2       2
# \tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + a ⋅cos (θ) + a ⋅cos (θ) - a

# %%
coeffs[2].factor().simplify()
# Out:
#           4  2             4               2  4    4                  2  2
# \tilde{r}₊ ⋅a  + \tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + 2⋅\tilde{r}₊ ⋅a  + a
#
# 6    4       4    4
#  ⋅cos (θ) + a ⋅cos (θ)

# %%
coeffs[3].simplify()
# Out:
#                                         2
#               ⎛          2    2    2   ⎞         2
# -2⋅\tilde{r}₊⋅⎝\tilde{r}₊  + a ⋅cos (θ)⎠ ⋅(a + 1)

# %%
coeffs[4].simplify()
# Out:
#           2 ⎛            6               4  2    2                4  2
# \tilde{r}₊ ⋅⎝- \tilde{r}₊  - 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + \tilde{r}₊ ⋅a  + 4⋅\ti
#
#        4               4               2  4    4                  2  4    2
# lde{r}₊ ⋅a + \tilde{r}₊  - 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + 3⋅\tilde{r}₊ ⋅a ⋅cos (θ)
#
#                2  3    2                  2  2    2                2  2    6
#  + 8⋅\tilde{r}₊ ⋅a ⋅cos (θ) + 3⋅\tilde{r}₊ ⋅a ⋅cos (θ) - \tilde{r}₊ ⋅a  + a ⋅c
#
#   4         5    4       4    4   ⎞
# os (θ) + 4⋅a ⋅cos (θ) + a ⋅cos (θ)⎠

# %%
r_tilde_plus_curves_1_tt = sympy.solve(A_coeff_tt, r_tilde_plus)
r_tilde_plus_curves_1_tt
# Out:
# ⎡     _____________________________________________________________      _____
# ⎢    ╱                     _______________________________________      ╱
# ⎢   ╱     2    2          ╱  2    4       2    2         2             ╱     2
# ⎣-╲╱   - a ⋅cos (θ) - a⋅╲╱  a ⋅cos (θ) - a ⋅cos (θ) - cos (θ) + 1  , ╲╱   - a
#
# ________________________________________________________       _______________
#                 _______________________________________       ╱
#     2          ╱  2    4       2    2         2              ╱     2    2
# ⋅cos (θ) - a⋅╲╱  a ⋅cos (θ) - a ⋅cos (θ) - cos (θ) + 1  , -╲╱   - a ⋅cos (θ) +
#
# ______________________________________________      __________________________
#       _______________________________________      ╱                     _____
#      ╱  2    4       2    2         2             ╱     2    2          ╱  2
#  a⋅╲╱  a ⋅cos (θ) - a ⋅cos (θ) - cos (θ) + 1  , ╲╱   - a ⋅cos (θ) + a⋅╲╱  a ⋅c
#
# ___________________________________⎤
# __________________________________ ⎥
#   4       2    2         2         ⎥
# os (θ) - a ⋅cos (θ) - cos (θ) + 1  ⎦

# %%
from tqdm import tqdm


def check_if_allowable(sols, A_coeff, a_val, r_tilde_plus_val):
    # check the sign of leading term in r_tilde
    A = A_coeff.subs({a: a_val, r_tilde_plus: r_tilde_plus_val}).evalf()
    if A < 0:
         return False

    for sol in sols:
        r = sol.subs({a: a_val, r_tilde_plus: r_tilde_plus_val}).evalf()
        if r != sympy.nan:
            if np.abs(r.coeff(sympy.I)) < 1e-10:
                if r.is_real:
                    real_part = r
                else:
                    real_part = r.args[0]
                if real_part > r_tilde_plus_val:
                    return False

    return True


def conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, sols, A_coeff):
    allowable_map = np.zeros(a_vals_grid.shape, dtype=bool)

    # restrict to given theta
    sols_theta = []
    for sol in sols:
        sols_theta.append(sol.subs({theta: theta_val}))
    A_coeff_theta = A_coeff.subs({theta: theta_val})

    with tqdm(total=np.prod(a_vals_grid.shape)) as pbar:
        for i in range(a_vals_grid.shape[0]):
            for j in range(a_vals_grid.shape[1]):
                allowable_map[i, j] = check_if_allowable(
                    sols_theta, A_coeff_theta, a_vals_grid[i, j], r_tilde_plus_vals_grid[i, j]
                )
                pbar.update(1)

    return allowable_map

# %%
a_vals = np.arange(0, 1.005, 0.01)
r_tilde_plus_vals = np.arange(-1, 1.01, 0.01)
a_vals_grid, r_tilde_plus_vals_grid = np.meshgrid(a_vals, r_tilde_plus_vals)

# %% [markdown]
# #### $\theta = \pi/4$

# %%
theta_val = np.pi / 4
allowable_maps_tt_pi_4 = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, roots_tt, A_coeff_tt)
# Out:
# 100%|██████████| 20301/20301 [01:18<00:00, 259.01it/s]

# %%
r_tilde_plus_curve_pi_4 = [r_tilde_plus_curves_1_tt[2].subs({theta: theta_val}).subs({a: a_val}).evalf().as_real_imag()[0] for a_val in a_vals]

# %%
plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_maps_tt_pi_4, cmap='Set2')
plt.plot(a_vals, r_tilde_plus_curve_pi_4, 'r-')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(0.5, -0.4, 'bx')
plt.plot(0.5, -0.5, 'gx')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/4$')
plt.savefig('figures/real_g_tt_sign_parameter_space_theta_pi_4.pdf', bbox_inches='tight', dpi=300);

# %% [markdown]
# Spotcheck some results.

# %%
a_val = 0.5
r_tilde_plus_val = -0.4
theta_val = np.pi / 4

# %%
g_tt_final_vals = []

r_tilde_vals = np.arange(-10, 10, 0.01)

for r_tilde_val in r_tilde_vals:
    g_tt_final_vals.append(g_tt_simp.subs({r_tilde_plus: r_tilde_plus_val, a: a_val, r_tilde: r_tilde_val, theta: theta_val}).evalf())

# %%
plt.plot(r_tilde_vals, g_tt_final_vals)
plt.plot(r_tilde_plus_val, 0, 'kx')
plt.ylim([-0.01, 0.01])
plt.plot([-2, 3], [0, 0], 'k-')
plt.xlim([-2, 3]);

# %%
a_val = 0.5
r_tilde_plus_val = -0.5
theta_val = np.pi / 4

# %%
g_tt_final_vals = []

r_tilde_vals = np.arange(-10, 10, 0.01)

for r_tilde_val in r_tilde_vals:
    g_tt_final_vals.append(g_tt_simp.subs({r_tilde_plus: r_tilde_plus_val, a: a_val, r_tilde: r_tilde_val, theta: theta_val}).evalf())

# %%
plt.plot(r_tilde_vals, g_tt_final_vals)
plt.plot(r_tilde_plus_val, 0, 'kx')
plt.ylim([-0.01, 0.01])
plt.plot([-1, 0], [0, 0], 'k-')
plt.xlim([-1, 0]);

# %% [markdown]
# #### $\theta = \pi/2$

# %%
theta_val = np.pi / 2
allowable_maps_tt_pi_2 = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, roots_tt, A_coeff_tt)
# Out:
# 100%|██████████| 20301/20301 [00:45<00:00, 446.82it/s]

# %%
r_tilde_plus_curve_pi_2 = [r_tilde_plus_curves_1_tt[2].subs({theta: theta_val}).subs({a: a_val}).evalf().as_real_imag()[0] for a_val in a_vals]

# %%
plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_maps_tt_pi_2, cmap='Set2')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, r_tilde_plus_curve_pi_2, 'r-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/2$')
plt.savefig('figures/real_g_tt_sign_parameter_space_theta_pi_2.pdf', bbox_inches='tight', dpi=300);

# %% [markdown]
# #### $\theta = 0$

# %%
theta_val = 0
allowable_maps_tt_pi_0 = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, roots_tt, A_coeff_tt)
# Out:
# 100%|██████████| 20301/20301 [01:49<00:00, 185.38it/s]

# %%
r_tilde_plus_curve_pi_0 = [r_tilde_plus_curves_1_tt[2].subs({theta: theta_val}).subs({a: a_val}).evalf().as_real_imag()[0] for a_val in a_vals]

# %%
plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_maps_tt_pi_0, cmap='Set2')
plt.plot(a_vals, r_tilde_plus_curve_pi_0, 'r-')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = 0$')
plt.savefig('figures/real_g_tt_sign_parameter_space_theta_pi_0.pdf', bbox_inches='tight', dpi=300);

# %%
theta_val = np.pi / 8
allowable_maps_tt_pi_8 = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, roots_tt, A_coeff_tt)
# Out:
# 100%|██████████| 20301/20301 [01:47<00:00, 189.02it/s]

# %%
r_tilde_plus_curve_pi_8 = [r_tilde_plus_curves_1_tt[2].subs({theta: theta_val}).subs({a: a_val}).evalf().as_real_imag()[0] for a_val in a_vals]

# %%
plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_maps_tt_pi_8, cmap='Set2')
plt.plot(a_vals, r_tilde_plus_curve_pi_8, 'r-')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/8$');

# %% [markdown]
# Conduct sweep.

# %%
a_vals = np.arange(0, 1.01, 0.01)
r_tilde_plus_vals = np.arange(-1, 1.01, 0.01)
a_vals_grid, r_tilde_plus_vals_grid = np.meshgrid(a_vals, r_tilde_plus_vals)

# %%
theta_vals = np.linspace(0, np.pi, 10)

allowable_maps_tt = {}

for theta_val in theta_vals:
    allowable_maps_tt[theta_val] = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, roots_tt, A_coeff_tt)
# Out:
# 100%|██████████| 20301/20301 [01:48<00:00, 187.66it/s]
# 100%|██████████| 20301/20301 [01:46<00:00, 190.42it/s]
# 100%|██████████| 20301/20301 [01:26<00:00, 235.26it/s]
# 100%|██████████| 20301/20301 [00:57<00:00, 352.76it/s]
# 100%|██████████| 20301/20301 [00:46<00:00, 438.49it/s]
# 100%|██████████| 20301/20301 [00:46<00:00, 437.62it/s]
# 100%|██████████| 20301/20301 [00:58<00:00, 349.28it/s]
# 100%|██████████| 20301/20301 [01:26<00:00, 234.20it/s]
# 100%|██████████| 20301/20301 [01:46<00:00, 189.77it/s]
# 100%|██████████| 20301/20301 [01:51<00:00, 182.16it/s]

# %%
for theta_val, allowable_map in allowable_maps_tt.items():
    plt.figure(figsize=(3, 3))

    plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map, cmap='Set2')
    plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
    plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')

    # plot possible curves
    r_tilde_plus_curve_vals = [r_tilde_plus_curves_1_tt[2].subs({theta: theta_val}).subs({a: a_val}).evalf().as_real_imag()[0] for a_val in a_vals]
    plt.plot(a_vals, r_tilde_plus_curve_vals, 'r-')

    plt.xlabel("$a$")
    plt.ylabel("$\\tilde{r}_+$")
    plt.xlim([0, 1])
    plt.ylim([-1, 1])
    plt.yticks([-1, -0.5, 0, 0.5, 1])
    plt.title(f"$\\theta = {theta_val}$");

# %% [markdown]
# ### $g_{\phi\phi}$

# %%
g_phiphi = (r_tilde ** 2 + a ** 2) ** 2 * delta_theta - delta_r * a ** 2 * sympy.sin(theta) ** 2
g_phiphi
# Out:
#                                           2
#       2    2             ⎛         2    2⎞
# - Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅⎝\tilde{r}  + a ⎠

# %%
g_phiphi_simp = g_phiphi.subs({delta_theta: delta_theta_val, delta_r: det_g_r_final}).expand().simplify()
g_phiphi_simp
# Out:
#            4  2            4            2  4    2                 2  4
# - \tilde{r} ⋅a  + \tilde{r}  + \tilde{r} ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅a  - \tild
#
#     2  2    2                 2  2                           4    2
# e{r} ⋅a ⋅sin (θ) + 2⋅\tilde{r} ⋅a  + 2⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 4⋅\ti
#
#                    3    2                              2    2                4
# lde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 2⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + \tilde{r}₊
#
#   2    2                2  4    2                  2  3    2                2
# ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅
#
#  2    2       6    2       6    4
# a ⋅sin (θ) + a ⋅sin (θ) - a  + a

# %%
roots_phiphi = sympy.solve(g_phiphi_simp, r_tilde)

# %%
coeffs = sympy.Poly(g_phiphi_simp, r_tilde).all_coeffs()
coeffs
# Out:
# ⎡     2      4    2         4    2    2         2                4    2
# ⎣1 - a , 0, a ⋅sin (θ) - 2⋅a  - a ⋅sin (θ) + 2⋅a , 2⋅\tilde{r}₊⋅a ⋅sin (θ) + 4
#
#              3    2                    2    2               4  2    2
# ⋅\tilde{r}₊⋅a ⋅sin (θ) + 2⋅\tilde{r}₊⋅a ⋅sin (θ), \tilde{r}₊ ⋅a ⋅sin (θ) - \ti
#
#        2  4    2                  2  3    2                2  2    2       6
# lde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) + a ⋅s
#
#   2       6    4⎤
# in (θ) - a  + a ⎦

# %%
A_coeff_phiphi = coeffs[0].simplify()
A_coeff_phiphi
# Out:
#      2
# 1 - a

# %%
coeffs[2].simplify()
# Out:
#  2 ⎛   2    2       2      2       ⎞
# a ⋅⎝- a ⋅cos (θ) - a  + cos (θ) + 1⎠

# %% [markdown]
# This is the same as:

# %%
a ** 2 * (1 - a ** 2) * (sympy.cos(theta) ** 2 + 1)
# Out:
#  2 ⎛     2⎞ ⎛   2       ⎞
# a ⋅⎝1 - a ⎠⋅⎝cos (θ) + 1⎠

# %%
coeffs[3].simplify()
# Out:
#               2 ⎛ 2          ⎞    2
# 2⋅\tilde{r}₊⋅a ⋅⎝a  + 2⋅a + 1⎠⋅sin (θ)

# %%
coeffs[4].simplify().factor()
# Out:
#  2 ⎛          4    2                2  2    2                  2      2
# a ⋅⎝\tilde{r}₊ ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a⋅sin (θ) - \
#
#          2    2       4    2       4    2⎞
# tilde{r}₊ ⋅sin (θ) + a ⋅sin (θ) - a  + a ⎠

# %% [markdown]
# Get candidate curves.

# %%
poly_1 = (roots_phiphi[0].args[0][1].simplify().args[0] * (a ** 2 - 1) / a ** 2).simplify()
poly_1
# Out:
#
#
#             4    2                2  2    2                  2      2
# - \tilde{r}₊ ⋅sin (θ) + \tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a⋅sin (θ) + \ti
#
#
#                                                               2
#                                       2 ⎛ 2    ⎞ ⎛   2       ⎞
#        2    2       4    2       4   a ⋅⎝a  - 1⎠⋅⎝sin (θ) - 2⎠     2
# lde{r}₊ ⋅sin (θ) - a ⋅sin (θ) + a  + ────────────────────────── - a
#                                                  12

# %%
r_tilde_plus_curves_1 = sympy.solve(poly_1, r_tilde_plus)

# %%
poly_2 = coeffs[4].simplify().factor() / a ** 2
poly_2
# Out:
#           4    2                2  2    2                  2      2
# \tilde{r}₊ ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a⋅sin (θ) - \tild
#
#      2    2       4    2       4    2
# e{r}₊ ⋅sin (θ) + a ⋅sin (θ) - a  + a

# %%
r_tilde_plus_curves_2 = sympy.solve(poly_2, r_tilde_plus)

# %%
poly_3 = roots_phiphi[0].args[0][0].args[0].args[1] ** 2
poly_3
# Out:
#                                 ______________________________________________
#                                ╱
#                               ╱                             ⎛   2    2
#                              ╱                          3   ⎝- a ⋅sin (θ) + 2⋅
#    2    2         2         ╱      ⎛   2    2         2⎞
# 2⋅a ⋅sin (θ)   4⋅a         ╱       ⎝- a ⋅sin (θ) + 2⋅a ⎠
# ──────────── - ──── - 2⋅3 ╱      - ────────────────────── + ──────────────────
#      3          3       ╲╱                  108
#
# ______________________________________________________________________________
#     ⎛            4  2    2                2  4    2                  2  3    2
#  2⎞ ⎜  \tilde{r}₊ ⋅a ⋅sin (θ)   \tilde{r}₊ ⋅a ⋅sin (θ)   4⋅\tilde{r}₊ ⋅a ⋅sin
# a ⎠⋅⎜- ────────────────────── + ────────────────────── + ─────────────────────
#     ⎜           2                        2                         2
#     ⎝          a  - 1                   a  - 1                    a  - 1
# ──────────────────────────────────────────────────────────────────────────────
#                                                            3
#
# ______________________________________________________________________________
#                 2  2    2       6    2         6        4  ⎞
# (θ)   \tilde{r}₊ ⋅a ⋅sin (θ)   a ⋅sin (θ)     a        a   ⎟   ⎛
# ─── + ────────────────────── - ────────── + ────── - ──────⎟   ⎜  2⋅\tilde{r}₊
#                2                  2          2        2    ⎟   ⎜- ────────────
#               a  - 1             a  - 1     a  - 1   a  - 1⎠   ⎝           a -
# ──────────────────────────────────────────────────────────── - ───────────────
#
#
# ________________________________________
#                                       2
#   3    2                    2    2   ⎞
# ⋅a ⋅sin (θ)   2⋅\tilde{r}₊⋅a ⋅sin (θ)⎟
# ─────────── - ───────────────────────⎟
#  1                     a - 1         ⎠
# ───────────────────────────────────────
#            8

# %%
r_tilde_plus_curves_3 = sympy.solve(poly_3, r_tilde_plus)

# %%
poly_5 = -roots_phiphi[0].args[1].args[0].args[0].args[1].args[0].args[0].args[1].args[0].args[0].args[0]
poly_5
# Out:
#
#   ⎛                                                 ⎛            4  2    2
#   ⎜                           ⎛   2    2         2⎞ ⎜  \tilde{r}₊ ⋅a ⋅sin (θ)
#   ⎜                       3   ⎝- a ⋅sin (θ) + 2⋅a ⎠⋅⎜- ──────────────────────
#   ⎜  ⎛   2    2         2⎞                          ⎜           2
#   ⎜  ⎝- a ⋅sin (θ) + 2⋅a ⎠                          ⎝          a  - 1
#   ⎜- ────────────────────── + ────────────────────────────────────────────────
#   ⎝           108
# - ────────────────────────────────────────────────────────────────────────────
#
#
#
#             2  4    2                  2  3    2                2  2    2
#   \tilde{r}₊ ⋅a ⋅sin (θ)   4⋅\tilde{r}₊ ⋅a ⋅sin (θ)   \tilde{r}₊ ⋅a ⋅sin (θ)
# + ────────────────────── + ──────────────────────── + ────────────────────── -
#            2                         2                         2
#           a  - 1                    a  - 1                    a  - 1
# ──────────────────────────────────────────────────────────────────────────────
#                              3
# ──────────────────────────────────────────────────────────────────────────────
#                                              4
#
#
#   6    2         6        4  ⎞
#  a ⋅sin (θ)     a        a   ⎟   ⎛                3    2                    2
#  ────────── + ────── - ──────⎟   ⎜  2⋅\tilde{r}₊⋅a ⋅sin (θ)   2⋅\tilde{r}₊⋅a ⋅
#     2          2        2    ⎟   ⎜- ─────────────────────── - ────────────────
#    a  - 1     a  - 1   a  - 1⎠   ⎝           a - 1                     a - 1
# ────────────────────────────── - ─────────────────────────────────────────────
#                                                            8
# ──────────────────────────────────────────────────────────────────────────────
#
#
#           2
#         2⎞
#    2   ⎞ ⎟
# sin (θ)⎟ ⎟    ⎛          4  2    2                2  4    2                  2
# ───────⎟ ⎟    ⎜\tilde{r}₊ ⋅a ⋅sin (θ)   \tilde{r}₊ ⋅a ⋅sin (θ)   4⋅\tilde{r}₊
#        ⎠ ⎟    ⎜────────────────────── - ────────────────────── - ─────────────
# ─────────⎟    ⎜         2                        2                         2
#          ⎠    ⎝        a  - 1                   a  - 1                    a  -
# ─────────── - ────────────────────────────────────────────────────────────────
#
#
#
#
#
#   3    2                2  2    2       6    2         6      4    4       4
# ⋅a ⋅sin (θ)   \tilde{r}₊ ⋅a ⋅sin (θ)   a ⋅sin (θ)     a      a ⋅sin (θ)   a ⋅s
# ─────────── - ────────────────────── + ────────── - ────── - ────────── + ────
#                        2                  2          2           12
#  1                    a  - 1             a  - 1     a  - 1
# ──────────────────────────────────────────────────────────────────────────────
#                  27
#
#
#
#                      3
#   2       4      4  ⎞
# in (θ)   a      a   ⎟
# ────── - ── + ──────⎟
# 3        3     2    ⎟
#               a  - 1⎠
# ──────────────────────

# %%
def alpha_shape(points, alpha, only_outer=True):
    """
    Compute the alpha shape (concave hull) of a set of points.
    :param points: np.array of shape (n,2) points.
    :param alpha: alpha value.
    :param only_outer: boolean value to specify if we keep only the outer border
    or also inner edges.
    :return: set of (i,j) pairs representing edges of the alpha-shape. (i,j) are
    the indices in the points array.
    """
    assert points.shape[0] > 3, "Need at least four points"
    def add_edge(edges, i, j):
        """
        Add an edge between the i-th and j-th points,
        if not in the list already
        """
        if (i, j) in edges or (j, i) in edges:
            # already added
            assert (j, i) in edges, "Can't go twice over same directed edge right?"
            if only_outer:
                # if both neighboring triangles are in shape, it's not a boundary edge
                edges.remove((j, i))
            return
        edges.add((i, j))
    tri = Delaunay(points)
    edges = set()
    # Loop over triangles:
    # ia, ib, ic = indices of corner points of the triangle
    for ia, ib, ic in tri.vertices:
        pa = points[ia]
        pb = points[ib]
        pc = points[ic]
        # Computing radius of triangle circumcircle
        # www.mathalino.com/reviewer/derivation-of-formulas/derivation-of-formula-for-radius-of-circumcircle
        a = np.sqrt((pa[0] - pb[0]) ** 2 + (pa[1] - pb[1]) ** 2)
        b = np.sqrt((pb[0] - pc[0]) ** 2 + (pb[1] - pc[1]) ** 2)
        c = np.sqrt((pc[0] - pa[0]) ** 2 + (pc[1] - pa[1]) ** 2)
        s = (a + b + c) / 2.0
        area = np.sqrt(s * (s - a) * (s - b) * (s - c))
        circum_r = a * b * c / (4.0 * area)
        if circum_r < alpha:
            add_edge(edges, ia, ib)
            add_edge(edges, ib, ic)
            add_edge(edges, ic, ia)
    return edges

# %% [markdown]
# Conduct sweep.

# %%
a_vals = np.arange(0, 1.01, 0.01)
r_tilde_plus_vals = np.arange(-1, 0.51, 0.01)
a_vals_grid, r_tilde_plus_vals_grid = np.meshgrid(a_vals, r_tilde_plus_vals)

# %%
theta_vals = np.linspace(0, np.pi / 2, 8)

allowable_maps = {}

for theta_val in theta_vals:
    allowable_maps[theta_val] = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, roots_phiphi, A_coeff_phiphi)
# Out:
# 100%|██████████| 15251/15251 [02:38<00:00, 96.15it/s]
# 100%|██████████| 15251/15251 [04:33<00:00, 55.80it/s]
# 100%|██████████| 15251/15251 [03:33<00:00, 71.53it/s]
# 100%|██████████| 15251/15251 [03:02<00:00, 83.78it/s]
# 100%|██████████| 15251/15251 [02:50<00:00, 89.58it/s]
# 100%|██████████| 15251/15251 [02:40<00:00, 94.75it/s]
# 100%|██████████| 15251/15251 [02:45<00:00, 92.38it/s]
# 100%|██████████| 15251/15251 [02:37<00:00, 96.63it/s]

# %%
poly_5_maps = {}

for theta_val in theta_vals:
    poly_5_map = np.zeros(a_vals_grid.shape)
    poly_5_map[:] = np.nan

    with tqdm(total=np.prod(a_vals_grid.shape)) as pbar:
        for i in range(a_vals_grid.shape[0]):
            for j in range(a_vals_grid.shape[1]):
                poly_5_val = poly_5.subs({a: a_vals_grid[i, j], r_tilde_plus: r_tilde_plus_vals_grid[i, j], theta: theta_val}).evalf()
                if poly_5_val.is_real:
                    poly_5_map[i, j] = int(bool(poly_5_val > 0))
                pbar.update(1)

    poly_5_maps[theta_val] = poly_5_map
# Out:
# 100%|██████████| 15251/15251 [02:10<00:00, 116.60it/s]
# 100%|██████████| 15251/15251 [02:16<00:00, 112.11it/s]
# 100%|██████████| 15251/15251 [02:15<00:00, 112.23it/s]
# 100%|██████████| 15251/15251 [02:16<00:00, 111.56it/s]
# 100%|██████████| 15251/15251 [02:17<00:00, 110.96it/s]
# 100%|██████████| 15251/15251 [02:15<00:00, 112.84it/s]
# 100%|██████████| 15251/15251 [02:15<00:00, 112.36it/s]
# 100%|██████████| 15251/15251 [02:15<00:00, 112.37it/s]

# %%
boundary_pts = {}

for theta_val in theta_vals:
    row_indices, col_indices = np.nonzero(np.logical_and(poly_5_maps[theta_val] == 0, a_vals_grid > 0))
    reg_pts = np.array([[a_vals_grid[idx[0], idx[1]], r_tilde_plus_vals_grid[idx[0], idx[1]]] for idx in zip(row_indices, col_indices)])
    edges = alpha_shape(reg_pts, alpha=0.01, only_outer=True)
    boundary_pts_arr = []
    for edge in edges:
        boundary_pts_arr.append(reg_pts[edge[0]])
        boundary_pts_arr.append(reg_pts[edge[1]])
    boundary_pts[theta_val] = np.array(boundary_pts_arr)
# Out:
# /var/folders/29/57ctygt16nb459fzj64lth0r0000gq/T/ipykernel_49696/579540476.py:6: DeprecationWarning: Delaunay attribute 'vertices' is deprecated in favour of 'simplices' and will be removed in Scipy 1.11.0.
#   edges = alpha_shape(reg_pts, alpha=0.01, only_outer=True)
# /var/folders/29/57ctygt16nb459fzj64lth0r0000gq/T/ipykernel_49696/3101725192.py:42: RuntimeWarning: divide by zero encountered in double_scalars
#   circum_r = a * b * c / (4.0 * area)
# /var/folders/29/57ctygt16nb459fzj64lth0r0000gq/T/ipykernel_49696/3101725192.py:41: RuntimeWarning: invalid value encountered in sqrt
#   area = np.sqrt(s * (s - a) * (s - b) * (s - c))

# %%
fig, ax = plt.subplots(ncols=4, nrows=2, figsize=(20, 8))

ind_row = 0
ind_col = 0

for theta_val, allowable_map in allowable_maps.items():
    if theta_val != theta_vals[0]:
        ax[ind_row, ind_col].plot(boundary_pts[theta_val][:, 0], boundary_pts[theta_val][:, 1], 'k.')

    ax[ind_row, ind_col].contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map, cmap='Set2')
    ax[ind_row, ind_col].plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
    ax[ind_row, ind_col].plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')

    ax[ind_row, ind_col].set_xlim([0, 1])
    ax[ind_row, ind_col].set_ylim([-1, 0.5])
    ax[ind_row, ind_col].set_yticks([-1, -0.5, 0, 0.5])
    ax[ind_row, ind_col].set_title(f"$\\theta = {theta_val:.2f}$");

    if ind_col == 0:
        ax[ind_row, ind_col].set_ylabel("$\\tilde{r}_+$")
    if ind_row == 1:
        ax[ind_row, ind_col].set_xlabel("$a$")

    if ind_col < 3:
        ind_col += 1
    else:
        ind_row += 1
        ind_col = 0

# %%
poly_5_coeff_1, poly_5_coeff_2, poly_5_coeff_3 = sympy.symbols("A_1 A_2 A_3")
poly_5_coeff_1_val = a ** 2 * (2 - sympy.sin(theta) ** 2)
poly_5_coeff_2_val = r_tilde_plus ** 4 * sympy.sin(theta) ** 2 - (a ** 2 + 4 * a + 1) * sympy.sin(theta) ** 2 * r_tilde_plus ** 2 - a ** 4 * sympy.cos(theta) ** 2 + a ** 2
poly_5_coeff_3_val = r_tilde_plus * a ** 2 * sympy.sin(theta) ** 2 * (a + 1)

# %%
poly_5_simp = -(-poly_5_coeff_1 * poly_5_coeff_2 * a ** 2 / (3 * (1 - a ** 2)) + poly_5_coeff_1 ** 3 / 108 + poly_5_coeff_3 ** 2 / (2 * (a - 1) ** 2)) ** 2 / 4
poly_5_simp += (poly_5_coeff_1 ** 2 / 12 + a ** 2 * poly_5_coeff_2 / ((1 - a ** 2))) ** 3 / 27
poly_5_simp
# Out:
#               3                                2
# ⎛  2       2 ⎞    ⎛  3          2        2    ⎞
# ⎜A₁    A₂⋅a  ⎟    ⎜A₁    A₁⋅A₂⋅a       A₃     ⎟
# ⎜─── + ──────⎟    ⎜─── - ──────── + ──────────⎟
# ⎜ 12        2⎟    ⎜108          2            2⎟
# ⎝      1 - a ⎠    ⎝      3 - 3⋅a    2⋅(a - 1) ⎠
# ─────────────── - ──────────────────────────────
#        27                       4

# %%
(poly_5_simp.subs({poly_5_coeff_1: poly_5_coeff_1_val, poly_5_coeff_2: poly_5_coeff_2_val, poly_5_coeff_3: poly_5_coeff_3_val}) - poly_5).simplify()
# Out:
# 0

# %%
poly_5_simp_subs = poly_5_simp.subs({poly_5_coeff_1: poly_5_coeff_1_val, poly_5_coeff_2: poly_5_coeff_2_val, poly_5_coeff_3: poly_5_coeff_3_val})

# %%
g_phiphi_pos_maps = {}

for theta_val in theta_vals:
    g_phiphi_pos_map = np.zeros(a_vals_grid.shape)
    g_phiphi_pos_map[:] = np.nan

    with tqdm(total=np.prod(a_vals_grid.shape)) as pbar:
        for i in range(a_vals_grid.shape[0]):
            for j in range(a_vals_grid.shape[1]):
                if r_tilde_plus_vals_grid[i, j] > 0:
                    g_phiphi_pos_map[i, j] = 1
                else:
                    poly_5_val = poly_5_simp_subs.subs({a: a_vals_grid[i, j], r_tilde_plus: r_tilde_plus_vals_grid[i, j], theta: theta_val}).evalf()
                    if poly_5_val.is_real:
                        g_phiphi_pos_map[i, j] = int(bool(poly_5_val > 0))
                pbar.update(1)

    g_phiphi_pos_maps[theta_val] = g_phiphi_pos_map
# Out:
# 100%|██████████| 15251/15251 [01:00<00:00, 251.49it/s]
# 100%|██████████| 15251/15251 [01:03<00:00, 241.15it/s]
# 100%|██████████| 15251/15251 [01:06<00:00, 229.39it/s]
# 100%|██████████| 15251/15251 [01:02<00:00, 245.66it/s]
# 100%|██████████| 15251/15251 [01:02<00:00, 245.63it/s]
# 100%|██████████| 15251/15251 [01:02<00:00, 244.17it/s]
# 100%|██████████| 15251/15251 [01:02<00:00, 244.85it/s]
# 100%|██████████| 15251/15251 [01:02<00:00, 245.46it/s]

# %%
fig, ax = plt.subplots(ncols=4, nrows=2, figsize=(20, 8))

ind_row = 0
ind_col = 0

for theta_val, allowable_map in g_phiphi_pos_maps.items():
    ax[ind_row, ind_col].contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map > 0, cmap='Set2')
    ax[ind_row, ind_col].plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
    ax[ind_row, ind_col].plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')

    ax[ind_row, ind_col].set_xlim([0, 1])
    ax[ind_row, ind_col].set_ylim([-1, 0.5])
    ax[ind_row, ind_col].set_yticks([-1, -0.5, 0, 0.5])
    ax[ind_row, ind_col].set_title(f"$\\theta = {theta_val:.2f}$");

    if ind_col == 0:
        ax[ind_row, ind_col].set_ylabel("$\\tilde{r}_+$")
    if ind_row == 1:
        ax[ind_row, ind_col].set_xlabel("$a$")

    if ind_col < 3:
        ind_col += 1
    else:
        ind_row += 1
        ind_col = 0

# %% [markdown]
# ### All Conditions

# %%
def conduct_sweep_all(a_vals_grid, r_tilde_plus_vals_grid, theta_val, sols_1, A_coeff_1, sols_2, A_coeff_2, sols_3, A_coeff_3):
    allowable_map = np.zeros(a_vals_grid.shape, dtype=bool)

    # restrict to given theta
    sols_1_theta = []
    sols_2_theta = []
    sols_3_theta = []
    for i in range(len(sols_1)):
        sols_1_theta.append(sols_1[i].subs({theta: theta_val}))
        sols_2_theta.append(sols_2[i].subs({theta: theta_val}))
        sols_3_theta.append(sols_3[i].subs({theta: theta_val}))
    A_coeff_1_theta = A_coeff_1.subs({theta: theta_val})
    A_coeff_2_theta = A_coeff_2.subs({theta: theta_val})
    A_coeff_3_theta = A_coeff_3.subs({theta: theta_val})

    with tqdm(total=np.prod(a_vals_grid.shape)) as pbar:
        for i in range(a_vals_grid.shape[0]):
            for j in range(a_vals_grid.shape[1]):
                is_allowable = check_if_allowable(
                    sols_1_theta, A_coeff_1_theta, a_vals_grid[i, j], r_tilde_plus_vals_grid[i, j]
                )
                if not is_allowable:
                    pbar.update(1)
                    continue
                is_allowable = check_if_allowable(
                    sols_2_theta, A_coeff_2_theta, a_vals_grid[i, j], r_tilde_plus_vals_grid[i, j]
                )
                if not is_allowable:
                    pbar.update(1)
                    continue
                allowable_map[i, j] = check_if_allowable(
                    sols_3_theta, A_coeff_3_theta, a_vals_grid[i, j], r_tilde_plus_vals_grid[i, j]
                )
                pbar.update(1)

    return allowable_map

# %%
a_vals = np.arange(0, 1.01, 0.01)
r_tilde_plus_vals = np.arange(-1, 1.01, 0.01)
a_vals_grid, r_tilde_plus_vals_grid = np.meshgrid(a_vals, r_tilde_plus_vals)

# %%
theta_vals = [0, np.pi / 8, np.pi / 6, np.pi / 4]

# %%
allowable_maps_all = {}

for theta_val in theta_vals:
    allowable_maps_all[theta_val] = conduct_sweep_all(
        a_vals_grid, r_tilde_plus_vals_grid, theta_val,
        sol, sympy.Integer(1),
        roots_tt, A_coeff_tt,
        roots_phiphi, A_coeff_phiphi
    )
# Out:
#  50%|████▉     | 10105/20301 [03:44<03:46, 45.01it/s]
#  47%|████▋     | 9467/20301 [04:07<04:42, 38.29it/s]
#  44%|████▎     | 8877/20301 [03:39<04:42, 40.43it/s]
#  32%|███▏      | 6586/20301 [02:48<05:51, 39.03it/s]

# %%
fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(8, 8))

ind_row = 0
ind_col = 0

for theta_val, allowable_map in allowable_maps_all.items():
    ax[ind_row, ind_col].contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map > 0, cmap='Set2')
    ax[ind_row, ind_col].plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
    ax[ind_row, ind_col].plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')

    ax[ind_row, ind_col].set_xlim([0, 1])
    ax[ind_row, ind_col].set_ylim([-1, 1])
    ax[ind_row, ind_col].set_yticks([-1, -0.5, 0, 0.5, 1])
    ax[ind_row, ind_col].set_title(f"$\\theta = {theta_val:.2f}$");

    if ind_col == 0:
        ax[ind_row, ind_col].set_ylabel("$\\tilde{r}_+$")
    if ind_row == 1:
        ax[ind_row, ind_col].set_xlabel("$a$")

    if ind_col < 1:
        ind_col += 1
    else:
        ind_row += 1
        ind_col = 0

# %% [markdown]
# Spotcheck results.

# %%
a_val = 0.8
r_tilde_plus_val = -0.25
theta_val = theta_vals[1]

# %%
g_rr_final_vals = []
g_tt_final_vals = []
g_phiphi_final_vals = []

r_tilde_vals = np.arange(-10, 10, 0.01)

for r_tilde_val in r_tilde_vals:
    g_rr_final_vals.append(det_g_r_final.subs({r_tilde_plus: r_tilde_plus_val, a: a_val, r_tilde: r_tilde_val, theta: theta_val}).evalf())
    g_tt_final_vals.append(g_tt_simp.subs({r_tilde_plus: r_tilde_plus_val, a: a_val, r_tilde: r_tilde_val, theta: theta_val}).evalf())
    g_phiphi_final_vals.append(g_phiphi_simp.subs({r_tilde_plus: r_tilde_plus_val, a: a_val, r_tilde: r_tilde_val, theta: theta_val}).evalf())

# %%
[sol[i].subs({a: a_val, r_tilde_plus: r_tilde_plus_val, theta: theta_val}).evalf() for i in range(4)]
# Out:
# [-0.25, -0.55552575966674, 0.40276287983337 + 1.40988381514163⋅ⅈ, 0.4027628798
# 3337 - 1.40988381514163⋅ⅈ]

# %%
[roots_tt[i].subs({a: a_val, r_tilde_plus: r_tilde_plus_val, theta: theta_val}).evalf() for i in range(4)]
# Out:
# [-0.25, -0.563682012791401, 0.4068410063957 + 1.49144830246124⋅ⅈ, 0.4068410063
# 957 - 1.49144830246124⋅ⅈ]

# %%
[roots_phiphi[i].subs({a: a_val, r_tilde_plus: r_tilde_plus_val, theta: theta_val}).evalf() for i in range(4)]
# Out:
# [-0.286665334641201 + 1.02133990388144⋅ⅈ, -0.286665334641201 - 1.0213399038814
# 4⋅ⅈ, 0.286665334641201 - 0.554520512595385⋅ⅈ, 0.286665334641201 + 0.5545205125
# 95385⋅ⅈ]

# %%
plt.figure(figsize=(5, 3))
plt.plot(r_tilde_vals, g_rr_final_vals)
plt.plot(r_tilde_plus_val, 0, 'kx')
plt.ylim([-0.01, 0.01])
plt.plot([-1, 0.2], [0, 0], 'k-')
plt.xlim([-1, 0.2]);

# %%
plt.figure(figsize=(5, 3))
plt.plot(r_tilde_vals, g_tt_final_vals)
plt.plot(r_tilde_plus_val, 0, 'kx')
plt.ylim([-0.001, 0.001])
plt.plot([-2, 2], [0, 0], 'k-')
plt.xlim([-2, 2]);

# %%
plt.figure(figsize=(5, 3))
plt.plot(r_tilde_vals, g_phiphi_final_vals)
plt.plot(r_tilde_plus_val, 0, 'kx')
plt.ylim([-1, 1])
plt.plot([-1.2, 1.2], [0, 0], 'k-')
plt.xlim([-1.2, 1.2]);

# %% [markdown]
# Compute the same regions using the discriminants.

# %%
allowable_maps_all_2 = {}

for theta_val in theta_vals:
    allowable_map_all = np.zeros(a_vals_grid.shape, dtype=bool)

    thres = 1e-10 if theta_val == 0 else 0

    with tqdm(total=np.prod(a_vals_grid.shape)) as pbar:
        for i in range(a_vals_grid.shape[0]):
            for j in range(a_vals_grid.shape[1]):
                if r_tilde_plus_vals_grid[i, j] > np.sqrt(a_vals_grid[i, j]):
                    allowable_map_all[i, j] = True
                elif r_tilde_plus_vals_grid[i, j] < 0 and r_tilde_plus_vals_grid[i, j] > -np.sqrt(a_vals_grid[i, j]):
                    D_t = A_coeff_tt.subs({a: a_vals_grid[i, j], r_tilde_plus: r_tilde_plus_vals_grid[i, j], theta: theta_val}).evalf()
                    if D_t.is_real and D_t > 0:
                        D_phi = poly_5_simp_subs.subs({a: a_vals_grid[i, j], r_tilde_plus: r_tilde_plus_vals_grid[i, j], theta: theta_val}).evalf()
                        if D_phi.is_real and D_phi > thres:
                            allowable_map_all[i, j] = True
                pbar.update(1)

    allowable_maps_all_2[theta_val] = allowable_map_all
# Out:
# 100%|██████████| 20301/20301 [00:44<00:00, 453.50it/s]
# 100%|██████████| 20301/20301 [00:44<00:00, 452.46it/s]
# 100%|██████████| 20301/20301 [00:40<00:00, 496.01it/s]
# 100%|██████████| 20301/20301 [00:24<00:00, 831.97it/s]

# %%
fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(8, 8))

ind_row = 0
ind_col = 0

for theta_val, allowable_map in allowable_maps_all_2.items():
    ax[ind_row, ind_col].contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map > 0, cmap='Set2')
    ax[ind_row, ind_col].plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
    ax[ind_row, ind_col].plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')

    ax[ind_row, ind_col].set_xlim([0, 1])
    ax[ind_row, ind_col].set_ylim([-1, 1])
    ax[ind_row, ind_col].set_yticks([-1, -0.5, 0, 0.5, 1])
    ax[ind_row, ind_col].set_title(f"$\\theta = {theta_val:.2f}$");

    if ind_col == 0:
        ax[ind_row, ind_col].set_ylabel("$\\tilde{r}_+$")
    if ind_row == 1:
        ax[ind_row, ind_col].set_xlabel("$a$")

    if ind_col < 1:
        ind_col += 1
    else:
        ind_row += 1
        ind_col = 0

plt.savefig('figures/allowability_condition_parameter_space_q_1.pdf', bbox_inches='tight', dpi=300);
