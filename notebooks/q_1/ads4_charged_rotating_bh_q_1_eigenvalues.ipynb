# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy

sympy.init_printing()

# %%
t, r, theta, phi, phi_tilde = sympy.symbols("t r theta phi \\tilde{\phi}")

# %%
r_tilde, delta_r, delta_theta, W, xi = sympy.symbols("\\tilde{r} Delta_r Delta_theta W Xi")

# %%
dt, dr, dtheta, dphi, dphi_tilde, dr_tilde = sympy.symbols(r"dt dr d\theta d\phi d\tilde{\phi} d\tilde{r}")

# %%
a, r_tilde_plus, delta = sympy.symbols("a \\tilde{r}_+ \delta")

# %%
tau, dtau = sympy.symbols("tau d\\tau")

# %%
metric_orig = -delta_r / W * (dt - a * sympy.sin(theta) ** 2 * dphi / xi) ** 2
metric_orig += delta_theta * sympy.sin(theta) ** 2 / W * (a * dt - (r_tilde ** 2 + a ** 2) * dphi / xi) ** 2
metric_orig += W * dr_tilde ** 2 / delta_r
metric_orig
# Out:
#                            2                                          2
#      ⎛                2   ⎞           ⎛             ⎛         2    2⎞⎞
#      ⎜     a⋅d\phi⋅sin (θ)⎟           ⎜       d\phi⋅⎝\tilde{r}  + a ⎠⎟     2
#   Δᵣ⋅⎜dt - ───────────────⎟    Δₜₕₑₜₐ⋅⎜a⋅dt - ───────────────────────⎟ ⋅sin (θ
#      ⎝            Ξ       ⎠           ⎝                  Ξ           ⎠
# - ────────────────────────── + ───────────────────────────────────────────────
#               W                                       W
#
#
#
#
# )               2
#     W⋅d\tilde{r}
# ─ + ─────────────
#           Δᵣ

# %%
dt_val = sympy.I * dtau

# %%
euclidean_metric = metric_orig.subs({dt: dt_val}).expand().collect([dtau ** 2, dtau * dphi, dphi ** 2])
euclidean_metric
# Out:
#        ⎛      2    4                      4    2                        2  2
#      2 ⎜  Δᵣ⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅\tilde{r} ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a ⋅s
# d\phi ⋅⎜- ───────────── + ───────────────────────── + ────────────────────────
#        ⎜          2                     2                             2
#        ⎝       W⋅Ξ                   W⋅Ξ                           W⋅Ξ
#
#   2              4    2   ⎞               ⎛            2
# in (θ)   Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟               ⎜2⋅ⅈ⋅Δᵣ⋅a⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅\tild
# ────── + ─────────────────⎟ + d\phi⋅d\tau⋅⎜──────────────── - ────────────────
#                    2      ⎟               ⎝      W⋅Ξ                        W⋅
#                 W⋅Ξ       ⎠
#
#     2      2                  3    2   ⎞          ⎛             2    2   ⎞
# e{r} ⋅a⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟        2 ⎜Δᵣ   Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟   W
# ─────────────── - ─────────────────────⎟ + d\tau ⋅⎜── - ─────────────────⎟ + ─
# Ξ                          W⋅Ξ         ⎠          ⎝W            W        ⎠
#
#
#            2
# ⋅d\tilde{r}
# ────────────
#      Δᵣ

# %%
omega = sympy.symbols("Omega")
dphi_val = dphi_tilde + omega * dt_val
dphi_val
# Out:
# ⅈ⋅Ω⋅d\tau + d\tilde{\phi}

# %%
euclidean_metric_2 = euclidean_metric.subs({dphi: dphi_val}).expand().collect([dtau ** 2, dtau * dphi_tilde, dphi_tilde ** 2])
euclidean_metric_2
# Out:
#        ⎛    2  2    4                  2                   2          4    2
#      2 ⎜Δᵣ⋅Ω ⋅a ⋅sin (θ)   2⋅Δᵣ⋅Ω⋅a⋅sin (θ)   Δᵣ   Δₜₕₑₜₐ⋅Ω ⋅\tilde{r} ⋅sin (θ
# d\tau ⋅⎜──────────────── - ──────────────── + ── - ───────────────────────────
#        ⎜         2               W⋅Ξ          W                   2
#        ⎝      W⋅Ξ                                              W⋅Ξ
#
#               2          2  2    2              2  4    2
# )   2⋅Δₜₕₑₜₐ⋅Ω ⋅\tilde{r} ⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅Ω ⋅a ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅Ω⋅\til
# ─ - ───────────────────────────────── - ──────────────────── + ───────────────
#                       2                            2                         W
#                    W⋅Ξ                          W⋅Ξ
#
#      2      2                  3    2              2    2   ⎞
# de{r} ⋅a⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅Ω⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟
# ──────────────── + ───────────────────── - ─────────────────⎟ + d\tau⋅d\tilde{
# ⋅Ξ                          W⋅Ξ                    W        ⎟
#                                                             ⎠
#
#       ⎛            2    4                  2                            4    2
#       ⎜  2⋅ⅈ⋅Δᵣ⋅Ω⋅a ⋅sin (θ)   2⋅ⅈ⋅Δᵣ⋅a⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅Ω⋅\tilde{r} ⋅sin
# \phi}⋅⎜- ─────────────────── + ──────────────── + ────────────────────────────
#       ⎜             2                W⋅Ξ                           2
#       ⎝          W⋅Ξ                                            W⋅Ξ
#
#                             2  2    2                    4    2
# (θ)   4⋅ⅈ⋅Δₜₕₑₜₐ⋅Ω⋅\tilde{r} ⋅a ⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅Ω⋅a ⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜ
# ─── + ────────────────────────────────── + ─────────────────────── - ─────────
#                         2                               2
#                      W⋅Ξ                             W⋅Ξ
#
#            2      2                  3    2   ⎞                  ⎛      2    4
# ₐ⋅\tilde{r} ⋅a⋅sin (θ)   2⋅ⅈ⋅Δₜₕₑₜₐ⋅a ⋅sin (θ)⎟                2 ⎜  Δᵣ⋅a ⋅sin
# ────────────────────── - ─────────────────────⎟ + d\tilde{\phi} ⋅⎜- ──────────
#      W⋅Ξ                          W⋅Ξ         ⎟                  ⎜          2
#                                               ⎠                  ⎝       W⋅Ξ
#
#                       4    2                        2  2    2              4
# (θ)   Δₜₕₑₜₐ⋅\tilde{r} ⋅sin (θ)   2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a ⋅sin (θ)   Δₜₕₑₜₐ⋅a ⋅s
# ─── + ───────────────────────── + ────────────────────────────── + ───────────
#                     2                             2                          2
#                  W⋅Ξ                           W⋅Ξ                        W⋅Ξ
#
#   2   ⎞               2
# in (θ)⎟   W⋅d\tilde{r}
# ──────⎟ + ─────────────
#       ⎟         Δᵣ
#       ⎠

# %%
metric_list_matrix = [[0 for i in range(3)] for i in range(3)]

# tau
metric_list_matrix[0][0] = euclidean_metric_2.coeff(dtau ** 2)
metric_list_matrix[0][1] = euclidean_metric_2.coeff(dtau * dr_tilde) / 2
metric_list_matrix[0][2] = euclidean_metric_2.coeff(dtau * dphi_tilde) / 2

# r_tilde
metric_list_matrix[1][0] = euclidean_metric_2.coeff(dr_tilde * dtau) / 2
metric_list_matrix[1][1] = euclidean_metric_2.coeff(dr_tilde ** 2)
metric_list_matrix[1][2] = euclidean_metric_2.coeff(dr_tilde * dphi_tilde) / 2

# phi_tilde
metric_list_matrix[2][0] = euclidean_metric_2.coeff(dphi_tilde * dtau) / 2
metric_list_matrix[2][1] = euclidean_metric_2.coeff(dphi_tilde * dr_tilde) / 2
metric_list_matrix[2][2] = euclidean_metric_2.coeff(dphi_tilde ** 2)

# %%
g_mat = sympy.Matrix(metric_list_matrix)
g_mat.simplify()
g_mat
# Out:
# ⎡ 2 ⎛    2    2                      4                     2  2           4⎞
# ⎢Ω ⋅⎝Δᵣ⋅a ⋅sin (θ) - Δₜₕₑₜₐ⋅\tilde{r}  - 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  - Δₜₕₑₜₐ⋅a ⎠⋅s
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                     ⎛  ⎛      2    2                      4
# ⎢                   ⅈ⋅⎝Ω⋅⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\tilde{r}  + 2⋅Δₜₕₑₜₐ⋅\tild
# ⎢                   ──────────────────────────────────────────────────────────
# ⎢
# ⎣
#
#   2              ⎛                      2           2⎞    2       2 ⎛
# in (θ) + 2⋅Ω⋅Ξ⋅a⋅⎝-Δᵣ + Δₜₕₑₜₐ⋅\tilde{r}  + Δₜₕₑₜₐ⋅a ⎠⋅sin (θ) + Ξ ⋅⎝Δᵣ - Δₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#          2
#       W⋅Ξ
#
#
#        0
#
#
#     2  2           4⎞       ⎛                     2           2⎞⎞    2
# e{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠ + Ξ⋅a⋅⎝Δᵣ - Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⎠⋅sin (θ)
# ─────────────────────────────────────────────────────────────────────────
#          2
#       W⋅Ξ
#
#     2    2   ⎞        ⎛  ⎛      2    2                      4
# ₜₐ⋅a ⋅sin (θ)⎠      ⅈ⋅⎝Ω⋅⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\tilde{r}  + 2⋅Δₜₕₑₜₐ⋅\tild
# ──────────────  0   ──────────────────────────────────────────────────────────
#
#
#
#                 W
#                 ──
#                 Δᵣ
#
#                                             ⎛      2    2
#                                             ⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\tilde{r
#                 0                           ──────────────────────────────────
#
#
#
#     2  2           4⎞       ⎛                     2           2⎞⎞    2   ⎤
# e{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠ + Ξ⋅a⋅⎝Δᵣ - Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⎠⋅sin (θ)⎥
# ─────────────────────────────────────────────────────────────────────────⎥
#          2                                                               ⎥
#       W⋅Ξ                                                                ⎥
#                                                                          ⎥
#                                                                          ⎥
#        0                                                                 ⎥
#                                                                          ⎥
#                                                                          ⎥
#  4                     2  2           4⎞    2                            ⎥
# }  + 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠⋅sin (θ)                         ⎥
# ────────────────────────────────────────────────                         ⎥
#         2                                                                ⎥
#      W⋅Ξ                                                                 ⎦

# %%
g_mat.det().simplify()
# Out:
#                                 2
#        ⎛         2    2    2   ⎞     2
# Δₜₕₑₜₐ⋅⎝\tilde{r}  + a ⋅cos (θ)⎠ ⋅sin (θ)
# ─────────────────────────────────────────
#                       2
#                    W⋅Ξ

# %% [markdown]
# ### Generic Metric

# %%
A, B, C, D, E, F, G, H = sympy.symbols("A B C D E F G H")

# %%
g_mat_simp = sympy.Matrix([[A + sympy.I * B, C + sympy.I * D, 0], [C + sympy.I * D, E + sympy.I * F, 0], [0, 0, G + sympy.I * H]])
g_mat_simp
# Out:
# ⎡A + ⅈ⋅B  C + ⅈ⋅D     0   ⎤
# ⎢                         ⎥
# ⎢C + ⅈ⋅D  E + ⅈ⋅F     0   ⎥
# ⎢                         ⎥
# ⎣   0        0     G + ⅈ⋅H⎦

# %%
det_g = g_mat_simp.det().simplify().collect(sympy.I)
det_g
# Out:
#                                  2                2       ⎛
# A⋅E⋅G - A⋅F⋅H - B⋅E⋅H - B⋅F⋅G - C ⋅G + 2⋅C⋅D⋅H + D ⋅G + ⅈ⋅⎝A⋅E⋅H + A⋅F⋅G + B⋅E
#
#               2                2  ⎞
# ⋅G - B⋅F⋅H - C ⋅H - 2⋅C⋅D⋅G + D ⋅H⎠

# %%
det_g_imag_part = det_g.coeff(sympy.I)
det_g_imag_part
# Out:
#                                  2                2
# A⋅E⋅H + A⋅F⋅G + B⋅E⋅G - B⋅F⋅H - C ⋅H - 2⋅C⋅D⋅G + D ⋅H

# %%
det_g_real_part = det_g - sympy.I * det_g_imag_part
det_g_real_part
# Out:
#                                  2                2
# A⋅E⋅G - A⋅F⋅H - B⋅E⋅H - B⋅F⋅G - C ⋅G + 2⋅C⋅D⋅H + D ⋅G

# %%
C_sol = sympy.solve(det_g_imag_part, C)[0]
C_sol
# Out:
#           _____________________________________________________
#          ╱      2                            2    2  2    2  2
# -D⋅G - ╲╱  A⋅E⋅H  + A⋅F⋅G⋅H + B⋅E⋅G⋅H - B⋅F⋅H  + D ⋅G  + D ⋅H
# ───────────────────────────────────────────────────────────────
#                                H

# %%
gamma = sympy.symbols("gamma")
gamma_val = C_sol.args[1].args[0].args[1].args[0]
gamma_val
# Out:
#      2                            2    2  2    2  2
# A⋅E⋅H  + A⋅F⋅G⋅H + B⋅E⋅G⋅H - B⋅F⋅H  + D ⋅G  + D ⋅H

# %%
C_sol_gamma = (-D * G - sympy.sqrt(gamma)) / H
C_sol_gamma
# Out:
# -D⋅G - √γ
# ─────────
#     H

# %%
epsilon = sympy.symbols("epsilon")

# %%
det_g_real_part.subs({C: C_sol_gamma}).expand().simplify()
# Out:
#    2  3        2             2 ⎛                                 2           ⎞
# - D ⋅G  - 2⋅D⋅G ⋅√γ - G⋅γ + H ⋅⎝A⋅E⋅G - A⋅F⋅H - B⋅E⋅H - B⋅F⋅G - D ⋅G - 2⋅D⋅√γ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                        2
#                                       H

# %%
epsilon_val = det_g_real_part.subs({C: C_sol_gamma}).expand().simplify() * H ** 2
epsilon_val
# Out:
#    2  3        2             2 ⎛                                 2           ⎞
# - D ⋅G  - 2⋅D⋅G ⋅√γ - G⋅γ + H ⋅⎝A⋅E⋅G - A⋅F⋅H - B⋅E⋅H - B⋅F⋅G - D ⋅G - 2⋅D⋅√γ⎠

# %%
g_mat_real_simp = sympy.Matrix([[A, C, 0], [C, E, 0], [0, 0, G]])
g_mat_real_simp
# Out:
# ⎡A  C  0⎤
# ⎢       ⎥
# ⎢C  E  0⎥
# ⎢       ⎥
# ⎣0  0  G⎦

# %%
g_mat_real_simp.eigenvals()
# Out:
# ⎧                 ________________________                ____________________
# ⎪                ╱  2              2    2                ╱  2              2
# ⎨      A   E   ╲╱  A  - 2⋅A⋅E + 4⋅C  + E       A   E   ╲╱  A  - 2⋅A⋅E + 4⋅C  +
# ⎪G: 1, ─ + ─ - ───────────────────────────: 1, ─ + ─ + ───────────────────────
# ⎩      2   2                2                  2   2                2
#
# ____   ⎫
#   2    ⎪
#  E     ⎬
# ────: 1⎪
#        ⎭

# %%
((A + E) ** 2 / 4 - (C ** 2 + (A - E) ** 2 / 4)).simplify()
# Out:
#        2
# A⋅E - C

# %%
sympy.fraction((A * E - C ** 2).subs({C: C_sol_gamma}).expand().simplify())[0].simplify()
# Out:
#      2    2  2
# A⋅E⋅H  - D ⋅G  - 2⋅D⋅G⋅√γ - γ

# %%
g_mat_simp.eigenvals()
# Out:
# ⎧                                  ___________________________________________
# ⎪            A   ⅈ⋅B   E   ⅈ⋅F   ╲╱ (A + ⅈ⋅B - 2⋅ⅈ⋅C + 2⋅D - E - ⅈ⋅F)⋅(A + ⅈ⋅B
# ⎨G + ⅈ⋅H: 1, ─ + ─── + ─ + ─── - ─────────────────────────────────────────────
# ⎪            2    2    2    2                                       2
# ⎩
#
# __________________________                           _________________________
#  + 2⋅ⅈ⋅C - 2⋅D - E - ⅈ⋅F)      A   ⅈ⋅B   E   ⅈ⋅F   ╲╱ (A + ⅈ⋅B - 2⋅ⅈ⋅C + 2⋅D -
# ──────────────────────────: 1, ─ + ─── + ─ + ─── + ───────────────────────────
#                                2    2    2    2
#
#
# ____________________________________________   ⎫
#  E - ⅈ⋅F)⋅(A + ⅈ⋅B + 2⋅ⅈ⋅C - 2⋅D - E - ⅈ⋅F)    ⎪
# ────────────────────────────────────────────: 1⎬
#         2                                      ⎪
#                                                ⎭

# %%
list(g_mat_simp.eigenvals().keys())[0].args[2].args[1].args[0].simplify().expand().collect(sympy.I)
# Out:
#  2            2              2      2    2    2
# A  - 2⋅A⋅E - B  + 2⋅B⋅F + 4⋅C  - 4⋅D  + E  - F  + ⅈ⋅(2⋅A⋅B - 2⋅A⋅F - 2⋅B⋅E + 8
#
#
# ⋅C⋅D + 2⋅E⋅F)

# %%
real_part_discrim = (A - E) ** 2 - (B - F) ** 2 + 4 * (C ** 2 - D ** 2)
real_part_discrim
# Out:
#    2      2          2          2
# 4⋅C  - 4⋅D  + (A - E)  - (B - F)

# %%
imag_part_discrim = 2 * ((A - E) * (B - F) + 4 * C * D)
imag_part_discrim
# Out:
# 8⋅C⋅D + 2⋅(A - E)⋅(B - F)

# %%
real_part_discrim.subs({C: sympy.solve(imag_part_discrim, C)[0]}).expand().simplify().factor()
# Out:
#                             ⎛ 2              2    2⎞
# (A - 2⋅D - E)⋅(A + 2⋅D - E)⋅⎝B  - 2⋅B⋅F + 4⋅D  + F ⎠
# ────────────────────────────────────────────────────
#                            2
#                         4⋅D

# %% [markdown]
# ### Generic Metric Inverse

# %%
g_mat_simp_inv = g_mat_simp.inv()
g_mat_simp_inv.simplify()
g_mat_simp_inv
# Out:
# ⎡                   E + ⅈ⋅F                                        -C - ⅈ⋅D
# ⎢─────────────────────────────────────────────  ──────────────────────────────
# ⎢                             2              2                               2
# ⎢A⋅E + ⅈ⋅A⋅F + ⅈ⋅B⋅E - B⋅F - C  - 2⋅ⅈ⋅C⋅D + D   A⋅E + ⅈ⋅A⋅F + ⅈ⋅B⋅E - B⋅F - C
# ⎢
# ⎢                   -C - ⅈ⋅D                                       A + ⅈ⋅B
# ⎢─────────────────────────────────────────────  ──────────────────────────────
# ⎢                             2              2                               2
# ⎢A⋅E + ⅈ⋅A⋅F + ⅈ⋅B⋅E - B⋅F - C  - 2⋅ⅈ⋅C⋅D + D   A⋅E + ⅈ⋅A⋅F + ⅈ⋅B⋅E - B⋅F - C
# ⎢
# ⎢
# ⎢                      0                                              0
# ⎣
#
#                         ⎤
# ───────────────     0   ⎥
#               2         ⎥
#  - 2⋅ⅈ⋅C⋅D + D          ⎥
#                         ⎥
#                         ⎥
# ───────────────     0   ⎥
#               2         ⎥
#  - 2⋅ⅈ⋅C⋅D + D          ⎥
#                         ⎥
#                     1   ⎥
#                  ───────⎥
#                  G + ⅈ⋅H⎦

# %%
denom = g_mat_simp_inv[0, 0].args[0].args[0].collect(sympy.I)
denom
# Out:
#              2    2
# A⋅E - B⋅F - C  + D  + ⅈ⋅(A⋅F + B⋅E - 2⋅C⋅D)

# %%
denom_conj = A * E - B * F - C ** 2 + D ** 2 - sympy.I * (A * F + B * E - 2 * C * D)
denom_conj
# Out:
#              2    2
# A⋅E - B⋅F - C  + D  - ⅈ⋅(A⋅F + B⋅E - 2⋅C⋅D)

# %%
kappa, delta = sympy.symbols("kappa delta")
kappa_val = (denom * denom_conj).expand().simplify().factor()
kappa_val
# Out:
#  2  2    2  2        2                      2      2  2    2  2        2
# A ⋅E  + A ⋅F  - 2⋅A⋅C ⋅E - 4⋅A⋅C⋅D⋅F + 2⋅A⋅D ⋅E + B ⋅E  + B ⋅F  + 2⋅B⋅C ⋅F - 4
#
#                 2      4      2  2    4
# ⋅B⋅C⋅D⋅E - 2⋅B⋅D ⋅F + C  + 2⋅C ⋅D  + D

# %%
delta_val = G ** 2 + H ** 2
delta_val
# Out:
#  2    2
# G  + H

# %%
metric_list_matrix = [[0 for i in range(3)] for i in range(3)]

metric_list_matrix[0][0] = ((E + sympy.I * F) * denom_conj).expand().simplify().collect(sympy.I) / kappa
metric_list_matrix[0][1] = ((-C - sympy.I * D) * denom_conj).expand().simplify().collect(sympy.I) / kappa
metric_list_matrix[1][0] = ((-C - sympy.I * D) * denom_conj).expand().simplify().collect(sympy.I) / kappa
metric_list_matrix[1][1] = ((A + sympy.I * B) * denom_conj).expand().simplify().collect(sympy.I) / kappa
metric_list_matrix[2][2] = (G - sympy.I * H) / delta

g_mat_simp_inv = sympy.Matrix(metric_list_matrix)
g_mat_simp_inv
# Out:
# ⎡        2      2    2                2       ⎛     2      2    2
# ⎢     A⋅E  + A⋅F  - C ⋅E - 2⋅C⋅D⋅F + D ⋅E + ⅈ⋅⎝- B⋅E  - B⋅F  - C ⋅F + 2⋅C⋅D⋅E
# ⎢     ────────────────────────────────────────────────────────────────────────
# ⎢                                            κ
# ⎢
# ⎢                                  3      2     ⎛
# ⎢-A⋅C⋅E - A⋅D⋅F + B⋅C⋅F - B⋅D⋅E + C  + C⋅D  + ⅈ⋅⎝A⋅C⋅F - A⋅D⋅E + B⋅C⋅E + B⋅D⋅F
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                                            κ
# ⎢
# ⎢
# ⎢                                            0
# ⎣
#
#    2  ⎞                                          3      2     ⎛
# + D ⋅F⎠        -A⋅C⋅E - A⋅D⋅F + B⋅C⋅F - B⋅D⋅E + C  + C⋅D  + ⅈ⋅⎝A⋅C⋅F - A⋅D⋅E +
# ───────        ───────────────────────────────────────────────────────────────
#                                                            κ
#
#     2      3⎞        2        2      2    2                 ⎛   2
#  - C ⋅D - D ⎠       A ⋅E - A⋅C  + A⋅D  + B ⋅E - 2⋅B⋅C⋅D + ⅈ⋅⎝- A ⋅F + 2⋅A⋅C⋅D
# ─────────────       ──────────────────────────────────────────────────────────
#                                                            κ
#
#
#                                                            0
#
#
#                   2      3⎞         ⎤
#  B⋅C⋅E + B⋅D⋅F - C ⋅D - D ⎠         ⎥
# ───────────────────────────     0   ⎥
#                                     ⎥
#                                     ⎥
#    2        2      2⎞               ⎥
# - B ⋅F - B⋅C  + B⋅D ⎠               ⎥
# ─────────────────────           0   ⎥
#                                     ⎥
#                                     ⎥
#                              G - ⅈ⋅H⎥
#                              ───────⎥
#                                 δ   ⎦

# %%
id = g_mat_simp_inv.subs({kappa: kappa_val, delta: delta_val}) @ g_mat_simp
id.simplify()
id
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  1  0⎥
# ⎢       ⎥
# ⎣0  0  1⎦

# %%
g_mat_real_simp_inv = [
    [(A * E ** 2 + A * F ** 2 - C ** 2 * E - 2 * C * D * F + D ** 2 * E) / kappa, (-A * C * E - A * D * F + B * C * F - B * D * E + C ** 3 + C * D ** 2) / kappa, 0],
    [(-A * C * E - A * D * F + B * C * F - B * D * E + C ** 3 + C * D ** 2) / kappa, (A ** 2 * E - A * C ** 2 + A * D ** 2 + B ** 2 * E - 2 * B * C * D) / kappa, 0],
    [0, 0, G / delta]
]
g_mat_real_simp_inv = sympy.Matrix(g_mat_real_simp_inv)
g_mat_real_simp_inv
# Out:
# ⎡      2      2    2                2
# ⎢   A⋅E  + A⋅F  - C ⋅E - 2⋅C⋅D⋅F + D ⋅E      -A⋅C⋅E - A⋅D⋅F + B⋅C⋅F - B⋅D⋅E +
# ⎢   ───────────────────────────────────      ─────────────────────────────────
# ⎢                    κ                                           κ
# ⎢
# ⎢                                  3      2      2        2      2    2
# ⎢-A⋅C⋅E - A⋅D⋅F + B⋅C⋅F - B⋅D⋅E + C  + C⋅D      A ⋅E - A⋅C  + A⋅D  + B ⋅E - 2⋅
# ⎢──────────────────────────────────────────     ──────────────────────────────
# ⎢                    κ                                           κ
# ⎢
# ⎢
# ⎢                    0                                           0
# ⎣
#
#  3      2   ⎤
# C  + C⋅D    ⎥
# ─────────  0⎥
#             ⎥
#             ⎥
#             ⎥
# B⋅C⋅D       ⎥
# ─────      0⎥
#             ⎥
#             ⎥
#            G⎥
#            ─⎥
#            δ⎦

# %%
z = (g_mat_real_simp_inv[0, 0] * g_mat_real_simp_inv[1, 1] * kappa ** 2 - (g_mat_real_simp_inv[0, 1] * kappa) ** 2).expand().factor()
z
# Out:
# ⎛       2⎞ ⎛ 2  2    2  2        2                      2      2  2    2  2
# ⎝A⋅E - C ⎠⋅⎝A ⋅E  + A ⋅F  - 2⋅A⋅C ⋅E - 4⋅A⋅C⋅D⋅F + 2⋅A⋅D ⋅E + B ⋅E  + B ⋅F  +
#
#      2                      2      4      2  2    4⎞
# 2⋅B⋅C ⋅F - 4⋅B⋅C⋅D⋅E - 2⋅B⋅D ⋅F + C  + 2⋅C ⋅D  + D ⎠

# %%
z_simp = (A * E - C ** 2) * ((A * F + B * E - 2 * C * D) ** 2 + (A * E - B * F - C ** 2 + D ** 2) ** 2)
z_simp
# Out:
#            ⎛                                            2⎞
# ⎛       2⎞ ⎜                   2   ⎛             2    2⎞ ⎟
# ⎝A⋅E - C ⎠⋅⎝(A⋅F + B⋅E - 2⋅C⋅D)  + ⎝A⋅E - B⋅F - C  + D ⎠ ⎠

# %%
(z_simp - z).simplify()
# Out:
# 0

# %% [markdown]
# This is an expression for $D^2G^2 + 2DG\sqrt{\gamma} + \gamma$.

# %%
discrim_dg = (-epsilon + H ** 2 * (A * E * G - A * F * H - B * E * H - B * F * G - D ** 2 * G - 2 * D * sympy.sqrt(gamma))) / G
discrim_dg
# Out:
#  2 ⎛                                 2           ⎞
# H ⋅⎝A⋅E⋅G - A⋅F⋅H - B⋅E⋅H - B⋅F⋅G - D ⋅G - 2⋅D⋅√γ⎠ - ε
# ──────────────────────────────────────────────────────
#                           G

# %% [markdown]
# #### $g_{00}$ Condition

# %%
g_00_cond = sympy.fraction(g_mat_real_simp_inv[0, 0].subs({C: C_sol_gamma}).expand().simplify())[0]
g_00_cond
# Out:
#                        ⎛ 2  2               ⎞    2 ⎛   2      2    2  ⎞
# 2⋅D⋅F⋅H⋅(D⋅G + √γ) - E⋅⎝D ⋅G  + 2⋅D⋅G⋅√γ + γ⎠ + H ⋅⎝A⋅E  + A⋅F  + D ⋅E⎠

# %%
g_00_cond = sympy.fraction(g_00_cond.subs({D ** 2 * G ** 2 + 2 * D * G * sympy.sqrt(gamma) + gamma: discrim_dg}).expand().simplify())[0]
g_00_cond
# Out:
#        3      2  3          2                ⎛   2                  2
# A⋅E⋅F⋅H  + B⋅E ⋅H  + 2⋅D⋅E⋅H ⋅√γ + E⋅ε + G⋅H⋅⎝A⋅F ⋅H + B⋅E⋅F⋅H + 2⋅D ⋅E⋅H + 2⋅
#
#  2               ⎞
# D ⋅F⋅G + 2⋅D⋅F⋅√γ⎠

# %%
g_00_cond = E * epsilon + sum(g_00_cond.args[1:]).factor()
g_00_cond
# Out:
#                     ⎛                   2           ⎞
# E⋅ε + H⋅(E⋅H + F⋅G)⋅⎝A⋅F⋅H + B⋅E⋅H + 2⋅D ⋅G + 2⋅D⋅√γ⎠

# %% [markdown]
# #### $g_{11}$ Condition

# %%
g_11_cond = sympy.fraction(g_mat_real_simp_inv[1, 1].subs({C: C_sol_gamma}).expand().simplify())[0]
g_11_cond
# Out:
#     ⎛ 2  2               ⎞                         2 ⎛ 2        2    2  ⎞
# - A⋅⎝D ⋅G  + 2⋅D⋅G⋅√γ + γ⎠ + 2⋅B⋅D⋅H⋅(D⋅G + √γ) + H ⋅⎝A ⋅E + A⋅D  + B ⋅E⎠

# %%
g_11_cond = sympy.fraction(g_11_cond.subs({D ** 2 * G ** 2 + 2 * D * G * sympy.sqrt(gamma) + gamma: discrim_dg}).expand().simplify())[0]
g_11_cond
# Out:
#  2    3          3          2                ⎛               2      2
# A ⋅F⋅H  + A⋅B⋅E⋅H  + 2⋅A⋅D⋅H ⋅√γ + A⋅ε + G⋅H⋅⎝A⋅B⋅F⋅H + 2⋅A⋅D ⋅H + B ⋅E⋅H + 2⋅
#
#    2             ⎞
# B⋅D ⋅G + 2⋅B⋅D⋅√γ⎠

# %%
g_11_cond = (g_11_cond.args[1] + g_11_cond.args[2] + g_11_cond.args[3] + g_11_cond.args[4]).factor() + A * epsilon
g_11_cond
# Out:
#                     ⎛                   2           ⎞
# A⋅ε + H⋅(A⋅H + B⋅G)⋅⎝A⋅F⋅H + B⋅E⋅H + 2⋅D ⋅G + 2⋅D⋅√γ⎠

# %% [markdown]
# #### Eigenvalues

# %%
I, K, M = sympy.symbols("I K M")

g_mat_real_simp_inv_2 = sympy.Matrix([
    [I / kappa, K / kappa, 0],
    [K / kappa, M / kappa, 0],
    [0, 0, G / delta]
])

g_mat_real_simp_inv_2
# Out:
# ⎡I  K   ⎤
# ⎢─  ─  0⎥
# ⎢κ  κ   ⎥
# ⎢       ⎥
# ⎢K  M   ⎥
# ⎢─  ─  0⎥
# ⎢κ  κ   ⎥
# ⎢       ⎥
# ⎢      G⎥
# ⎢0  0  ─⎥
# ⎣      δ⎦

# %%
g_mat_real_simp_inv_2.eigenvals()
# Out:
# ⎧                 ________________________                ____________________
# ⎪                ╱  2              2    2                ╱  2              2
# ⎨G     I + M   ╲╱  I  - 2⋅I⋅M + 4⋅K  + M       I + M   ╲╱  I  - 2⋅I⋅M + 4⋅K  +
# ⎪─: 1, ───── - ───────────────────────────: 1, ───── + ───────────────────────
# ⎩δ      2⋅κ                2⋅κ                  2⋅κ                2⋅κ
#
# ____   ⎫
#   2    ⎪
#  M     ⎬
# ────: 1⎪
#        ⎭

# %%
g_mat_real_simp_inv.eigenvals()
# Out:
# ⎧
# ⎪       2        2      2      2      2    2                2                2
# ⎨G     A ⋅E - A⋅C  + A⋅D  + A⋅E  + A⋅F  + B ⋅E - 2⋅B⋅C⋅D - C ⋅E - 2⋅C⋅D⋅F + D
# ⎪─: 1, ───────────────────────────────────────────────────────────────────────
# ⎩δ                                        2⋅κ
#
#         ______________________________________________________________________
#        ╱  4  2      3  2        3  2        3  3      3    2      2  2  2
# ⋅E   ╲╱  A ⋅E  - 2⋅A ⋅C ⋅E + 2⋅A ⋅D ⋅E - 2⋅A ⋅E  - 2⋅A ⋅E⋅F  + 2⋅A ⋅B ⋅E  - 4⋅
# ── - ─────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#  2            2  4      2  2  2      2  2  2      2  2  2       2            2
# A ⋅B⋅C⋅D⋅E + A ⋅C  - 2⋅A ⋅C ⋅D  + 8⋅A ⋅C ⋅E  + 2⋅A ⋅C ⋅F  + 12⋅A ⋅C⋅D⋅E⋅F + A
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#   4      2  2  2      2  2  2    2  4      2  2  2    2  4        2  2
# ⋅D  - 4⋅A ⋅D ⋅E  + 2⋅A ⋅D ⋅F  + A ⋅E  + 2⋅A ⋅E ⋅F  + A ⋅F  - 2⋅A⋅B ⋅C ⋅E + 2⋅A
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#   2  2          2  3        2    2          3            2                3
# ⋅B ⋅D ⋅E - 2⋅A⋅B ⋅E  - 2⋅A⋅B ⋅E⋅F  + 4⋅A⋅B⋅C ⋅D - 8⋅A⋅B⋅C ⋅E⋅F - 4⋅A⋅B⋅C⋅D  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#             2              2          2             4           3            2
# 12⋅A⋅B⋅C⋅D⋅E  - 4⋅A⋅B⋅C⋅D⋅F  + 8⋅A⋅B⋅D ⋅E⋅F - 10⋅A⋅C ⋅E - 12⋅A⋅C ⋅D⋅F - 4⋅A⋅C
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2⋅κ
#
# ______________________________________________________________________________
#   2          2  3        2    2          3              2              3
# ⋅D ⋅E - 2⋅A⋅C ⋅E  - 2⋅A⋅C ⋅E⋅F  - 4⋅A⋅C⋅D ⋅F - 4⋅A⋅C⋅D⋅E ⋅F - 4⋅A⋅C⋅D⋅F  - 2⋅A
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#   4          2  3        2    2    4  2      3            2  2  2      2  2  2
# ⋅D ⋅E + 2⋅A⋅D ⋅E  + 2⋅A⋅D ⋅E⋅F  + B ⋅E  - 4⋅B ⋅C⋅D⋅E + 4⋅B ⋅C ⋅D  + 2⋅B ⋅C ⋅E
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#       2  2  2      2              2  2  2        4           3              3
#  + 4⋅B ⋅C ⋅F  - 4⋅B ⋅C⋅D⋅E⋅F + 2⋅B ⋅D ⋅E  + 8⋅B⋅C ⋅F - 12⋅B⋅C ⋅D⋅E - 4⋅B⋅C⋅D ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#        6      4  2    4  2      3            2  4      2  2  2      2  2  2
# E + 4⋅C  + 8⋅C ⋅D  + C ⋅E  + 4⋅C ⋅D⋅E⋅F + 4⋅C ⋅D  - 2⋅C ⋅D ⋅E  + 4⋅C ⋅D ⋅F  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ___________________
#      3        4  2       2        2      2      2      2    2                2
# 4⋅C⋅D ⋅E⋅F + D ⋅E       A ⋅E - A⋅C  + A⋅D  + A⋅E  + A⋅F  + B ⋅E - 2⋅B⋅C⋅D - C
# ───────────────────: 1, ──────────────────────────────────────────────────────
#                                                            2⋅κ
#
#                          _____________________________________________________
#                 2       ╱  4  2      3  2        3  2        3  3      3    2
# ⋅E - 2⋅C⋅D⋅F + D ⋅E   ╲╱  A ⋅E  - 2⋅A ⋅C ⋅E + 2⋅A ⋅D ⋅E - 2⋅A ⋅E  - 2⋅A ⋅E⋅F
# ─────────────────── + ────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#      2  2  2      2            2  4      2  2  2      2  2  2      2  2  2
# + 2⋅A ⋅B ⋅E  - 4⋅A ⋅B⋅C⋅D⋅E + A ⋅C  - 2⋅A ⋅C ⋅D  + 8⋅A ⋅C ⋅E  + 2⋅A ⋅C ⋅F  + 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#    2            2  4      2  2  2      2  2  2    2  4      2  2  2    2  4
# 2⋅A ⋅C⋅D⋅E⋅F + A ⋅D  - 4⋅A ⋅D ⋅E  + 2⋅A ⋅D ⋅F  + A ⋅E  + 2⋅A ⋅E ⋅F  + A ⋅F  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#      2  2          2  2          2  3        2    2          3            2
# 2⋅A⋅B ⋅C ⋅E + 2⋅A⋅B ⋅D ⋅E - 2⋅A⋅B ⋅E  - 2⋅A⋅B ⋅E⋅F  + 4⋅A⋅B⋅C ⋅D - 8⋅A⋅B⋅C ⋅E⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#              3               2              2          2             4
# F - 4⋅A⋅B⋅C⋅D  + 12⋅A⋅B⋅C⋅D⋅E  - 4⋅A⋅B⋅C⋅D⋅F  + 8⋅A⋅B⋅D ⋅E⋅F - 10⋅A⋅C ⋅E - 12⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                                   2⋅κ
#
# ______________________________________________________________________________
#    3            2  2          2  3        2    2          3              2
# A⋅C ⋅D⋅F - 4⋅A⋅C ⋅D ⋅E - 2⋅A⋅C ⋅E  - 2⋅A⋅C ⋅E⋅F  - 4⋅A⋅C⋅D ⋅F - 4⋅A⋅C⋅D⋅E ⋅F -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#           3        4          2  3        2    2    4  2      3            2
#  4⋅A⋅C⋅D⋅F  - 2⋅A⋅D ⋅E + 2⋅A⋅D ⋅E  + 2⋅A⋅D ⋅E⋅F  + B ⋅E  - 4⋅B ⋅C⋅D⋅E + 4⋅B ⋅C
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
# 2  2      2  2  2      2  2  2      2              2  2  2        4
#  ⋅D  + 2⋅B ⋅C ⋅E  + 4⋅B ⋅C ⋅F  - 4⋅B ⋅C⋅D⋅E⋅F + 2⋅B ⋅D ⋅E  + 8⋅B⋅C ⋅F - 12⋅B⋅C
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
# 3              3        6      4  2    4  2      3            2  4      2  2
#  ⋅D⋅E - 4⋅B⋅C⋅D ⋅E + 4⋅C  + 8⋅C ⋅D  + C ⋅E  + 4⋅C ⋅D⋅E⋅F + 4⋅C ⋅D  - 2⋅C ⋅D ⋅E
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ____________________________________   ⎫
# 2      2  2  2        3        4  2    ⎪
#   + 4⋅C ⋅D ⋅F  - 4⋅C⋅D ⋅E⋅F + D ⋅E     ⎬
# ────────────────────────────────────: 1⎪
#                                        ⎭

# %% [markdown]
# #### Numerical Evaluation

# %%
from tqdm import tqdm

bad_matrices = []
sampled_matrices = []
num_sampled_matrices = 0

for i in tqdm(range(10000)):
    # A, E, G > 0
    A_val, E_val, G_val = np.random.uniform(0, 5, size=3)

    # sample imaginary parts
    B_val, D_val, F_val, H_val = np.random.uniform(-5, 5, size=4)

    # C_val = np.random.uniform(-5, 5)
    gamma_val_i = gamma_val.subs({A: A_val, B: B_val, D: D_val, E: E_val, F: F_val, G: G_val, H: H_val}).evalf()
    if gamma_val_i < 0:
        continue
    C_val = ((-D_val * G_val - sympy.sqrt(gamma_val_i)) / H_val).evalf()

    if A_val * E_val < C_val ** 2:
        # it needs to satisfy AE > C^2
        continue

    epsilon_val_i = epsilon_val.subs({A: A_val, B: B_val, C: C_val, D: D_val, E: E_val, F: F_val, G: G_val, H: H_val, gamma: gamma_val_i}).evalf()
    if epsilon_val_i > 0:
        continue

    g_mat_1 = sympy.Matrix([
        [A_val + sympy.I * B_val, C_val + sympy.I * D_val, 0],
        [C_val + sympy.I * D_val, E_val + sympy.I * F_val, 0],
        [0, 0, G_val + sympy.I * H_val]
    ])

    det = g_mat_1.det().evalf()

    g_mat_1_inv = g_mat_1.inv()

    A_val_inv = g_mat_1_inv[0, 0].args[0]
    C_val_inv = g_mat_1_inv[0, 1].args[0]
    E_val_inv = g_mat_1_inv[1, 1].args[0]
    G_val_inv = g_mat_1_inv[2, 2].args[0]
    cond = A_val_inv < 0 or E_val_inv < 0 or G_val_inv < 0 or A_val_inv * E_val_inv < C_val_inv ** 2

    num_sampled_matrices += 1
    sampled_matrices.append([g_mat_1, g_mat_1_inv, det])

    if cond:
        print([g_mat_1, g_mat_1_inv, det])
        bad_matrices.append([g_mat_1, g_mat_1_inv, det])
        break
# Out:
# 100%|██████████| 10000/10000 [01:01<00:00, 162.22it/s]

# %%
print(len(bad_matrices))
print(num_sampled_matrices)
# Out:
# 0
# 222300

# %% [markdown]
# ### BH Metric

# %%
g_mat.det().simplify()
# Out:
#                                 2
#        ⎛         2    2    2   ⎞     2
# Δₜₕₑₜₐ⋅⎝\tilde{r}  + a ⋅cos (θ)⎠ ⋅sin (θ)
# ─────────────────────────────────────────
#                       2
#                    W⋅Ξ

# %%
g_mat
# Out:
# ⎡ 2 ⎛    2    2                      4                     2  2           4⎞
# ⎢Ω ⋅⎝Δᵣ⋅a ⋅sin (θ) - Δₜₕₑₜₐ⋅\tilde{r}  - 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  - Δₜₕₑₜₐ⋅a ⎠⋅s
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                     ⎛  ⎛      2    2                      4
# ⎢                   ⅈ⋅⎝Ω⋅⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\tilde{r}  + 2⋅Δₜₕₑₜₐ⋅\tild
# ⎢                   ──────────────────────────────────────────────────────────
# ⎢
# ⎣
#
#   2              ⎛                      2           2⎞    2       2 ⎛
# in (θ) + 2⋅Ω⋅Ξ⋅a⋅⎝-Δᵣ + Δₜₕₑₜₐ⋅\tilde{r}  + Δₜₕₑₜₐ⋅a ⎠⋅sin (θ) + Ξ ⋅⎝Δᵣ - Δₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#          2
#       W⋅Ξ
#
#
#        0
#
#
#     2  2           4⎞       ⎛                     2           2⎞⎞    2
# e{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠ + Ξ⋅a⋅⎝Δᵣ - Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⎠⋅sin (θ)
# ─────────────────────────────────────────────────────────────────────────
#          2
#       W⋅Ξ
#
#     2    2   ⎞        ⎛  ⎛      2    2                      4
# ₜₐ⋅a ⋅sin (θ)⎠      ⅈ⋅⎝Ω⋅⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\tilde{r}  + 2⋅Δₜₕₑₜₐ⋅\tild
# ──────────────  0   ──────────────────────────────────────────────────────────
#
#
#
#                 W
#                 ──
#                 Δᵣ
#
#                                             ⎛      2    2
#                                             ⎝- Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅\tilde{r
#                 0                           ──────────────────────────────────
#
#
#
#     2  2           4⎞       ⎛                     2           2⎞⎞    2   ⎤
# e{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠ + Ξ⋅a⋅⎝Δᵣ - Δₜₕₑₜₐ⋅\tilde{r}  - Δₜₕₑₜₐ⋅a ⎠⎠⋅sin (θ)⎥
# ─────────────────────────────────────────────────────────────────────────⎥
#          2                                                               ⎥
#       W⋅Ξ                                                                ⎥
#                                                                          ⎥
#                                                                          ⎥
#        0                                                                 ⎥
#                                                                          ⎥
#                                                                          ⎥
#  4                     2  2           4⎞    2                            ⎥
# }  + 2⋅Δₜₕₑₜₐ⋅\tilde{r} ⋅a  + Δₜₕₑₜₐ⋅a ⎠⋅sin (θ)                         ⎥
# ────────────────────────────────────────────────                         ⎥
#         2                                                                ⎥
#      W⋅Ξ                                                                 ⎦

# %%
A = delta_r * (xi - a * omega * sympy.sin(theta) ** 2) ** 2 - delta_theta * (a * xi - omega * (r_tilde ** 2 + a ** 2)) ** 2 * sympy.sin(theta) ** 2
A
# Out:
#                       2                                       2
#    ⎛         2       ⎞           ⎛    ⎛         2    2⎞      ⎞     2
# Δᵣ⋅⎝- Ω⋅a⋅sin (θ) + Ξ⎠  - Δₜₕₑₜₐ⋅⎝- Ω⋅⎝\tilde{r}  + a ⎠ + Ξ⋅a⎠ ⋅sin (θ)

# %%
(A / (W * xi ** 2) - g_mat[0, 0]).simplify()
# Out:
# 0

# %%
C = (r_tilde ** 2 + a ** 2) ** 2 * delta_theta * sympy.sin(theta) ** 2 - delta_r * a ** 2 * sympy.sin(theta) ** 4
C
# Out:
#                                           2
#       2    4             ⎛         2    2⎞     2
# - Δᵣ⋅a ⋅sin (θ) + Δₜₕₑₜₐ⋅⎝\tilde{r}  + a ⎠ ⋅sin (θ)

# %%
(C / (W * xi ** 2) - g_mat[2, 2]).simplify()
# Out:
# 0

# %%
B = ((omega * a ** 2 * sympy.sin(theta) ** 2 - a * xi) * sympy.sin(theta) ** 2) * delta_r
B
# Out:
#    ⎛   2    2         ⎞    2
# Δᵣ⋅⎝Ω⋅a ⋅sin (θ) - Ξ⋅a⎠⋅sin (θ)

# %%
(B / (W * xi ** 2) - (sympy.I * g_mat[0, 2].expand().collect(delta_r).coeff(delta_r)) * delta_r).simplify()
# Out:
# 0

# %%
real_delta_r = r_tilde ** 4 - r_tilde_plus ** 4 + (r_tilde_plus - r_tilde) ** 2 * (a + 1) ** 2 + 2 * a * (r_tilde_plus ** 2 - r_tilde ** 2)
real_delta_r
# Out:
#          4             4       ⎛           2             2⎞
# \tilde{r}  - \tilde{r}₊  + 2⋅a⋅⎝- \tilde{r}  + \tilde{r}₊ ⎠ + (-\tilde{r} + \t
#
#          2        2
# ilde{r}₊) ⋅(a + 1)

# %%
imag_delta_r = 2 * (r_tilde_plus - r_tilde) * (a + 1) * (r_tilde_plus ** 2 - a)
imag_delta_r
# Out:
#                               ⎛          2    ⎞
# (-2⋅\tilde{r} + 2⋅\tilde{r}₊)⋅⎝\tilde{r}₊  - a⎠⋅(a + 1)

# %%
xi_val = 1 - a ** 2
xi_val
# Out:
#      2
# 1 - a

# %%
omega_val = a * xi / (r_tilde_plus ** 2 + a ** 2)
omega_val
# Out:
#       Ξ⋅a
# ────────────────
#           2    2
# \tilde{r}₊  + a

# %%
delta_theta_val = 1 - a ** 2 * sympy.cos(theta) ** 2
delta_theta_val
# Out:
#    2    2
# - a ⋅cos (θ) + 1

# %%
poly = A.subs({delta_r: real_delta_r}) * C.subs({delta_r: real_delta_r}) - (B ** 2).subs({delta_r: imag_delta_r})
poly = poly.subs({omega: omega_val}).subs({xi: xi_val, delta_theta: delta_theta_val}).expand().simplify()
poly
# Out:
#        2        2 ⎛ 2 ⎛          2    2⎞ ⎛           8  4              8  2
# (a - 1) ⋅(a + 1) ⋅⎝a ⋅⎝\tilde{r}₊  + a ⎠⋅⎝- \tilde{r} ⋅a  + 2⋅\tilde{r} ⋅a  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          8              6  6    2                 6  6              6  4    2
# \tilde{r}  + 2⋅\tilde{r} ⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅a  - 4⋅\tilde{r} ⋅a ⋅sin (
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 6  4              6  2    2                 6  2
# θ) + 8⋅\tilde{r} ⋅a  + 2⋅\tilde{r} ⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅a  + 4⋅\tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 5             6    2                 5             5    2                 5
#  ⋅\tilde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 8⋅\tilde{r} ⋅\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           3    2                 5             2    2                 4
# ilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) + 2⋅\tilde{r} ⋅\tilde
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     4  4    2                 4           4  2    2                 4
# {r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅\tilde{r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2  6    2                 4           2  5    2                 4
# }₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r} ⋅\tilde{r}₊
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2  3    2                 4           2  2    2               4  8    4
#  ⋅a ⋅sin (θ) + 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r} ⋅a ⋅sin (θ) + 6
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           4  8    2                 4  8              4  6    4
# ⋅\tilde{r} ⋅a ⋅sin (θ) - 6⋅\tilde{r} ⋅a  + 2⋅\tilde{r} ⋅a ⋅sin (θ) - 10⋅\tilde
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    4  6    2                  4  6            4  4    4                 4  4
# {r} ⋅a ⋅sin (θ) + 12⋅\tilde{r} ⋅a  - \tilde{r} ⋅a ⋅sin (θ) + 4⋅\tilde{r} ⋅a ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                 4  4              3             8    4                 3
# in (θ) - 6⋅\tilde{r} ⋅a  - 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r} ⋅\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            8    2                 3             7    4                  3
# tilde{r}₊⋅a ⋅sin (θ) - 8⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) + 16⋅\tilde{r} ⋅\til
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         7    2                 3             5    4                  3
# de{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 16⋅\tilde{r} ⋅\tilde{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      5    2                 3             4    4                 3
# r}₊⋅a ⋅sin (θ) + 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 8⋅\tilde{r} ⋅\tilde{r}₊⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  4    2                 2           4  6    4                 2           4  6
# a ⋅sin (θ) - 6⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                 2           4  5    4                 2           4  4
# ⋅sin (θ) - 8⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   4                 2           4  4    2                 2           2  8
# in (θ) - 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 4                 2           2  8    2                  2           2  7    2
#  (θ) - 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  2           2  6    4                  2           2  5    4
# (θ) - 8⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  2           2  5    2                 2           2  4    4
# θ) + 16⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 6⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                2           2  4    2                 2  10    4
# ) + 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅a  ⋅sin (θ) + 6⋅\tilde{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2  10    2                 2  10              2  8    4                 2  8
# r} ⋅a  ⋅sin (θ) - 4⋅\tilde{r} ⋅a   - 2⋅\tilde{r} ⋅a ⋅sin (θ) - 8⋅\tilde{r} ⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                 2  8              2  7    4                 2  6    4
# ⋅sin (θ) + 8⋅\tilde{r} ⋅a  - 8⋅\tilde{r} ⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅a ⋅sin (θ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               2  6    2                 2  6                         5  6    4
#  + 2⋅\tilde{r} ⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅a  + 4⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                             5  5    4                            5  4    4
# (θ) + 8⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                         3  8    4                            3  7    4
# + 4⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                     3  6    4                            3  5    4
# \tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\til
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 3  4    4                              10    4
# de{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}⋅\tilde{r}₊⋅a  ⋅sin (θ) + 4⋅\tilde{r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               10    2                              9    4
# }⋅\tilde{r}₊⋅a  ⋅sin (θ) - 8⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r}⋅\ti
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          9    2                              8    4
# lde{r}₊⋅a ⋅sin (θ) + 4⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 16⋅\tilde{r}⋅\tilde{r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     7    4                              7    2                              6
# }₊⋅a ⋅sin (θ) - 8⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    4                              6    2                8  4    4
# sin (θ) - 4⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tild
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      6  6    4                  6  4    4                  4  8    4
# e{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         4  8    2                  4  6    4                  4  6    2
# ilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          4  4    4                  2  10    4                  2  10    2
# tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  ⋅sin (θ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               2  9    4                  2  9    2                  2  8    4
# + 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  2  7    4                  2  7    2                  2  6
# θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅si
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  4                  2  6    2       12    4         12    2       12      10
# n (θ) + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - a  ⋅sin (θ) + 2⋅a  ⋅sin (θ) - a   - 2⋅a  ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2         10    8⎞    2         2 ⎛          4               2  2    4⎞ ⎛
# in (θ) + 2⋅a   - a ⎠⋅sin (θ) + 2⋅a ⋅⎝\tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a  + a ⎠⋅⎝\ti
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       8  2            8              6  4    2                 6  4
# lde{r} ⋅a  - \tilde{r}  - 2⋅\tilde{r} ⋅a ⋅sin (θ) + 4⋅\tilde{r} ⋅a  + 2⋅\tilde
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    6  2    2                 6  2              5             4    2
# {r} ⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅a  - 2⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 2⋅\ti
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       5             4              5             3    2                 5
# lde{r} ⋅\tilde{r}₊⋅a  - 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅\til
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         3              5             2    2                 5
# de{r}₊⋅a  - 2⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) + 4⋅\tilde{r} ⋅\tilde{r}₊⋅a + 2
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           5                       4           4  2    2               4
# ⋅\tilde{r} ⋅\tilde{r}₊ - \tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r} ⋅\tilde
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     4  2            4           4            4           2  4    2
# {r}₊ ⋅a  + \tilde{r} ⋅\tilde{r}₊  + \tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    4           2  4              4           2  3    2                 4
# {r} ⋅\tilde{r}₊ ⋅a  + 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r} ⋅\tild
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      2  3            4           2  2    2                 4           2
# e{r}₊ ⋅a  + \tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a - \
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         4           2            4  6    4                 4  6    2
# tilde{r} ⋅\tilde{r}₊  + \tilde{r} ⋅a ⋅sin (θ) - 6⋅\tilde{r} ⋅a ⋅sin (θ) + 6⋅\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        4  6            4  4    4                 4  4    2                 4
# ilde{r} ⋅a  - \tilde{r} ⋅a ⋅sin (θ) + 5⋅\tilde{r} ⋅a ⋅sin (θ) - 7⋅\tilde{r} ⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 4            4  2              3             6    4                 3
#   + \tilde{r} ⋅a  + 2⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅\tilde{r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     6    2                 3             6              3             5    4
# }₊⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅\tilde{r}₊⋅a  + 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                3             5    2                 3             5
# ) - 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 8⋅\tilde{r} ⋅\tilde{r}₊⋅a  + 2⋅\tilde
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    3             4    4                 3             4    2                 3
# {r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#              3    2                 3             3              3
# ⋅\tilde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r} ⋅\tilde{r}₊⋅a  - 2⋅\tilde{r} ⋅\tilde{r}₊⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2    2                 3             2            2           4  4    4
# a ⋅sin (θ) + 4⋅\tilde{r} ⋅\tilde{r}₊⋅a  + \tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2           4  4    2                 2           4  4
# 3⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a  + 8⋅\tilde{r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2           4  3    2                 2           4  2    2                 2
# } ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 3⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            4  2            2           2  6    4                 2           2
# ⋅\tilde{r}₊ ⋅a  - \tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r} ⋅\tilde{r}₊
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   6    2                 2           2  6              2           2  5    4
# ⋅a ⋅sin (θ) + 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 2           2  5    2                 2           2  5
# ) + 12⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r} ⋅\tilde{r}₊ ⋅a  - \tild
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2           2  4    4                  2           2  4    2
# e{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 10⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 12⋅\tild
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2           2  3    2                 2           2  3              2
# e{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r} ⋅\tilde{r}₊ ⋅a  + 5⋅\tilde{r} ⋅\til
# ──────────────────────────────────────────────────────────────────────────────
#                                                            ⎛          2    2⎞
#                                                            ⎝\tilde{r}₊  + a ⎠⋅
#
#       2  2    2                 2           2  2              2  8    4
# de{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r} ⋅a ⋅sin (θ) - 6
# ──────────────────────────────────────────────────────────────────────────────
# ⎛          4               2  2    4⎞
# ⎝\tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a  + a ⎠
#
#           2  8    2                 2  8            2  6    4
# ⋅\tilde{r} ⋅a ⋅sin (θ) + 4⋅\tilde{r} ⋅a  - \tilde{r} ⋅a ⋅sin (θ) + 9⋅\tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2  6    2                 2  6              2  5    2                 2  4
#  ⋅a ⋅sin (θ) - 6⋅\tilde{r} ⋅a  + 8⋅\tilde{r} ⋅a ⋅sin (θ) + 3⋅\tilde{r} ⋅a ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2                 2  4                         5  4    2
#  (θ) + 2⋅\tilde{r} ⋅a  - 4⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}⋅\til
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       5  3    2                            5  2    2
# de{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}⋅\tilde{r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   3  6    2                            3  5    2                            3
# }₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}⋅\tilde{r}₊ ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  4    2                            3  3    2                            3  2
# a ⋅sin (θ) - 8⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                              8    4                              8
# in (θ) + 2⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) - 2⋅\tilde{r}⋅\tilde{r}₊⋅a  + 4⋅\ti
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    7    4                              7
# lde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r}⋅\tilde{r}₊⋅a  + 2⋅\tilde{r}⋅\tilde{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      6    4                              6    2
# r}₊⋅a ⋅sin (θ) - 6⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) - 12⋅\tilde{r}⋅\tilde{r}₊⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 5    2                              5                           4    2
#  ⋅sin (θ) + 4⋅\tilde{r}⋅\tilde{r}₊⋅a  - 6⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                       4             8  2    2                  6  4    2
# \tilde{r}⋅\tilde{r}₊⋅a  + \tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             6  2    2                4  6    4                4  6    2
# 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a ⋅sin (θ) - \
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          4  6               4  4    2                4  4             4  2
# tilde{r}₊ ⋅a  + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  + \tilde{r}₊ ⋅a ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2                2  8    4                2  8               2  7    4
#  (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           2  7             2  6    4                  2  6    2
# \tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a ⋅sin (θ) + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    2  5    2                  2  5               2  4    2                2  4
# r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a  + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     10    4         10    2       10      8    2         8    6⎞    2      ⎛
#  + a  ⋅sin (θ) - 2⋅a  ⋅sin (θ) + a   + 2⋅a ⋅sin (θ) - 2⋅a  + a ⎠⋅sin (θ) + ⎝\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2    2⎞ ⎛          4               2  2    4⎞ ⎛           8  2
# ilde{r}₊  + a ⎠⋅⎝\tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a  + a ⎠⋅⎝- \tilde{r} ⋅a  + \tild
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     8            6  4    2                 6  4            6  2    2
# e{r}  + \tilde{r} ⋅a ⋅sin (θ) - 3⋅\tilde{r} ⋅a  - \tilde{r} ⋅a ⋅sin (θ) + 2⋅\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        6  2            6              5             4    2                 5
# ilde{r} ⋅a  + \tilde{r}  + 2⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) + 2⋅\tilde{r} ⋅\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            4              5             3    2                 5             3
# tilde{r}₊⋅a  + 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) + 4⋅\tilde{r} ⋅\tilde{r}₊⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               5             2    2                 5
#  + 2⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅\tilde{r}₊⋅a - 2⋅\tilde{r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  5                       4           4  2    2               4           4  2
# } ⋅\tilde{r}₊ + \tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r} ⋅\tilde{r}₊ ⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            4           4            4           2  4    2               4
# - \tilde{r} ⋅\tilde{r}₊  - \tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r} ⋅\til
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2  4              4           2  3    2                 4           2  3
# de{r}₊ ⋅a  - 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             4           2  2    2                 4           2              4
#  - \tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a + \tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2            4  6    4               4  6    2                 4  6
# ⋅\tilde{r}₊  + \tilde{r} ⋅a ⋅sin (θ) + \tilde{r} ⋅a ⋅sin (θ) - 3⋅\tilde{r} ⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             4  4    4                 4  4    2               4  4
#  - \tilde{r} ⋅a ⋅sin (θ) + 2⋅\tilde{r} ⋅a ⋅sin (θ) + \tilde{r} ⋅a  - 2⋅\tilde{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   4  2    2                 4  2              3             6              3
# r} ⋅a ⋅sin (θ) + 2⋅\tilde{r} ⋅a  + 4⋅\tilde{r} ⋅\tilde{r}₊⋅a  + 8⋅\tilde{r} ⋅\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            5              3             4    2                 3             3
# tilde{r}₊⋅a  + 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r} ⋅\tilde{r}₊⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                 3             3              3             2    2
# ⋅sin (θ) - 8⋅\tilde{r} ⋅\tilde{r}₊⋅a  + 4⋅\tilde{r} ⋅\tilde{r}₊⋅a ⋅sin (θ) - 4
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           3             2              2           4  4    2                 2
# ⋅\tilde{r} ⋅\tilde{r}₊⋅a  - 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            4  4              2           4  3    2                 2
# ⋅\tilde{r}₊ ⋅a  - 8⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅\tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  4  2    2                 2           4  2              2           2  6    2
# ₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  2           2  6              2           2  5    2
# (θ) - 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a  - 8⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2           2  5               2           2  4    2                  2
# ilde{r} ⋅\tilde{r}₊ ⋅a  - 10⋅\tilde{r} ⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2  3    2                 2           2  3              2
# ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r} ⋅\tilde{r}₊ ⋅a  - 6⋅\tilde{r} ⋅\tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2  2    2                 2           2  2            2  8    6
# ₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r} ⋅\tilde{r}₊ ⋅a  - \tilde{r} ⋅a ⋅sin (θ) + 3⋅\tilde
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    2  8    4               2  8    2               2  8            2  6    6
# {r} ⋅a ⋅sin (θ) - \tilde{r} ⋅a ⋅sin (θ) - \tilde{r} ⋅a  + \tilde{r} ⋅a ⋅sin (θ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                2  6    4               2  6    2                 2  5    2
# ) - 4⋅\tilde{r} ⋅a ⋅sin (θ) + \tilde{r} ⋅a ⋅sin (θ) - 8⋅\tilde{r} ⋅a ⋅sin (θ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2  4    4                 2  4    2               2  4
# + \tilde{r} ⋅a ⋅sin (θ) - 6⋅\tilde{r} ⋅a ⋅sin (θ) + \tilde{r} ⋅a  + 4⋅\tilde{r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             5  4    2                            5  3    2
# }⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}⋅\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         5  2    2                            3  6    2
# ilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}⋅\tilde
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     3  5    2                            3  4    2
# {r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}⋅\tilde{r}₊
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 3  3    2                            3  2    2                              8
#  ⋅a ⋅sin (θ) + 4⋅\tilde{r}⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    6                              8    4                              8    2
# sin (θ) + 2⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) - 2⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                             8                           7    6
# ) + 2⋅\tilde{r}⋅\tilde{r}₊⋅a  - 4⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 4⋅\tilde{r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               7    4                              7    2
# }⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 4⋅\tilde{r}⋅\til
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         7                           6    6                              6    2
# de{r}₊⋅a  - 2⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 6⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                               5    4                               5    2
# (θ) - 4⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 16⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                          5                           4    4
#  4⋅\tilde{r}⋅\tilde{r}₊⋅a  - 2⋅\tilde{r}⋅\tilde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r}⋅\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            4    2                              4             8  2    2
# tilde{r}₊⋅a ⋅sin (θ) - 2⋅\tilde{r}⋅\tilde{r}₊⋅a  - \tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           6  4    2                  6  2    2                4  6    6
# \tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) + \
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          4  6    4                  4  6    2                4  6
# tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  - \tilde{r}₊
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 4  4    4                  4  4    2                4  4             4  2    2
#  ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 2  8    6                2  8    4                2  8    2
# (θ) + \tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a ⋅sin (θ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#              2  8               2  7    6                  2  7    4
#  - \tilde{r}₊ ⋅a  + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2  7    2                  2  7             2  6    6
# ilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a  + \tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2  6    2                  2  5    4                  2  5    2
# ₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2  5             2  4    4                  2  4    2                2  4
# {r}₊ ⋅a  + \tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    10    6         10    4       10    2         8    4         8    2       6
# - a  ⋅sin (θ) + 2⋅a  ⋅sin (θ) - a  ⋅sin (θ) - 2⋅a ⋅sin (θ) + 2⋅a ⋅sin (θ) - a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2   ⎞⎞    2
# ⋅sin (θ)⎠⎠⋅sin (θ)
# ──────────────────

# %%
poly_2 = sympy.fraction(poly)[0].args[3].factor().args[2].collect(r_tilde)
poly_2
# Out:
#          7 ⎛            4  2             4               2  4    2
# \tilde{r} ⋅⎝- \tilde{r}₊ ⋅a  + \tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\til
#
#       2  4               2  2    2                  2  2    6    2       6
# de{r}₊ ⋅a  - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  + a ⋅sin (θ) - a  + a
#
# 4    2    2   ⎞            6 ⎛            5  2             5               3
#   - a ⋅sin (θ)⎠ + \tilde{r} ⋅⎝- \tilde{r}₊ ⋅a  + \tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a
#
# 4    2                  3  4               3  2    2                  3  2
#  ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  + \
#
#            6    2                  6               4               2    2   ⎞
# tilde{r}₊⋅a ⋅sin (θ) - \tilde{r}₊⋅a  + \tilde{r}₊⋅a  - \tilde{r}₊⋅a ⋅sin (θ)⎠
#
#            5 ⎛            6  2             6               4  4    2
# + \tilde{r} ⋅⎝- \tilde{r}₊ ⋅a  + \tilde{r}₊  + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 5⋅\t
#
#         4  4               4  2    2                  4  2             4
# ilde{r}₊ ⋅a  - 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  + \tilde{r}₊  - 4⋅\
#
#          2  6    4                   2  6    2                  2  6
# tilde{r}₊ ⋅a ⋅sin (θ) + 11⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a  + 4⋅\tild
#
#      2  4    4                   2  4    2                  2  4             2
# e{r}₊ ⋅a ⋅sin (θ) - 10⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅a  - \tilde{r}₊
#
#   2    2                  2  2      8    4         8    2         8    6    2
# ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  - 2⋅a ⋅sin (θ) + 5⋅a ⋅sin (θ) - 3⋅a  - a ⋅sin (
#
#         6      4    4         4    2       4⎞            4 ⎛            7  2
# θ) + 2⋅a  + 2⋅a ⋅sin (θ) - 4⋅a ⋅sin (θ) + a ⎠ + \tilde{r} ⋅⎝- \tilde{r}₊ ⋅a  +
#
#            7               5  4    2                  5  4               5  3
#  \tilde{r}₊  + 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a  + 4⋅\tilde{r}₊ ⋅a ⋅
#
#    2                  5  3             5  2    2                  5  2
# sin (θ) + 4⋅\tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  - 4⋅\ti
#
#        5               5               3  6    4                   3  6    2
# lde{r}₊ ⋅a - \tilde{r}₊  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 11⋅\tilde{r}₊ ⋅a ⋅sin (θ
#
#                 3  6               3  5    4                  3  5
# ) - 3⋅\tilde{r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}₊ ⋅a  - 6⋅\tilde{
#
#    3  4    2                  3  4               3  3    2                  3
# r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅a  + 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅
#
#  3               3  2    2                  3  2                 8    4
# a  + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  - 2⋅\tilde{r}₊⋅a ⋅sin (θ) + 3
#
#              8    2                  8                 7    2
# ⋅\tilde{r}₊⋅a ⋅sin (θ) - \tilde{r}₊⋅a  - 4⋅\tilde{r}₊⋅a ⋅sin (θ) + 4⋅\tilde{r}
#
#    7                 6    4                  6    2                    6
# ₊⋅a  - 4⋅\tilde{r}₊⋅a ⋅sin (θ) + \tilde{r}₊⋅a ⋅sin (θ) + 2⋅\tilde{r}₊⋅a  - 8⋅\
#
#            5    4                    5    2                    5
# tilde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r}₊⋅a  - 2⋅\tilde{r}
#
#    4    4                  4⎞            3 ⎛          8  2    2
# ₊⋅a ⋅sin (θ) - \tilde{r}₊⋅a ⎠ + \tilde{r} ⋅⎝\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{
#
#    6  4    4                  6  4    2                  6  4               6
# r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅
#
#  2               4  6    4                   4  6    2                  4  6
# a  - 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 11⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a  -
#
#            4  4    4                  4  4    2                  4  4
#  \tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅a  - \tilde
#
#     4  2    2                  4  2               2  8    6
# {r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 12⋅\tilde{r}₊
#
# 2  8    4                   2  8    2                  2  8               2  6
#  ⋅a ⋅sin (θ) + 18⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a  - 2⋅\tilde{r}₊ ⋅a
#
#     6                  2  6    4                   2  6    2
# ⋅sin (θ) + 6⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 10⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊
#
# 2  6               2  4    2                  2  4    10    6         10    4
#  ⋅a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  + a  ⋅sin (θ) - 5⋅a  ⋅sin (
#
#         10    2         10    8    4       8    6    6         6    4
# θ) + 7⋅a  ⋅sin (θ) - 3⋅a   - a ⋅sin (θ) + a  - a ⋅sin (θ) + 4⋅a ⋅sin (θ) - 6⋅a
#
# 6    2         6⎞            2 ⎛          9  2    2                  7  4    4
#  ⋅sin (θ) + 2⋅a ⎠ + \tilde{r} ⋅⎝\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin
#
#                   7  4    2                  7  4               7  2
# (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅a  - 5⋅\tild
#
#      5  6    4                   5  6    2                  5  6
# e{r}₊ ⋅a ⋅sin (θ) + 11⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a  + 8⋅\tilde{r}
#
#  5  5             5  4    4                  5  4               5  3    2
# ₊ ⋅a  - \tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅a  + 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) -
#
#              5  3               5  2    2                  5  2
#  8⋅\tilde{r}₊ ⋅a  + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  + 6⋅\tilde{r}₊
#
# 3  8    6                   3  8    4                   3  8    2
#  ⋅a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 10⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tild
#
#      3  7    6                  3  7    4                   3  7    2
# e{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 16⋅
#
#           3  7               3  6    6                  3  6    4
# \tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tild
#
#      3  6    2                  3  6               3  5    4
# e{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 32⋅\tilde{r}
#
#  3  5    2                   3  5               3  4    4                   3
# ₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 12⋅\tilde{r}₊ ⋅
#
#  4    2                  3  4               10    6                  10    4
# a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a  + \tilde{r}₊⋅a  ⋅sin (θ) - \tilde{r}₊⋅a  ⋅sin (θ
#
#                 10    2                  10                 9    4
# ) - \tilde{r}₊⋅a  ⋅sin (θ) + \tilde{r}₊⋅a   + 8⋅\tilde{r}₊⋅a ⋅sin (θ) - 16⋅\ti
#
#          9    2                    9                 8    6
# lde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r}₊⋅a  + 4⋅\tilde{r}₊⋅a ⋅sin (θ) - 9⋅\tilde{r}₊⋅
#
#  8    4                    8    2                  8                 7    6
# a ⋅sin (θ) + 4⋅\tilde{r}₊⋅a ⋅sin (θ) + \tilde{r}₊⋅a  + 8⋅\tilde{r}₊⋅a ⋅sin (θ)
#
#                   7    4                     7    2                    7
#  - 24⋅\tilde{r}₊⋅a ⋅sin (θ) + 24⋅\tilde{r}₊⋅a ⋅sin (θ) - 8⋅\tilde{r}₊⋅a  + 3⋅\
#
#            6    6                    6    4                    6    2
# tilde{r}₊⋅a ⋅sin (θ) - 8⋅\tilde{r}₊⋅a ⋅sin (θ) + 6⋅\tilde{r}₊⋅a ⋅sin (θ) - 2⋅\
#
#            6⎞             ⎛          10  2    2                  8  4    4
# tilde{r}₊⋅a ⎠ + \tilde{r}⋅⎝\tilde{r}₊  ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ)
#
#               8  3    2                  8  2    2                  6  6    6
# - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a ⋅sin (
#
#                6  6    4                  6  6    2                6  6
# θ) + \tilde{r}₊ ⋅a ⋅sin (θ) - 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a  + 16⋅\
#
#          6  5    4                   6  5    2                  6  4    4
# tilde{r}₊ ⋅a ⋅sin (θ) - 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) -
#
#               6  4    2                6  4               6  3    2
#  10⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\ti
#
#        6  2    2                4  8    6                  4  8    4
# lde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\t
#
#         4  8    2                  4  8               4  7    6
# ilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 32⋅\tilde
#
#     4  7    4                   4  7    2                4  6    6
# {r}₊ ⋅a ⋅sin (θ) - 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) + 16⋅\ti
#
#        4  6    4                   4  6    2                  4  6
# lde{r}₊ ⋅a ⋅sin (θ) - 19⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  + 16⋅\tilde
#
#     4  5    4                   4  5    2                  4  4    4
# {r}₊ ⋅a ⋅sin (θ) - 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 10⋅\
#
#          4  4    2                4  4             2  10    6                2
# tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a  ⋅sin (θ) - \tilde{r}₊
#
#   10    4                  2  10    2                  2  10               2
# ⋅a  ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅a  ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a   - 8⋅\tilde{r}₊ ⋅a
#
# 9    6                   2  9    4                  2  9    2
#  ⋅sin (θ) + 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 6⋅\tilde{r}
#
#  2  8    6                   2  8    4                   2  8    2
# ₊ ⋅a ⋅sin (θ) + 21⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde
#
#     2  8               2  7    6                   2  7    4
# {r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 32⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 24⋅\tilde{r}
#
#  2  7    2                  2  6    6                   2  6    4
# ₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 14⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 12⋅\til
#
#       2  6    2                  2  6    12    6         12    4         12
# de{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  + a  ⋅sin (θ) - 3⋅a  ⋅sin (θ) + 3⋅a  ⋅si
#
#  2       12      10    6         10    4         10    2         9    6
# n (θ) - a   - 3⋅a  ⋅sin (θ) + 6⋅a  ⋅sin (θ) - 3⋅a  ⋅sin (θ) - 8⋅a ⋅sin (θ) + 1
#
#    9    4         9    2         8    6         8    4         8    2       8⎞
# 6⋅a ⋅sin (θ) - 8⋅a ⋅sin (θ) - 4⋅a ⋅sin (θ) + 9⋅a ⋅sin (θ) - 6⋅a ⋅sin (θ) + a ⎠
#
#              11  2    2                  9  4    4                  9  4    2
#  + \tilde{r}₊  ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (
#
#                  9  2    2                  7  6    6                  7  6
# θ) + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a ⋅si
#
#  4                  7  6    2                7  6               7  4    4
# n (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a  - 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) +
#
#              7  4    2                7  4             7  2    2
#  6⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  + \tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r
#
#   5  8    6                  5  8    4                  5  8    2
# }₊ ⋅a ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{
#
#    5  8               5  7    6                  5  7    4                  5
# r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅
#
#  7    2                  5  7             5  6    6                  5  6    4
# a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  + \tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin
#
#                   5  6    2                  5  6               5  5    4
# (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) +
#
#              5  5    2                  5  5               5  4    4
#  8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a  - 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 6⋅\t
#
#         5  4    2                5  4               3  10    6
# ilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a  + 3⋅\tilde{r}₊ ⋅a  ⋅sin (θ) - 5⋅\tilde{r
#
#   3  10    4                3  10    2                3  10               3  9
# }₊ ⋅a  ⋅sin (θ) + \tilde{r}₊ ⋅a  ⋅sin (θ) + \tilde{r}₊ ⋅a   + 8⋅\tilde{r}₊ ⋅a
#
#     4                   3  9    2                  3  9               3  8
# ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅a ⋅sin
#
# 6                  3  8    4                  3  8    2                3  8
#  (θ) - 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  -
#
#              3  7    4                   3  7    2                  3  7
# 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a  + \ti
#
#        3  6    6                   3  6    4                   3  6    2
# lde{r}₊ ⋅a ⋅sin (θ) - 10⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 12⋅\tilde{r}₊ ⋅a ⋅sin (θ) -
#
#             3  6               12    6                    12    4
# 2⋅\tilde{r}₊ ⋅a  - \tilde{r}₊⋅a  ⋅sin (θ) + 3⋅\tilde{r}₊⋅a  ⋅sin (θ) - 3⋅\tild
#
#        12    2                  12                 11    6
# e{r}₊⋅a  ⋅sin (θ) + \tilde{r}₊⋅a   - 4⋅\tilde{r}₊⋅a  ⋅sin (θ) + 12⋅\tilde{r}₊⋅
#
#  11    4                     11    2                    11                 10
# a  ⋅sin (θ) - 12⋅\tilde{r}₊⋅a  ⋅sin (θ) + 4⋅\tilde{r}₊⋅a   + 3⋅\tilde{r}₊⋅a  ⋅
#
#    6                    10    4                    10    2
# sin (θ) - 6⋅\tilde{r}₊⋅a  ⋅sin (θ) + 3⋅\tilde{r}₊⋅a  ⋅sin (θ) + 8⋅\tilde{r}₊⋅a
#
# 9    6                     9    4                     9    2
#  ⋅sin (θ) - 20⋅\tilde{r}₊⋅a ⋅sin (θ) + 16⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r}₊
#
#   9                 8    6                    8    4                    8    2
# ⋅a  + 4⋅\tilde{r}₊⋅a ⋅sin (θ) - 9⋅\tilde{r}₊⋅a ⋅sin (θ) + 6⋅\tilde{r}₊⋅a ⋅sin
#
#                   8
# (θ) - \tilde{r}₊⋅a

# %%
coeffs = sympy.Poly(poly_2, r_tilde).all_coeffs()
coeffs
# Out:
# ⎡            4  2             4               2  4    2                  2  4
# ⎣- \tilde{r}₊ ⋅a  + \tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a
#
#               2  2    2                  2  2    6    2       6    4    2    2
# - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  + a ⋅sin (θ) - a  + a  - a ⋅sin
#
#                  5  2             5               3  4    2                  3
# (θ), - \tilde{r}₊ ⋅a  + \tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊
#
#   4               3  2    2                  3  2               6    2
# ⋅a  - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  + \tilde{r}₊⋅a ⋅sin (θ) - \t
#
#           6               4               2    2                 6  2
# ilde{r}₊⋅a  + \tilde{r}₊⋅a  - \tilde{r}₊⋅a ⋅sin (θ), - \tilde{r}₊ ⋅a  + \tilde
#
#     6               4  4    2                  4  4               4  2    2
# {r}₊  + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 5⋅\tilde{r}₊ ⋅a  - 3⋅\tilde{r}₊ ⋅a ⋅sin (θ)
#
#                4  2             4               2  6    4                   2
#  + 4⋅\tilde{r}₊ ⋅a  + \tilde{r}₊  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 11⋅\tilde{r}₊ ⋅
#
#  6    2                  2  6               2  4    4                   2  4
# a ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a  + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 10⋅\tilde{r}₊ ⋅a ⋅s
#
#   2                  2  4             2  2    2                  2  2      8
# in (θ) + 5⋅\tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  - 2⋅a ⋅s
#
#   4         8    2         8    6    2         6      4    4         4    2
# in (θ) + 5⋅a ⋅sin (θ) - 3⋅a  - a ⋅sin (θ) + 2⋅a  + 2⋅a ⋅sin (θ) - 4⋅a ⋅sin (θ)
#
#     4              7  2             7               5  4    2
#  + a , - \tilde{r}₊ ⋅a  + \tilde{r}₊  + 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}
#
#  5  4               5  3    2                  5  3             5  2    2
# ₊ ⋅a  + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a ⋅sin (θ) +
#
#              5  2               5               5               3  6    4
#  4⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a - \tilde{r}₊  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) +
#
#               3  6    2                  3  6               3  5    4
#  11⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\
#
#          3  5               3  4    2                  3  4               3  3
# tilde{r}₊ ⋅a  - 6⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅a  + 8⋅\tilde{r}₊ ⋅a
#
#     2                  3  3               3  2    2                  3  2
# ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a  + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  - 2⋅
#
#             8    4                    8    2                  8
# \tilde{r}₊⋅a ⋅sin (θ) + 3⋅\tilde{r}₊⋅a ⋅sin (θ) - \tilde{r}₊⋅a  - 4⋅\tilde{r}₊
#
#   7    2                    7                 6    4                  6    2
# ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊⋅a  - 4⋅\tilde{r}₊⋅a ⋅sin (θ) + \tilde{r}₊⋅a ⋅sin (θ
#
#                   6                 5    4                    5    2
# ) + 2⋅\tilde{r}₊⋅a  - 8⋅\tilde{r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\t
#
#           5                 4    4                  4            8  2    2
# ilde{r}₊⋅a  - 2⋅\tilde{r}₊⋅a ⋅sin (θ) - \tilde{r}₊⋅a , \tilde{r}₊ ⋅a ⋅sin (θ)
#
#               6  4    4                  6  4    2                  6  4
# - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  + 2⋅\
#
#          6  2               4  6    4                   4  6    2
# tilde{r}₊ ⋅a  - 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 11⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 7⋅\tild
#
#      4  6             4  4    4                  4  4    2                  4
# e{r}₊ ⋅a  - \tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅
#
#  4             4  2    2                  4  2               2  8    6
# a  - \tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 12
#
#            2  8    4                   2  8    2                  2  8
# ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 18⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a  - 2⋅\ti
#
#        2  6    6                  2  6    4                   2  6    2
# lde{r}₊ ⋅a ⋅sin (θ) + 6⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 10⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4
#
#            2  6               2  4    2                  2  4    10    6
# ⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  + a  ⋅sin (θ) -
#
#    10    4         10    2         10    8    4       8    6    6         6
# 5⋅a  ⋅sin (θ) + 7⋅a  ⋅sin (θ) - 3⋅a   - a ⋅sin (θ) + a  - a ⋅sin (θ) + 4⋅a ⋅si
#
#  4         6    2         6            9  2    2                  7  4    4
# n (θ) - 6⋅a ⋅sin (θ) + 2⋅a , \tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ)
#
#                7  4    2                  7  4               7  2
#  + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅a  - 5⋅\tilde{r
#
#   5  6    4                   5  6    2                  5  6               5
# }₊ ⋅a ⋅sin (θ) + 11⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a  + 8⋅\tilde{r}₊ ⋅
#
#  5             5  4    4                  5  4               5  3    2
# a  - \tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅a  + 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅
#
#           5  3               5  2    2                  5  2               3
# \tilde{r}₊ ⋅a  + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  + 6⋅\tilde{r}₊ ⋅a
#
# 8    6                   3  8    4                   3  8    2
#  ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 10⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r
#
#   3  7    6                  3  7    4                   3  7    2
# }₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 16⋅\ti
#
#        3  7               3  6    6                  3  6    4
# lde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r
#
#   3  6    2                  3  6               3  5    4                   3
# }₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 32⋅\tilde{r}₊ ⋅
#
#  5    2                   3  5               3  4    4                   3  4
# a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 12⋅\tilde{r}₊ ⋅a ⋅
#
#    2                  3  4               10    6                  10    4
# sin (θ) - 4⋅\tilde{r}₊ ⋅a  + \tilde{r}₊⋅a  ⋅sin (θ) - \tilde{r}₊⋅a  ⋅sin (θ) -
#
#              10    2                  10                 9    4
#  \tilde{r}₊⋅a  ⋅sin (θ) + \tilde{r}₊⋅a   + 8⋅\tilde{r}₊⋅a ⋅sin (θ) - 16⋅\tilde
#
#       9    2                    9                 8    6                    8
# {r}₊⋅a ⋅sin (θ) + 8⋅\tilde{r}₊⋅a  + 4⋅\tilde{r}₊⋅a ⋅sin (θ) - 9⋅\tilde{r}₊⋅a ⋅
#
#    4                    8    2                  8                 7    6
# sin (θ) + 4⋅\tilde{r}₊⋅a ⋅sin (θ) + \tilde{r}₊⋅a  + 8⋅\tilde{r}₊⋅a ⋅sin (θ) -
#
#                7    4                     7    2                    7
# 24⋅\tilde{r}₊⋅a ⋅sin (θ) + 24⋅\tilde{r}₊⋅a ⋅sin (θ) - 8⋅\tilde{r}₊⋅a  + 3⋅\til
#
#         6    6                    6    4                    6    2
# de{r}₊⋅a ⋅sin (θ) - 8⋅\tilde{r}₊⋅a ⋅sin (θ) + 6⋅\tilde{r}₊⋅a ⋅sin (θ) - 2⋅\til
#
#         6            10  2    2                  8  4    4                  8
# de{r}₊⋅a , \tilde{r}₊  ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅
#
#  3    2                  8  2    2                  6  6    6                6
# a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊
#
#   6    4                  6  6    2                6  6                6  5
# ⋅a ⋅sin (θ) - 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a  + 16⋅\tilde{r}₊ ⋅a ⋅si
#
#  4                   6  5    2                  6  4    4                   6
# n (θ) - 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 10⋅\tilde{r}₊ ⋅
#
#  4    2                6  4               6  3    2                  6  2    2
# a ⋅sin (θ) + \tilde{r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a ⋅sin
#
#                 4  8    6                  4  8    4                  4  8
# (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a ⋅sin
#
# 2                  4  8               4  7    6                   4  7    4
#  (θ) - 3⋅\tilde{r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 32⋅\tilde{r}₊ ⋅a ⋅sin (θ)
#
#                 4  7    2                4  6    6                   4  6    4
#  - 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) + 16⋅\tilde{r}₊ ⋅a ⋅sin
#
#                    4  6    2                  4  6                4  5    4
# (θ) - 19⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  + 16⋅\tilde{r}₊ ⋅a ⋅sin (θ)
#
#                 4  5    2                  4  4    4                   4  4
#  - 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 10⋅\tilde{r}₊ ⋅a ⋅si
#
#  2                4  4             2  10    6                2  10    4
# n (θ) + \tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a  ⋅sin (θ) - \tilde{r}₊ ⋅a  ⋅sin (θ) + 5
#
#            2  10    2                  2  10               2  9    6
# ⋅\tilde{r}₊ ⋅a  ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a   - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 16⋅\
#
#          2  9    4                  2  9    2                  2  8    6
# tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 6⋅\tilde{r}₊ ⋅a ⋅sin (θ) +
#
#              2  8    4                   2  8    2                2  8
# 21⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  - 8⋅\ti
#
#        2  7    6                   2  7    4                   2  7    2
# lde{r}₊ ⋅a ⋅sin (θ) + 32⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) -
#
#             2  6    6                   2  6    4                   2  6    2
# 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 14⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 12⋅\tilde{r}₊ ⋅a ⋅sin (
#
#                  2  6    12    6         12    4         12    2       12
# θ) + 2⋅\tilde{r}₊ ⋅a  + a  ⋅sin (θ) - 3⋅a  ⋅sin (θ) + 3⋅a  ⋅sin (θ) - a   - 3⋅
#
#  10    6         10    4         10    2         9    6          9    4
# a  ⋅sin (θ) + 6⋅a  ⋅sin (θ) - 3⋅a  ⋅sin (θ) - 8⋅a ⋅sin (θ) + 16⋅a ⋅sin (θ) - 8
#
#   9    2         8    6         8    4         8    2       8            11  2
# ⋅a ⋅sin (θ) - 4⋅a ⋅sin (θ) + 9⋅a ⋅sin (θ) - 6⋅a ⋅sin (θ) + a , \tilde{r}₊  ⋅a
#
#     2                  9  4    4                  9  4    2                  9
# ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊
#
#   2    2                  7  6    6                  7  6    4
# ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r
#
#   7  6    2                7  6               7  4    4                  7  4
# }₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a  - 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 6⋅\tilde{r}₊ ⋅a ⋅
#
#    2                7  4             7  2    2                5  8    6
# sin (θ) + \tilde{r}₊ ⋅a  + \tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a ⋅sin (θ) - 7
#
#            5  8    4                  5  8    2                5  8
# ⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a  - 4⋅\tilde
#
#     5  7    6                  5  7    4                  5  7    2
# {r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\ti
#
#        5  7             5  6    6                  5  6    4
# lde{r}₊ ⋅a  + \tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r}₊
#
# 5  6    2                  5  6               5  5    4                  5  5
#  ⋅a ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}₊ ⋅a ⋅
#
#    2                  5  5               5  4    4                  5  4    2
# sin (θ) - 4⋅\tilde{r}₊ ⋅a  - 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 6⋅\tilde{r}₊ ⋅a ⋅sin (
#
#                5  4               3  10    6                  3  10    4
# θ) - \tilde{r}₊ ⋅a  + 3⋅\tilde{r}₊ ⋅a  ⋅sin (θ) - 5⋅\tilde{r}₊ ⋅a  ⋅sin (θ) +
#
#           3  10    2                3  10               3  9    4
# \tilde{r}₊ ⋅a  ⋅sin (θ) + \tilde{r}₊ ⋅a   + 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\til
#
#       3  9    2                  3  9               3  8    6
# de{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 7⋅\tilde{r}
#
#  3  8    4                  3  8    2                3  8                3  7
# ₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  - 16⋅\tilde{r}₊ ⋅a ⋅
#
#    4                   3  7    2                  3  7             3  6    6
# sin (θ) + 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a  + \tilde{r}₊ ⋅a ⋅sin (θ
#
#                  3  6    4                   3  6    2                  3  6
# ) - 10⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 12⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  -
#
#              12    6                    12    4                    12    2
#  \tilde{r}₊⋅a  ⋅sin (θ) + 3⋅\tilde{r}₊⋅a  ⋅sin (θ) - 3⋅\tilde{r}₊⋅a  ⋅sin (θ)
#
#               12                 11    6                     11    4
# + \tilde{r}₊⋅a   - 4⋅\tilde{r}₊⋅a  ⋅sin (θ) + 12⋅\tilde{r}₊⋅a  ⋅sin (θ) - 12⋅\
#
#            11    2                    11                 10    6
# tilde{r}₊⋅a  ⋅sin (θ) + 4⋅\tilde{r}₊⋅a   + 3⋅\tilde{r}₊⋅a  ⋅sin (θ) - 6⋅\tilde
#
#       10    4                    10    2                    9    6
# {r}₊⋅a  ⋅sin (θ) + 3⋅\tilde{r}₊⋅a  ⋅sin (θ) + 8⋅\tilde{r}₊⋅a ⋅sin (θ) - 20⋅\ti
#
#          9    4                     9    2                    9
# lde{r}₊⋅a ⋅sin (θ) + 16⋅\tilde{r}₊⋅a ⋅sin (θ) - 4⋅\tilde{r}₊⋅a  + 4⋅\tilde{r}₊
#
#   8    6                    8    4                    8    2
# ⋅a ⋅sin (θ) - 9⋅\tilde{r}₊⋅a ⋅sin (θ) + 6⋅\tilde{r}₊⋅a ⋅sin (θ) - \tilde{r}₊⋅a
#
# 8⎤
#  ⎦

# %%
coeffs[0].simplify().factor()
# Out:
#                  ⎛          4               2  2    2       4    2       2
# -(a - 1)⋅(a + 1)⋅⎝\tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + a ⋅cos (θ) + a ⋅cos
#
# 2       2⎞
#  (θ) - a ⎠

# %%
A_coeff = coeffs[0].simplify().factor().args[3]
A_coeff
# Out:
#           4               2  2    2       4    2       2    2       2
# \tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + a ⋅cos (θ) + a ⋅cos (θ) - a

# %%
coeffs[1].simplify().factor()
# Out:
#                             ⎛          4               2  2    2       4    2
# -\tilde{r}₊⋅(a - 1)⋅(a + 1)⋅⎝\tilde{r}₊  + 2⋅\tilde{r}₊ ⋅a ⋅cos (θ) + a ⋅cos (
#
#       2    2       2⎞
# θ) + a ⋅cos (θ) - a ⎠

# %%
coeffs[2].simplify().factor().args[3].collect(r_tilde_plus)
# Out:
#           6             4 ⎛     2    2         2    ⎞             2 ⎛   4    4
# \tilde{r}₊  + \tilde{r}₊ ⋅⎝- 3⋅a ⋅sin (θ) + 5⋅a  + 1⎠ + \tilde{r}₊ ⋅⎝4⋅a ⋅sin
#
#           4    2         4    2    2         2⎞      6    4         6    2
# (θ) - 11⋅a ⋅sin (θ) + 7⋅a  - a ⋅sin (θ) + 2⋅a ⎠ + 2⋅a ⋅sin (θ) - 5⋅a ⋅sin (θ)
#
#      6      4    4         4    2       4
# + 3⋅a  + 2⋅a ⋅sin (θ) - 4⋅a ⋅sin (θ) + a

# %%
coeffs_2_r_tilde_plus = sympy.Poly(coeffs[2].simplify().factor().args[3].collect(r_tilde_plus), r_tilde_plus).all_coeffs()
coeffs_2_r_tilde_plus
# Out:
# ⎡           2    2         2            4    4          4    2         4    2
# ⎣1, 0, - 3⋅a ⋅sin (θ) + 5⋅a  + 1, 0, 4⋅a ⋅sin (θ) - 11⋅a ⋅sin (θ) + 7⋅a  - a ⋅
#
#    2         2        6    4         6    2         6      4    4         4
# sin (θ) + 2⋅a , 0, 2⋅a ⋅sin (θ) - 5⋅a ⋅sin (θ) + 3⋅a  + 2⋅a ⋅sin (θ) - 4⋅a ⋅si
#
#  2       4⎤
# n (θ) + a ⎦

# %%
coeffs_3_r_tilde_plus = sympy.Poly(coeffs[3].simplify().factor().args[3].collect(r_tilde_plus), r_tilde_plus).all_coeffs()
coeffs_3_r_tilde_plus
# Out:
# ⎡               3    2         3    2    2         2                  5    4
# ⎣a - 1, 0, - 5⋅a ⋅sin (θ) + 3⋅a  + a ⋅sin (θ) - 7⋅a  + 3⋅a + 1, 0, 8⋅a ⋅sin (θ
#
#         5    2         5       4    2          4      3    2         3      2
# ) - 11⋅a ⋅sin (θ) + 3⋅a  + 11⋅a ⋅sin (θ) - 11⋅a  - 5⋅a ⋅sin (θ) + 6⋅a  - 3⋅a ⋅
#
#    2         2        7    4         7    2       7      6    4         6    2
# sin (θ) + 2⋅a , 0, 2⋅a ⋅sin (θ) - 3⋅a ⋅sin (θ) + a  - 2⋅a ⋅sin (θ) + 7⋅a ⋅sin
#
#          6      5    4         5    2         5      4    4       4⎤
# (θ) - 5⋅a  + 6⋅a ⋅sin (θ) - 8⋅a ⋅sin (θ) + 3⋅a  + 2⋅a ⋅sin (θ) + a ⎦

# %%
coeffs[4].simplify().factor()
# Out:
#  2 ⎛          8    2                  6  2    4                  6  2    2
# a ⋅⎝\tilde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ)
#
#               6  2               6               4  4    4                   4
# - 2⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊  - 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 11⋅\tilde{r}₊
#
#   4    2                  4  4             4  2    4                  4  2
# ⋅a ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin
#
# 2                  4  2             4    2                  4               2
#  (θ) + 5⋅\tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅sin (θ) + 2⋅\tilde{r}₊  + 2⋅\tilde{r}₊ ⋅
#
#  6    6                   2  6    4                   2  6    2
# a ⋅sin (θ) - 12⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 18⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{
#
#    2  6               2  4    6                  2  4    4                   2
# r}₊ ⋅a  - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 6⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 10⋅\tilde{r}₊
#
#   4    2                  2  4               2  2    2                  2  2
# ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  +
#
#   8    6         8    4         8    2         8    6    4       6    4    6
#  a ⋅sin (θ) - 5⋅a ⋅sin (θ) + 7⋅a ⋅sin (θ) - 3⋅a  - a ⋅sin (θ) + a  - a ⋅sin (θ
#
#        4    4         4    2         4⎞
# ) + 4⋅a ⋅sin (θ) - 6⋅a ⋅sin (θ) + 2⋅a ⎠

# %%
coeffs[5].simplify().factor()
# Out:
#             2 ⎛          8    2                  6  2    4                  6
# \tilde{r}₊⋅a ⋅⎝\tilde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅
#
#  2    2                  6  2               6               4  4    4
# a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊  - 5⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 11⋅
#
#           4  4    2                  4  4               4  3             4  2
# \tilde{r}₊ ⋅a ⋅sin (θ) - 3⋅\tilde{r}₊ ⋅a  + 8⋅\tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a ⋅
#
#    4                  4  2               4      2                  4
# sin (θ) + 5⋅\tilde{r}₊ ⋅a  + 8⋅\tilde{r}₊ ⋅a⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a + 3⋅\ti
#
#        4    2                  4               2  6    6                   2
# lde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊  + 6⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a
#
# 6    4                   2  6    2                  2  5    6
#  ⋅sin (θ) + 10⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}
#
#  2  5    4                   2  5    2                   2  5               2
# ₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 16⋅\tilde{r}₊ ⋅a  + 2⋅\tilde{r}₊ ⋅
#
#  4    6                  2  4    4                  2  4    2
# a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}
#
#  2  4               2  3    4                   2  3    2                   2
# ₊ ⋅a  - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 32⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 16⋅\tilde{r}₊ ⋅
#
#  3               2  2    4                   2  2    2                  2  2
# a  - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 12⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a  +
#
#   8    6       8    4       8    2       8      7    4          7    2
#  a ⋅sin (θ) - a ⋅sin (θ) - a ⋅sin (θ) + a  + 8⋅a ⋅sin (θ) - 16⋅a ⋅sin (θ) + 8⋅
#
#  7      6    6         6    4         6    2       6      5    6          5
# a  + 4⋅a ⋅sin (θ) - 9⋅a ⋅sin (θ) + 4⋅a ⋅sin (θ) + a  + 8⋅a ⋅sin (θ) - 24⋅a ⋅si
#
#  4          5    2         5      4    6         4    4         4    2
# n (θ) + 24⋅a ⋅sin (θ) - 8⋅a  + 3⋅a ⋅sin (θ) - 8⋅a ⋅sin (θ) + 6⋅a ⋅sin (θ) - 2⋅
#
#  4⎞
# a ⎠

# %%
coeffs_6_r_tilde_plus = sympy.Poly((coeffs[6].simplify().factor() / a ** 2).factor().collect(r_tilde_plus), r_tilde_plus).all_coeffs()
coeffs_6_r_tilde_plus
# Out:
# ⎡   2             2    4             2           2           4    6       4
# ⎣sin (θ), 0, - 2⋅a ⋅sin (θ) - 8⋅a⋅sin (θ) - 2⋅sin (θ), 0, 2⋅a ⋅sin (θ) + a ⋅si
#
#  4         4    2       4       3    4          3    2         2    4
# n (θ) - 5⋅a ⋅sin (θ) - a  + 16⋅a ⋅sin (θ) - 24⋅a ⋅sin (θ) + 5⋅a ⋅sin (θ) - 10⋅
#
#  2    2       2          2           2           6    6         6    4
# a ⋅sin (θ) + a  - 8⋅a⋅sin (θ) - 3⋅sin (θ), 0, - a ⋅sin (θ) + 7⋅a ⋅sin (θ) - 3⋅
#
#  6    2         6      5    6          5    4          5    2       4    6
# a ⋅sin (θ) - 3⋅a  - 8⋅a ⋅sin (θ) + 32⋅a ⋅sin (θ) - 24⋅a ⋅sin (θ) - a ⋅sin (θ)
#
#       4    4          4    2         4       3    4          3    2         2
# + 16⋅a ⋅sin (θ) - 19⋅a ⋅sin (θ) + 2⋅a  + 16⋅a ⋅sin (θ) - 24⋅a ⋅sin (θ) + 7⋅a ⋅
#
#    4          2    2       2        8    6       8    4         8    2
# sin (θ) - 10⋅a ⋅sin (θ) + a , 0, - a ⋅sin (θ) - a ⋅sin (θ) + 5⋅a ⋅sin (θ) - 3⋅
#
#  8      7    6          7    4         7    2         6    6          6    4
# a  - 8⋅a ⋅sin (θ) + 16⋅a ⋅sin (θ) - 8⋅a ⋅sin (θ) - 6⋅a ⋅sin (θ) + 21⋅a ⋅sin (θ
#
#         6    2       6      5    6          5    4          5    2         4
# ) - 16⋅a ⋅sin (θ) + a  - 8⋅a ⋅sin (θ) + 32⋅a ⋅sin (θ) - 24⋅a ⋅sin (θ) - 3⋅a ⋅s
#
#   6          4    4          4    2         4      10    6         10    4
# in (θ) + 14⋅a ⋅sin (θ) - 12⋅a ⋅sin (θ) + 2⋅a , 0, a  ⋅sin (θ) - 3⋅a  ⋅sin (θ)
#
#      10    2       10      8    6         8    4         8    2         7    6
# + 3⋅a  ⋅sin (θ) - a   - 3⋅a ⋅sin (θ) + 6⋅a ⋅sin (θ) - 3⋅a ⋅sin (θ) - 8⋅a ⋅sin
#
#           7    4         7    2         6    6         6    4         6    2
# (θ) + 16⋅a ⋅sin (θ) - 8⋅a ⋅sin (θ) - 4⋅a ⋅sin (θ) + 9⋅a ⋅sin (θ) - 6⋅a ⋅sin (θ
#
#      6⎤
# ) + a ⎦

# %%
coeffs[7].simplify().factor()
# Out:
#              2 ⎛            10    2                  8  2    4
# -\tilde{r}₊⋅a ⋅⎝- \tilde{r}₊  ⋅sin (θ) + 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r
#
#   8  2    2                  8    2                  6  4    6
# }₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r
#
#   6  4    4                  6  4    2                6  4               6  2
# }₊ ⋅a ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  + 3⋅\tilde{r}₊ ⋅a ⋅
#
#    4                  6  2    2                6  2             6    2
# sin (θ) - 6⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅sin (θ) - \t
#
#         4  6    6                  4  6    4                  4  6    2
# ilde{r}₊ ⋅a ⋅sin (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \
#
#          4  6               4  5    6                  4  5    4
# tilde{r}₊ ⋅a  + 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde
#
#     4  5    2                  4  5             4  4    6                  4
# {r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a  - \tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}₊ ⋅a
#
# 4    4                  4  4    2                  4  4               4  3
#  ⋅sin (θ) - 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 2⋅\tilde{r}₊ ⋅a  + 4⋅\tilde{r}₊ ⋅a ⋅sin
#
# 4                  4  3    2                  4  3               4  2    4
#  (θ) - 8⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 4⋅\tilde{r}₊ ⋅a  + 3⋅\tilde{r}₊ ⋅a ⋅sin (θ)
#
#               4  2    2                4  2               2  8    6
# - 6⋅\tilde{r}₊ ⋅a ⋅sin (θ) + \tilde{r}₊ ⋅a  - 3⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 5⋅\ti
#
#        2  8    4                2  8    2                2  8               2
# lde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a  - 8⋅\tilde{r}₊ ⋅
#
#  7    4                   2  7    2                  2  7               2  6
# a ⋅sin (θ) + 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 8⋅\tilde{r}₊ ⋅a  - 2⋅\tilde{r}₊ ⋅a ⋅s
#
#   6                  2  6    4                  2  6    2                2  6
# in (θ) + 7⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 4⋅\tilde{r}₊ ⋅a ⋅sin (θ) - \tilde{r}₊ ⋅a
#
#                2  5    4                   2  5    2                  2  5
# + 16⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 24⋅\tilde{r}₊ ⋅a ⋅sin (θ) + 8⋅\tilde{r}₊ ⋅a  - \
#
#          2  4    6                   2  4    4                   2  4    2
# tilde{r}₊ ⋅a ⋅sin (θ) + 10⋅\tilde{r}₊ ⋅a ⋅sin (θ) - 12⋅\tilde{r}₊ ⋅a ⋅sin (θ)
#
#               2  4    10    6         10    4         10    2       10      9
# + 2⋅\tilde{r}₊ ⋅a  + a  ⋅sin (θ) - 3⋅a  ⋅sin (θ) + 3⋅a  ⋅sin (θ) - a   + 4⋅a ⋅
#
#    6          9    4          9    2         9      8    6         8    4
# sin (θ) - 12⋅a ⋅sin (θ) + 12⋅a ⋅sin (θ) - 4⋅a  - 3⋅a ⋅sin (θ) + 6⋅a ⋅sin (θ) -
#
#     8    2         7    6          7    4          7    2         7      6
#  3⋅a ⋅sin (θ) - 8⋅a ⋅sin (θ) + 20⋅a ⋅sin (θ) - 16⋅a ⋅sin (θ) + 4⋅a  - 4⋅a ⋅sin
#
# 6         6    4         6    2       6⎞
#  (θ) + 9⋅a ⋅sin (θ) - 6⋅a ⋅sin (θ) + a ⎠

# %% [markdown]
# ### Numerical Evaluation

# %%
from tqdm import tqdm

# %%
def check_if_allowable(poly_cond, A_coeff, a_val, r_tilde_plus_val):
    # check the sign of leading term in r_tilde
    A = A_coeff.subs({a: a_val, r_tilde_plus: r_tilde_plus_val}).evalf()
    if A < 0:
         return False

    # numerically compute the roots
    p = poly_cond.subs({a: a_val, r_tilde_plus: r_tilde_plus_val})
    roots = sympy.solve(p, r_tilde)

    if not roots:
        print(f"No roots found for a = {a_val}, r_tilde_plus = {r_tilde_plus_val}")

    for r in roots:
        if r != sympy.nan:
            if np.abs(r.coeff(sympy.I)) < 1e-10:
                if r.is_real:
                    real_part = r
                else:
                    real_part = r.args[0]
                if real_part > r_tilde_plus_val:
                    return False

    return True


def conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, poly_cond, A_coeff):
    allowable_map = np.zeros(a_vals_grid.shape, dtype=bool)

    # restrict to given theta
    poly_cond_theta = poly_cond.subs({theta: theta_val})
    A_coeff_theta = A_coeff.subs({theta: theta_val})

    with tqdm(total=np.prod(a_vals_grid.shape)) as pbar:
        for i in range(a_vals_grid.shape[0]):
            for j in range(a_vals_grid.shape[1]):
                allowable_map[i, j] = check_if_allowable(
                    poly_cond_theta, A_coeff_theta, a_vals_grid[i, j], r_tilde_plus_vals_grid[i, j]
                )
                pbar.update(1)

    return allowable_map

# %% [markdown]
# #### $\theta=\pi/4$

# %%
a_vals = np.arange(0, 1.05, 0.05)
r_tilde_plus_vals = np.arange(-1, 1.1, 0.1)
a_vals_grid, r_tilde_plus_vals_grid = np.meshgrid(a_vals, r_tilde_plus_vals)

# %%
a_vals_2 = np.arange(0, 1.05, 0.05)
r_tilde_plus_vals_2 = np.arange(-1, 1.05, 0.05)
a_vals_grid_2, r_tilde_plus_vals_grid_2 = np.meshgrid(a_vals_2, r_tilde_plus_vals_2)

# %%
a_vals_3 = np.arange(0, 1.025, 0.025)
r_tilde_plus_vals_3 = np.arange(-1, 1.025, 0.025)
a_vals_grid_3, r_tilde_plus_vals_grid_3 = np.meshgrid(a_vals_3, r_tilde_plus_vals_3)

# %%
a_vals_4 = np.arange(0, 1.01, 0.01)
r_tilde_plus_vals_4 = np.arange(-1, 1.01, 0.01)
a_vals_grid_4, r_tilde_plus_vals_grid_4 = np.meshgrid(a_vals_4, r_tilde_plus_vals_4)

# %%
theta_val = np.pi / 4
allowable_map_pi_4 = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, poly_2, A_coeff)
# Out:
# 100%|██████████| 441/441 [20:46<00:00,  2.83s/it]

# %%
plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map_pi_4, cmap='Set2')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/4$');

# %% [markdown]
# #### $\theta=\pi/2$

# %%
theta_val = np.pi / 2
allowable_map_pi_2 = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, poly_2, A_coeff)
# Out:
# 100%|██████████| 441/441 [10:46<00:00,  1.47s/it]

# %%
plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map_pi_2, cmap='Set2')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/2$');

# %% [markdown]
# #### $\theta = 0$

# %%
theta_val = 0
allowable_map_0 = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, poly_2, A_coeff)
# Out:
#   5%|▍         | 20/441 [01:21<32:58,  4.70s/it]
# No roots found for a = 1.0, r_tilde_plus = -1.0
# 100%|██████████| 441/441 [47:02<00:00,  6.40s/it]

# %%
plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map_0, cmap='Set2')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = 0$');

# %% [markdown]
# #### $\theta = \pi/8$

# %%
theta_val = np.pi / 8
allowable_map_pi_8 = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, poly_2, A_coeff)
# Out:
# 100%|██████████| 441/441 [31:08<00:00,  4.24s/it]

# %%
plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map_pi_8, cmap='Set2')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/8$');

# %%
theta_val = np.pi / 8
allowable_map_pi_8_2 = conduct_sweep(a_vals_grid_2, r_tilde_plus_vals_grid_2, theta_val, poly_2, A_coeff)
# Out:
# 100%|██████████| 861/861 [57:48<00:00,  4.03s/it]

# %%
plt.contourf(a_vals_grid_2, r_tilde_plus_vals_grid_2, allowable_map_pi_8_2, cmap='Set2')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/8$');

# %%
theta_val = np.pi / 8
allowable_map_pi_8_3 = conduct_sweep(a_vals_grid_3, r_tilde_plus_vals_grid_3, theta_val, poly_2, A_coeff)
# Out:
# 100%|██████████| 3321/3321 [9:41:39<00:00, 10.51s/it]

# %%
plt.contourf(a_vals_grid_3, r_tilde_plus_vals_grid_3, allowable_map_pi_8_3, cmap='Set2')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/8$');

# %%
import allowability
from multiprocessing import Pool

# %%
args_parallel = [(poly_2, A_coeff, theta_val, av, rp) for av, rp in zip(a_vals_grid_4.flatten(), r_tilde_plus_vals_grid_4.flatten())]

# %%
processes_count = 10

with Pool(processes_count) as pool:
    results = pool.starmap(allowability.check_if_allowable_theta, tqdm(args_parallel, total=len(args_parallel)))
# Out:
# 100%|██████████| 20301/20301 [3:23:23<00:00,  1.66it/s]

# %%
plt.contourf(a_vals_grid_4, r_tilde_plus_vals_grid_4, np.array(results).reshape(a_vals_grid_4.shape), cmap='Set2')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/8$')
plt.savefig('figures/sufficient_condition_parameter_space_theta_pi_8.pdf', bbox_inches='tight', dpi=300);

# %% [markdown]
# Spotcheck.

# %%
a_val = 0.8
r_tilde_plus_val = -0.25

# %%
p = poly.subs({a: a_val, r_tilde_plus: r_tilde_plus_val, theta: theta_val})
roots = sympy.solve(p, r_tilde)

# %%
roots
# Out:
# [-0.733408284174792, -0.25, 0.0411270962319479, 0.554572767535705, -0.32645128
# 448271 - 1.24995359166451⋅ⅈ, -0.32645128448271 + 1.24995359166451⋅ⅈ, 0.5203054
# 94686279 - 1.52472070169571⋅ⅈ, 0.520305494686279 + 1.52472070169571⋅ⅈ]

# %%
poly_vals = []

r_tilde_vals = np.arange(-10, 10, 0.01)

for r_tilde_val in r_tilde_vals:
    poly_vals.append(p.subs({r_tilde: r_tilde_val}).evalf())

# %%
plt.figure(figsize=(5, 3))
plt.plot(r_tilde_vals, poly_vals)
plt.plot(r_tilde_plus_val, 0, 'kx')
plt.ylim([-0.001, 0.001])
plt.plot([-1, 1], [0, 0], 'k-')
plt.xlim([-1, 1]);

# %% [markdown]
# Plot the actual determinant of the real part of the metric.

# %%
W_val = r_tilde ** 2 + a ** 2 * sympy.cos(theta) ** 2

# %%
g2 = g_mat.subs({omega: omega_val, delta_theta: delta_theta_val, W: W_val}).subs({xi: xi_val, delta_r: real_delta_r + sympy.I * imag_delta_r})
g2 = g2.subs({a: a_val, r_tilde_plus: r_tilde_plus_val, theta: theta_val})

# %%
g_mat_real_det_vals = []

r_tilde_vals = np.arange(-10, 10, 0.01)

for r_tilde_val in r_tilde_vals:
    g_mat_real_det_vals.append(sympy.re(g2.subs({r_tilde: r_tilde_val}).evalf()).det())

# %%
plt.figure(figsize=(5, 3))
plt.plot(r_tilde_vals, g_mat_real_det_vals)
plt.plot([-1, 1], [0, 0], 'k-')
plt.ylim([-0.05, 0.05])
plt.xlim([-1, 1]);

# %% [markdown]
# #### $\theta=\pi/6$

# %%
theta_val = np.pi / 6
allowable_map_pi_6 = conduct_sweep(a_vals_grid, r_tilde_plus_vals_grid, theta_val, poly_2, A_coeff)
# Out:
# 100%|██████████| 441/441 [26:15<00:00,  3.57s/it]

# %%
plt.contourf(a_vals_grid, r_tilde_plus_vals_grid, allowable_map_pi_6, cmap='Set2')
plt.plot(a_vals, [sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.plot(a_vals, [-sympy.sqrt(a_val) for a_val in a_vals], 'k-')
plt.xlabel("$a$")
plt.ylabel("$\\tilde{r}_+$")
plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.colorbar()
plt.title('$\\theta = \pi/6$');
