# %%
import sympy

from complex_spacetime_metrics import config
from complex_spacetime_metrics import metric as metric_utils
from complex_spacetime_metrics.admissibility import PointwiseAnalyticalRoots
from complex_spacetime_metrics.plot import plot_admissibility

# %%
q_val = "q_1"
filename_base = "AE_minus_C_squared_gt_0"

# %%
data_dir_path = f"../../data/{q_val}"
figure_dir_path = f"../../figures/{q_val}"

# %%
metric = metric_utils.Metric3D()
metric_coeffs = metric.coefficients()

# %%
A = metric_coeffs[metric_utils.A]
C = metric_coeffs[metric_utils.C]
E = metric_coeffs[metric_utils.E]

# %%
condition = A * E - C ** 2
condition = condition.expand().simplify().factor()

# %%
condition
# Out:
# (\tilde{r} - \tilde{r}_+)*(-\tilde{r}**7*\tilde{r}_+**4*a**2 + \tilde{r}**7*\tilde{r}_+**4 + 2*\tilde{r}**7*\tilde{r}_+**2*a**4*sin(theta)**2 - 2*\tilde{r}**7*\tilde{r}_+**2*a**4 - 2*\tilde{r}**7*\tilde{r}_+**2*a**2*sin(theta)**2 + 2*\tilde{r}**7*\tilde{r}_+**2*a**2 + \tilde{r}**7*a**6*sin(theta)**2 - \tilde{r}**7*a**6 + \tilde{r}**7*a**4 - \tilde{r}**7*a**2*sin(theta)**2 - \tilde{r}**6*\tilde{r}_+**5*a**2 + \tilde{r}**6*\tilde{r}_+**5 + 2*\tilde{r}**6*\tilde{r}_+**3*a**4*sin(theta)**2 - 2*\tilde{r}**6*\tilde{r}_+**3*a**4 - 2*\tilde{r}**6*\tilde{r}_+**3*a**2*sin(theta)**2 + 2*\tilde{r}**6*\tilde{r}_+**3*a**2 + \tilde{r}**6*\tilde{r}_+*a**6*sin(theta)**2 - \tilde{r}**6*\tilde{r}_+*a**6 + \tilde{r}**6*\tilde{r}_+*a**4 - \tilde{r}**6*\tilde{r}_+*a**2*sin(theta)**2 - \tilde{r}**5*\tilde{r}_+**6*a**2 + \tilde{r}**5*\tilde{r}_+**6 + 3*\tilde{r}**5*\tilde{r}_+**4*a**4*sin(theta)**2 - 5*\tilde{r}**5*\tilde{r}_+**4*a**4 - 3*\tilde{r}**5*\tilde{r}_+**4*a**2*sin(theta)**2 + 4*\tilde{r}**5*\tilde{r}_+**4*a**2 + \tilde{r}**5*\tilde{r}_+**4 - 4*\tilde{r}**5*\tilde{r}_+**2*a**6*sin(theta)**4 + 11*\tilde{r}**5*\tilde{r}_+**2*a**6*sin(theta)**2 - 7*\tilde{r}**5*\tilde{r}_+**2*a**6 + 4*\tilde{r}**5*\tilde{r}_+**2*a**4*sin(theta)**4 - 10*\tilde{r}**5*\tilde{r}_+**2*a**4*sin(theta)**2 + 5*\tilde{r}**5*\tilde{r}_+**2*a**4 - \tilde{r}**5*\tilde{r}_+**2*a**2*sin(theta)**2 + 2*\tilde{r}**5*\tilde{r}_+**2*a**2 - 2*\tilde{r}**5*a**8*sin(theta)**4 + 5*\tilde{r}**5*a**8*sin(theta)**2 - 3*\tilde{r}**5*a**8 - \tilde{r}**5*a**6*sin(theta)**2 + 2*\tilde{r}**5*a**6 + 2*\tilde{r}**5*a**4*sin(theta)**4 - 4*\tilde{r}**5*a**4*sin(theta)**2 + \tilde{r}**5*a**4 - \tilde{r}**4*\tilde{r}_+**7*a**2 + \tilde{r}**4*\tilde{r}_+**7 + 5*\tilde{r}**4*\tilde{r}_+**5*a**4*sin(theta)**2 - 3*\tilde{r}**4*\tilde{r}_+**5*a**4 + 4*\tilde{r}**4*\tilde{r}_+**5*a**3*sin(theta)**2 + 4*\tilde{r}**4*\tilde{r}_+**5*a**3 - \tilde{r}**4*\tilde{r}_+**5*a**2*sin(theta)**2 + 4*\tilde{r}**4*\tilde{r}_+**5*a**2 - 4*\tilde{r}**4*\tilde{r}_+**5*a - \tilde{r}**4*\tilde{r}_+**5 - 8*\tilde{r}**4*\tilde{r}_+**3*a**6*sin(theta)**4 + 11*\tilde{r}**4*\tilde{r}_+**3*a**6*sin(theta)**2 - 3*\tilde{r}**4*\tilde{r}_+**3*a**6 - 8*\tilde{r}**4*\tilde{r}_+**3*a**5*sin(theta)**4 + 8*\tilde{r}**4*\tilde{r}_+**3*a**5 - 6*\tilde{r}**4*\tilde{r}_+**3*a**4*sin(theta)**2 + 5*\tilde{r}**4*\tilde{r}_+**3*a**4 + 8*\tilde{r}**4*\tilde{r}_+**3*a**3*sin(theta)**2 - 8*\tilde{r}**4*\tilde{r}_+**3*a**3 + 3*\tilde{r}**4*\tilde{r}_+**3*a**2*sin(theta)**2 - 2*\tilde{r}**4*\tilde{r}_+**3*a**2 - 2*\tilde{r}**4*\tilde{r}_+*a**8*sin(theta)**4 + 3*\tilde{r}**4*\tilde{r}_+*a**8*sin(theta)**2 - \tilde{r}**4*\tilde{r}_+*a**8 - 4*\tilde{r}**4*\tilde{r}_+*a**7*sin(theta)**2 + 4*\tilde{r}**4*\tilde{r}_+*a**7 - 4*\tilde{r}**4*\tilde{r}_+*a**6*sin(theta)**4 + \tilde{r}**4*\tilde{r}_+*a**6*sin(theta)**2 + 2*\tilde{r}**4*\tilde{r}_+*a**6 - 8*\tilde{r}**4*\tilde{r}_+*a**5*sin(theta)**4 + 8*\tilde{r}**4*\tilde{r}_+*a**5*sin(theta)**2 - 4*\tilde{r}**4*\tilde{r}_+*a**5 - 2*\tilde{r}**4*\tilde{r}_+*a**4*sin(theta)**4 - \tilde{r}**4*\tilde{r}_+*a**4 + \tilde{r}**3*\tilde{r}_+**8*a**2*sin(theta)**2 - 2*\tilde{r}**3*\tilde{r}_+**6*a**4*sin(theta)**4 + 4*\tilde{r}**3*\tilde{r}_+**6*a**4*sin(theta)**2 - 2*\tilde{r}**3*\tilde{r}_+**6*a**4 + 2*\tilde{r}**3*\tilde{r}_+**6*a**2 - 5*\tilde{r}**3*\tilde{r}_+**4*a**6*sin(theta)**4 + 11*\tilde{r}**3*\tilde{r}_+**4*a**6*sin(theta)**2 - 7*\tilde{r}**3*\tilde{r}_+**4*a**6 - \tilde{r}**3*\tilde{r}_+**4*a**4*sin(theta)**4 - 4*\tilde{r}**3*\tilde{r}_+**4*a**4*sin(theta)**2 + 5*\tilde{r}**3*\tilde{r}_+**4*a**4 - \tilde{r}**3*\tilde{r}_+**4*a**2*sin(theta)**2 + 2*\tilde{r}**3*\tilde{r}_+**4*a**2 + 2*\tilde{r}**3*\tilde{r}_+**2*a**8*sin(theta)**6 - 12*\tilde{r}**3*\tilde{r}_+**2*a**8*sin(theta)**4 + 18*\tilde{r}**3*\tilde{r}_+**2*a**8*sin(theta)**2 - 8*\tilde{r}**3*\tilde{r}_+**2*a**8 - 2*\tilde{r}**3*\tilde{r}_+**2*a**6*sin(theta)**6 + 6*\tilde{r}**3*\tilde{r}_+**2*a**6*sin(theta)**4 - 10*\tilde{r}**3*\tilde{r}_+**2*a** ...

# %% [markdown]
# Remove the denominator, which is always positive.

# %%
condition = sympy.fraction(condition)[0]

# %% [markdown]
# Remove common angular dependence.

# %%
condition /= sympy.sin(metric_utils.theta) ** 2
condition
# Out:
# (\tilde{r} - \tilde{r}_+)*(-\tilde{r}**7*\tilde{r}_+**4*a**2 + \tilde{r}**7*\tilde{r}_+**4 + 2*\tilde{r}**7*\tilde{r}_+**2*a**4*sin(theta)**2 - 2*\tilde{r}**7*\tilde{r}_+**2*a**4 - 2*\tilde{r}**7*\tilde{r}_+**2*a**2*sin(theta)**2 + 2*\tilde{r}**7*\tilde{r}_+**2*a**2 + \tilde{r}**7*a**6*sin(theta)**2 - \tilde{r}**7*a**6 + \tilde{r}**7*a**4 - \tilde{r}**7*a**2*sin(theta)**2 - \tilde{r}**6*\tilde{r}_+**5*a**2 + \tilde{r}**6*\tilde{r}_+**5 + 2*\tilde{r}**6*\tilde{r}_+**3*a**4*sin(theta)**2 - 2*\tilde{r}**6*\tilde{r}_+**3*a**4 - 2*\tilde{r}**6*\tilde{r}_+**3*a**2*sin(theta)**2 + 2*\tilde{r}**6*\tilde{r}_+**3*a**2 + \tilde{r}**6*\tilde{r}_+*a**6*sin(theta)**2 - \tilde{r}**6*\tilde{r}_+*a**6 + \tilde{r}**6*\tilde{r}_+*a**4 - \tilde{r}**6*\tilde{r}_+*a**2*sin(theta)**2 - \tilde{r}**5*\tilde{r}_+**6*a**2 + \tilde{r}**5*\tilde{r}_+**6 + 3*\tilde{r}**5*\tilde{r}_+**4*a**4*sin(theta)**2 - 5*\tilde{r}**5*\tilde{r}_+**4*a**4 - 3*\tilde{r}**5*\tilde{r}_+**4*a**2*sin(theta)**2 + 4*\tilde{r}**5*\tilde{r}_+**4*a**2 + \tilde{r}**5*\tilde{r}_+**4 - 4*\tilde{r}**5*\tilde{r}_+**2*a**6*sin(theta)**4 + 11*\tilde{r}**5*\tilde{r}_+**2*a**6*sin(theta)**2 - 7*\tilde{r}**5*\tilde{r}_+**2*a**6 + 4*\tilde{r}**5*\tilde{r}_+**2*a**4*sin(theta)**4 - 10*\tilde{r}**5*\tilde{r}_+**2*a**4*sin(theta)**2 + 5*\tilde{r}**5*\tilde{r}_+**2*a**4 - \tilde{r}**5*\tilde{r}_+**2*a**2*sin(theta)**2 + 2*\tilde{r}**5*\tilde{r}_+**2*a**2 - 2*\tilde{r}**5*a**8*sin(theta)**4 + 5*\tilde{r}**5*a**8*sin(theta)**2 - 3*\tilde{r}**5*a**8 - \tilde{r}**5*a**6*sin(theta)**2 + 2*\tilde{r}**5*a**6 + 2*\tilde{r}**5*a**4*sin(theta)**4 - 4*\tilde{r}**5*a**4*sin(theta)**2 + \tilde{r}**5*a**4 - \tilde{r}**4*\tilde{r}_+**7*a**2 + \tilde{r}**4*\tilde{r}_+**7 + 5*\tilde{r}**4*\tilde{r}_+**5*a**4*sin(theta)**2 - 3*\tilde{r}**4*\tilde{r}_+**5*a**4 + 4*\tilde{r}**4*\tilde{r}_+**5*a**3*sin(theta)**2 + 4*\tilde{r}**4*\tilde{r}_+**5*a**3 - \tilde{r}**4*\tilde{r}_+**5*a**2*sin(theta)**2 + 4*\tilde{r}**4*\tilde{r}_+**5*a**2 - 4*\tilde{r}**4*\tilde{r}_+**5*a - \tilde{r}**4*\tilde{r}_+**5 - 8*\tilde{r}**4*\tilde{r}_+**3*a**6*sin(theta)**4 + 11*\tilde{r}**4*\tilde{r}_+**3*a**6*sin(theta)**2 - 3*\tilde{r}**4*\tilde{r}_+**3*a**6 - 8*\tilde{r}**4*\tilde{r}_+**3*a**5*sin(theta)**4 + 8*\tilde{r}**4*\tilde{r}_+**3*a**5 - 6*\tilde{r}**4*\tilde{r}_+**3*a**4*sin(theta)**2 + 5*\tilde{r}**4*\tilde{r}_+**3*a**4 + 8*\tilde{r}**4*\tilde{r}_+**3*a**3*sin(theta)**2 - 8*\tilde{r}**4*\tilde{r}_+**3*a**3 + 3*\tilde{r}**4*\tilde{r}_+**3*a**2*sin(theta)**2 - 2*\tilde{r}**4*\tilde{r}_+**3*a**2 - 2*\tilde{r}**4*\tilde{r}_+*a**8*sin(theta)**4 + 3*\tilde{r}**4*\tilde{r}_+*a**8*sin(theta)**2 - \tilde{r}**4*\tilde{r}_+*a**8 - 4*\tilde{r}**4*\tilde{r}_+*a**7*sin(theta)**2 + 4*\tilde{r}**4*\tilde{r}_+*a**7 - 4*\tilde{r}**4*\tilde{r}_+*a**6*sin(theta)**4 + \tilde{r}**4*\tilde{r}_+*a**6*sin(theta)**2 + 2*\tilde{r}**4*\tilde{r}_+*a**6 - 8*\tilde{r}**4*\tilde{r}_+*a**5*sin(theta)**4 + 8*\tilde{r}**4*\tilde{r}_+*a**5*sin(theta)**2 - 4*\tilde{r}**4*\tilde{r}_+*a**5 - 2*\tilde{r}**4*\tilde{r}_+*a**4*sin(theta)**4 - \tilde{r}**4*\tilde{r}_+*a**4 + \tilde{r}**3*\tilde{r}_+**8*a**2*sin(theta)**2 - 2*\tilde{r}**3*\tilde{r}_+**6*a**4*sin(theta)**4 + 4*\tilde{r}**3*\tilde{r}_+**6*a**4*sin(theta)**2 - 2*\tilde{r}**3*\tilde{r}_+**6*a**4 + 2*\tilde{r}**3*\tilde{r}_+**6*a**2 - 5*\tilde{r}**3*\tilde{r}_+**4*a**6*sin(theta)**4 + 11*\tilde{r}**3*\tilde{r}_+**4*a**6*sin(theta)**2 - 7*\tilde{r}**3*\tilde{r}_+**4*a**6 - \tilde{r}**3*\tilde{r}_+**4*a**4*sin(theta)**4 - 4*\tilde{r}**3*\tilde{r}_+**4*a**4*sin(theta)**2 + 5*\tilde{r}**3*\tilde{r}_+**4*a**4 - \tilde{r}**3*\tilde{r}_+**4*a**2*sin(theta)**2 + 2*\tilde{r}**3*\tilde{r}_+**4*a**2 + 2*\tilde{r}**3*\tilde{r}_+**2*a**8*sin(theta)**6 - 12*\tilde{r}**3*\tilde{r}_+**2*a**8*sin(theta)**4 + 18*\tilde{r}**3*\tilde{r}_+**2*a**8*sin(theta)**2 - 8*\tilde{r}**3*\tilde{r}_+**2*a**8 - 2*\tilde{r}**3*\tilde{r}_+**2*a**6*sin(theta)**6 + 6*\tilde{r}**3*\tilde{r}_+**2*a**6*sin(theta)**4 - 10*\tilde{r}**3*\tilde{r}_+**2*a** ...

# %% [markdown]
# Remove $\tilde{r} - \tilde{r}_+$ since we only care about $\tilde{r} > \tilde{r}_+$.

# %%
condition = condition.args[1]

# %%
condition = condition.expand().collect(metric_utils.r_tilde)
condition
# Out:
# \tilde{r}**7*(-\tilde{r}_+**4*a**2 + \tilde{r}_+**4 + 2*\tilde{r}_+**2*a**4*sin(theta)**2 - 2*\tilde{r}_+**2*a**4 - 2*\tilde{r}_+**2*a**2*sin(theta)**2 + 2*\tilde{r}_+**2*a**2 + a**6*sin(theta)**2 - a**6 + a**4 - a**2*sin(theta)**2) + \tilde{r}**6*(-\tilde{r}_+**5*a**2 + \tilde{r}_+**5 + 2*\tilde{r}_+**3*a**4*sin(theta)**2 - 2*\tilde{r}_+**3*a**4 - 2*\tilde{r}_+**3*a**2*sin(theta)**2 + 2*\tilde{r}_+**3*a**2 + \tilde{r}_+*a**6*sin(theta)**2 - \tilde{r}_+*a**6 + \tilde{r}_+*a**4 - \tilde{r}_+*a**2*sin(theta)**2) + \tilde{r}**5*(-\tilde{r}_+**6*a**2 + \tilde{r}_+**6 + 3*\tilde{r}_+**4*a**4*sin(theta)**2 - 5*\tilde{r}_+**4*a**4 - 3*\tilde{r}_+**4*a**2*sin(theta)**2 + 4*\tilde{r}_+**4*a**2 + \tilde{r}_+**4 - 4*\tilde{r}_+**2*a**6*sin(theta)**4 + 11*\tilde{r}_+**2*a**6*sin(theta)**2 - 7*\tilde{r}_+**2*a**6 + 4*\tilde{r}_+**2*a**4*sin(theta)**4 - 10*\tilde{r}_+**2*a**4*sin(theta)**2 + 5*\tilde{r}_+**2*a**4 - \tilde{r}_+**2*a**2*sin(theta)**2 + 2*\tilde{r}_+**2*a**2 - 2*a**8*sin(theta)**4 + 5*a**8*sin(theta)**2 - 3*a**8 - a**6*sin(theta)**2 + 2*a**6 + 2*a**4*sin(theta)**4 - 4*a**4*sin(theta)**2 + a**4) + \tilde{r}**4*(-\tilde{r}_+**7*a**2 + \tilde{r}_+**7 + 5*\tilde{r}_+**5*a**4*sin(theta)**2 - 3*\tilde{r}_+**5*a**4 + 4*\tilde{r}_+**5*a**3*sin(theta)**2 + 4*\tilde{r}_+**5*a**3 - \tilde{r}_+**5*a**2*sin(theta)**2 + 4*\tilde{r}_+**5*a**2 - 4*\tilde{r}_+**5*a - \tilde{r}_+**5 - 8*\tilde{r}_+**3*a**6*sin(theta)**4 + 11*\tilde{r}_+**3*a**6*sin(theta)**2 - 3*\tilde{r}_+**3*a**6 - 8*\tilde{r}_+**3*a**5*sin(theta)**4 + 8*\tilde{r}_+**3*a**5 - 6*\tilde{r}_+**3*a**4*sin(theta)**2 + 5*\tilde{r}_+**3*a**4 + 8*\tilde{r}_+**3*a**3*sin(theta)**2 - 8*\tilde{r}_+**3*a**3 + 3*\tilde{r}_+**3*a**2*sin(theta)**2 - 2*\tilde{r}_+**3*a**2 - 2*\tilde{r}_+*a**8*sin(theta)**4 + 3*\tilde{r}_+*a**8*sin(theta)**2 - \tilde{r}_+*a**8 - 4*\tilde{r}_+*a**7*sin(theta)**2 + 4*\tilde{r}_+*a**7 - 4*\tilde{r}_+*a**6*sin(theta)**4 + \tilde{r}_+*a**6*sin(theta)**2 + 2*\tilde{r}_+*a**6 - 8*\tilde{r}_+*a**5*sin(theta)**4 + 8*\tilde{r}_+*a**5*sin(theta)**2 - 4*\tilde{r}_+*a**5 - 2*\tilde{r}_+*a**4*sin(theta)**4 - \tilde{r}_+*a**4) + \tilde{r}**3*(\tilde{r}_+**8*a**2*sin(theta)**2 - 2*\tilde{r}_+**6*a**4*sin(theta)**4 + 4*\tilde{r}_+**6*a**4*sin(theta)**2 - 2*\tilde{r}_+**6*a**4 + 2*\tilde{r}_+**6*a**2 - 5*\tilde{r}_+**4*a**6*sin(theta)**4 + 11*\tilde{r}_+**4*a**6*sin(theta)**2 - 7*\tilde{r}_+**4*a**6 - \tilde{r}_+**4*a**4*sin(theta)**4 - 4*\tilde{r}_+**4*a**4*sin(theta)**2 + 5*\tilde{r}_+**4*a**4 - \tilde{r}_+**4*a**2*sin(theta)**2 + 2*\tilde{r}_+**4*a**2 + 2*\tilde{r}_+**2*a**8*sin(theta)**6 - 12*\tilde{r}_+**2*a**8*sin(theta)**4 + 18*\tilde{r}_+**2*a**8*sin(theta)**2 - 8*\tilde{r}_+**2*a**8 - 2*\tilde{r}_+**2*a**6*sin(theta)**6 + 6*\tilde{r}_+**2*a**6*sin(theta)**4 - 10*\tilde{r}_+**2*a**6*sin(theta)**2 + 4*\tilde{r}_+**2*a**6 - 4*\tilde{r}_+**2*a**4*sin(theta)**2 + 4*\tilde{r}_+**2*a**4 + a**10*sin(theta)**6 - 5*a**10*sin(theta)**4 + 7*a**10*sin(theta)**2 - 3*a**10 - a**8*sin(theta)**4 + a**8 - a**6*sin(theta)**6 + 4*a**6*sin(theta)**4 - 6*a**6*sin(theta)**2 + 2*a**6) + \tilde{r}**2*(\tilde{r}_+**9*a**2*sin(theta)**2 - 2*\tilde{r}_+**7*a**4*sin(theta)**4 + 4*\tilde{r}_+**7*a**4*sin(theta)**2 - 2*\tilde{r}_+**7*a**4 + 2*\tilde{r}_+**7*a**2 - 5*\tilde{r}_+**5*a**6*sin(theta)**4 + 11*\tilde{r}_+**5*a**6*sin(theta)**2 - 3*\tilde{r}_+**5*a**6 + 8*\tilde{r}_+**5*a**5 - \tilde{r}_+**5*a**4*sin(theta)**4 + 5*\tilde{r}_+**5*a**4 + 8*\tilde{r}_+**5*a**3*sin(theta)**2 - 8*\tilde{r}_+**5*a**3 + 3*\tilde{r}_+**5*a**2*sin(theta)**2 - 2*\tilde{r}_+**5*a**2 + 6*\tilde{r}_+**3*a**8*sin(theta)**6 - 16*\tilde{r}_+**3*a**8*sin(theta)**4 + 10*\tilde{r}_+**3*a**8*sin(theta)**2 + 8*\tilde{r}_+**3*a**7*sin(theta)**6 - 8*\tilde{r}_+**3*a**7*sin(theta)**4 - 16*\tilde{r}_+**3*a**7*sin(theta)**2 + 16*\tilde{r}_+**3*a**7 + 2*\tilde{r}_+**3*a**6*sin(theta)**6 - 2*\tilde{r}_+**3*a**6*sin(theta)**4 - 2*\tilde{r}_+**3*a**6*sin(theta)**2 + 4*\tilde{r}_+**3*a**6 - 8*\tilde{r}_+**3*a**5*sin(theta)**4 + 32*\til ...

# %%
condition_coeffs = sympy.Poly(condition, metric_utils.r_tilde).all_coeffs()

# %%
leading_coeff = condition_coeffs[0].simplify().factor()
leading_coeff
# Out:
# -(a - 1)*(a + 1)*(\tilde{r}_+**4 + 2*\tilde{r}_+**2*a**2*cos(theta)**2 + a**4*cos(theta)**2 + a**2*cos(theta)**2 - a**2)

# %%
leading_coeff = leading_coeff.args[3]
leading_coeff
# Out:
# \tilde{r}_+**4 + 2*\tilde{r}_+**2*a**2*cos(theta)**2 + a**4*cos(theta)**2 + a**2*cos(theta)**2 - a**2

# %%
admissible_evaluator = PointwiseAnalyticalRoots()
admissible_maps = {}

# %%
parameter_grid = config.grids['coarse']

# %%
for theta_name, theta_val in config.thetas.items():
    print(f"Running {theta_name} ...")

    # conduct sweep
    filename_data = f"{data_dir_path}/{filename_base}.{theta_name}.pk"
    admissible_maps[theta_val] = admissible_evaluator.admissibility_parallel(
        parameter_grid, theta_val, condition, leading_coeff, filename_data
    )

    # save plot
    filename_plot = f"{figure_dir_path}/{filename_base}.{theta_name}.pdf"
    plot_admissibility(parameter_grid, admissible_maps[theta_val], filename_plot)
# Out:
# Running theta_pi_18 ...
#  80%|███████▉  | 351/441 [02:20<00:35,  2.54it/s]
